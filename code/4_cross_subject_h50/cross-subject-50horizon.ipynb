# %%
# !git clone https://github.com/Omidzarexz/AnkleBiLSTMJointPrediction
# Out:
# Cloning into 'AnkleBiLSTMJointPrediction'...
# remote: Enumerating objects: 206, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 206 (delta 45), reused 14 (delta 14), pack-reused 129 (from 1)
# Receiving objects: 100% (206/206), 27.42 MiB | 15.44 MiB/s, done.
# Resolving deltas: 100% (99/99), done.

# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt


# df_clean_train_12feature_cross_subject = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_train_12feature_cross_subject.csv")
# df_clean_test_12feature_cross_subject  = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_test_12feature_cross_subject.csv")


df_clean_train_16feature_cross_subject = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_train_16feature_cross_subject.csv")
df_clean_test_16feature_cross_subject  = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_test_16feature_cross_subject.csv")


# df_clean_train_16feature_within_subject = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_train_16feature_within_subject_txt25.csv")
# df_clean_test_16feature_within_subject  = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_test_16feature_within_subject_txt25.csv")

df_clean_train = df_clean_train_16feature_cross_subject
df_clean_test  = df_clean_test_16feature_cross_subject

# %%
from scipy.signal import butter, filtfilt

def low_pass_butter(signal, cutoff=10, fs=100, order=2):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return filtfilt(b, a, signal)
feature_columns = [
    'MPU1_Acc_X', 'MPU1_Acc_Y', 'MPU1_Acc_Z',
    'MPU1_Gyro_X', 'MPU1_Gyro_Y', 'MPU1_Gyro_Z',
    'MPU1_Roll','MPU1_Pitch',
    'MPU2_Acc_X', 'MPU2_Acc_Y', 'MPU2_Acc_Z',
    'MPU2_Gyro_X', 'MPU2_Gyro_Y', 'MPU2_Gyro_Z',
    'MPU2_Roll','MPU2_Pitch'
]




df_filtered_trainig = pd.DataFrame()
df_filtered_test    = pd.DataFrame()
for col in feature_columns:
    df_filtered_trainig[col] = low_pass_butter( df_clean_train[col].values
                                        , cutoff=5 # Hz
                                        , fs=100  # Hz
                                        , order=2  )
    df_filtered_test[col] = low_pass_butter( df_clean_test[col].values
                                        , cutoff=5 # Hz
                                        , fs=100  # Hz
                                        , order=2  )







print("\ndf_filtered_trainig shape:",df_filtered_trainig.shape)
print("\ndf_filtered_test shape:",df_filtered_test.shape)
# Out:
# df_filtered_trainig shape: (87394, 16)
#
# df_filtered_test shape: (17492, 16)

# %%
from sklearn.preprocessing import  MinMaxScaler


scaler = MinMaxScaler(feature_range=(-1, 1))
X_data_train = scaler.fit_transform(df_filtered_trainig[feature_columns].values)  # (T, 12)


y_scaler = MinMaxScaler(feature_range=(-1, 1))
y_data_train = y_scaler.fit_transform(df_clean_train['angle'].values.reshape(-1, 1))





X_data_test = scaler.transform(df_filtered_test[feature_columns].values)

y_data_test = y_scaler.transform(df_clean_test["angle"].values.reshape(-1,1))


# تنظیمات پنجره
window_size = 200   #
horizon = 50        #
step_size = 20      #

# تابع پنجره‌بندی
def create_windows_with_labels(X, y, window_size, horizon, step_size):
    X_windows = []
    y_windows = []
    for i in range(0,  len(X) - window_size - horizon + 1, step_size):
        X_windows.append(X[i:i + window_size])
        y_windows.append(y[i + window_size : i + window_size + horizon])  # برچسب آخرین نمونه در پنجره
    return np.array(X_windows), np.array(y_windows)

# ایجاد پنجره‌ها
X_windows, y_windows = create_windows_with_labels(X_data_train, y_data_train,
                                                  window_size, horizon, step_size)
if horizon==1:
    y_windows = y_windows.reshape(-1,1)
else:
    y_windows = np.squeeze(y_windows, axis=2)





print(f"✅   (X_windows):(samples, time steps, features) → {X_windows.shape}")
print(f"✅  (y_windows): {y_windows.shape}")

step_size_for_test = 1
X_windows_test, y_windows_test = create_windows_with_labels(X_data_test, y_data_test,
                                                            window_size, horizon, step_size_for_test)

if horizon==1:
    y_windows_test = y_windows_test.reshape(-1,1)
else:
    y_windows_test = np.squeeze(y_windows_test, axis=2)

print(f"\n✅   (X_windows_test):(samples, time steps, features) → {X_windows_test.shape}")
print(f"✅  (y_windows_test): {y_windows_test.shape}")
# Out:
# ✅   (X_windows):(samples, time steps, features) → (4358, 200, 16)
# ✅  (y_windows): (4358, 50)
#
# ✅   (X_windows_test):(samples, time steps, features) → (17243, 200, 16)
# ✅  (y_windows_test): (17243, 50)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from keras.layers import Bidirectional

from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, GlobalAveragePooling1D
from tensorflow.keras.layers import Input, Dense, GRU, Bidirectional, Dropout, ReLU, TimeDistributed, LayerNormalization
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l2

LEARNING_RATE = 0.001
lambda_loss_amount = 0.0005



def build_bi_lstm_model(input_shape, horizon=1, lambda_loss_amount=1e-4, learning_rate=1e-3):
    inputs = Input(shape=input_shape, name="input")

    # Dense projection per timestep
    x = TimeDistributed(Dense(128, kernel_regularizer=l2(lambda_loss_amount)))(inputs)
    x = ReLU()(x)

    # Stacked BiGRU layers
    x = Bidirectional(LSTM(128, return_sequences=True,
                           kernel_regularizer=l2(lambda_loss_amount)))(x)
    x = LayerNormalization()(x)
    x = Dropout(0.3)(x)

    x = Bidirectional(LSTM(128, return_sequences=False,
                           kernel_regularizer=l2(lambda_loss_amount)))(x)
    x = Dropout(0.3)(x)

    # Output
    outputs = Dense(horizon, activation='linear')(x)

    # Model compile
    model = Model(inputs=inputs, outputs=outputs, name="BiLSTM_reg")
    model.compile(optimizer=optimizers.Adam(learning_rate=learning_rate),
                  loss='mse',
                  metrics=['mae'])
    return model

final_model = build_bi_lstm_model(input_shape=(X_windows.shape[1],X_windows.shape[2]),horizon=horizon)

# final_model.summary()

plot_model(final_model, show_shapes=True , dpi=45)
# Out:
# 2025-10-20 09:04:28.893003: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760951069.071076      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760951069.125266      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# I0000 00:00:1760951080.610639      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from sklearn.model_selection import train_test_split


X_train, X_val, y_train, y_val = train_test_split( X_windows, y_windows, test_size=0.2,
                                                   shuffle=False, random_state=42)


callbacks = [
    ModelCheckpoint('best_lstm_model_reg.keras', save_best_only=True, monitor='val_loss',verbose=1),
    EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True,verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=5e-6,verbose=1)
]

history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=500,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/500
# I0000 00:00:1760951100.348109     109 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2448 - mae: 0.2832
# Epoch 1: val_loss improved from inf to 0.11972, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 22s 136ms/step - loss: 0.2438 - mae: 0.2822 - val_loss: 0.1197 - val_mae: 0.1614 - learning_rate: 0.0010
# Epoch 2/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1237 - mae: 0.1727
# Epoch 2: val_loss improved from 0.11972 to 0.09407, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.1235 - mae: 0.1726 - val_loss: 0.0941 - val_mae: 0.1560 - learning_rate: 0.0010
# Epoch 3/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0906 - mae: 0.1457
# Epoch 3: val_loss improved from 0.09407 to 0.07590, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0906 - mae: 0.1457 - val_loss: 0.0759 - val_mae: 0.1418 - learning_rate: 0.0010
# Epoch 4/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0716 - mae: 0.1301
# Epoch 4: val_loss improved from 0.07590 to 0.06604, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0716 - mae: 0.1302 - val_loss: 0.0660 - val_mae: 0.1360 - learning_rate: 0.0010
# Epoch 5/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0598 - mae: 0.1205
# Epoch 5: val_loss improved from 0.06604 to 0.05719, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0598 - mae: 0.1205 - val_loss: 0.0572 - val_mae: 0.1305 - learning_rate: 0.0010
# Epoch 6/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0525 - mae: 0.1163
# Epoch 6: val_loss improved from 0.05719 to 0.05154, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0525 - mae: 0.1163 - val_loss: 0.0515 - val_mae: 0.1231 - learning_rate: 0.0010
# Epoch 7/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0451 - mae: 0.1074
# Epoch 7: val_loss improved from 0.05154 to 0.04901, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0451 - mae: 0.1074 - val_loss: 0.0490 - val_mae: 0.1331 - learning_rate: 0.0010
# Epoch 8/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0414 - mae: 0.1058
# Epoch 8: val_loss improved from 0.04901 to 0.04745, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0413 - mae: 0.1058 - val_loss: 0.0474 - val_mae: 0.1321 - learning_rate: 0.0010
# Epoch 9/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0410 - mae: 0.1117
# Epoch 9: val_loss improved from 0.04745 to 0.04620, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0410 - mae: 0.1117 - val_loss: 0.0462 - val_mae: 0.1317 - learning_rate: 0.0010
# Epoch 10/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0357 - mae: 0.1020
# Epoch 10: val_loss improved from 0.04620 to 0.04217, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0357 - mae: 0.1020 - val_loss: 0.0422 - val_mae: 0.1269 - learning_rate: 0.0010
# Epoch 11/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0334 - mae: 0.1006
# Epoch 11: val_loss improved from 0.04217 to 0.03760, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0334 - mae: 0.1007 - val_loss: 0.0376 - val_mae: 0.1199 - learning_rate: 0.0010
# Epoch 12/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0312 - mae: 0.0981
# Epoch 12: val_loss did not improve from 0.03760
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0312 - mae: 0.0981 - val_loss: 0.0420 - val_mae: 0.1322 - learning_rate: 0.0010
# Epoch 13/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0299 - mae: 0.0973
# Epoch 13: val_loss improved from 0.03760 to 0.03459, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0299 - mae: 0.0973 - val_loss: 0.0346 - val_mae: 0.1187 - learning_rate: 0.0010
# Epoch 14/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0284 - mae: 0.0960
# Epoch 14: val_loss did not improve from 0.03459
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0284 - mae: 0.0960 - val_loss: 0.0354 - val_mae: 0.1227 - learning_rate: 0.0010
# Epoch 15/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0283 - mae: 0.0979
# Epoch 15: val_loss did not improve from 0.03459
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 0.0283 - mae: 0.0979 - val_loss: 0.0372 - val_mae: 0.1311 - learning_rate: 0.0010
# Epoch 16/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0257 - mae: 0.0921
# Epoch 16: val_loss did not improve from 0.03459
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0257 - mae: 0.0920 - val_loss: 0.0386 - val_mae: 0.1309 - learning_rate: 0.0010
# Epoch 17/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0245 - mae: 0.0910
# Epoch 17: val_loss improved from 0.03459 to 0.03109, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0245 - mae: 0.0910 - val_loss: 0.0311 - val_mae: 0.1137 - learning_rate: 0.0010
# Epoch 18/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0242 - mae: 0.0911
# Epoch 18: val_loss did not improve from 0.03109
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0241 - mae: 0.0911 - val_loss: 0.0321 - val_mae: 0.1207 - learning_rate: 0.0010
# Epoch 19/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0233 - mae: 0.0905
# Epoch 19: val_loss did not improve from 0.03109
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0233 - mae: 0.0905 - val_loss: 0.0384 - val_mae: 0.1404 - learning_rate: 0.0010
# Epoch 20/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0252 - mae: 0.0980
# Epoch 20: val_loss did not improve from 0.03109
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 0.0252 - mae: 0.0979 - val_loss: 0.0330 - val_mae: 0.1244 - learning_rate: 0.0010
# Epoch 21/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0216 - mae: 0.0875
# Epoch 21: val_loss did not improve from 0.03109
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0216 - mae: 0.0875 - val_loss: 0.0348 - val_mae: 0.1286 - learning_rate: 0.0010
# Epoch 22/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0213 - mae: 0.0875
# Epoch 22: val_loss improved from 0.03109 to 0.03109, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0213 - mae: 0.0875 - val_loss: 0.0311 - val_mae: 0.1219 - learning_rate: 0.0010
# Epoch 23/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0206 - mae: 0.0862
# Epoch 23: val_loss improved from 0.03109 to 0.03022, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0206 - mae: 0.0862 - val_loss: 0.0302 - val_mae: 0.1188 - learning_rate: 0.0010
# Epoch 24/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0202 - mae: 0.0858
# Epoch 24: val_loss did not improve from 0.03022
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0202 - mae: 0.0858 - val_loss: 0.0316 - val_mae: 0.1235 - learning_rate: 0.0010
# Epoch 25/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0196 - mae: 0.0851
# Epoch 25: val_loss did not improve from 0.03022
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0196 - mae: 0.0851 - val_loss: 0.0320 - val_mae: 0.1271 - learning_rate: 0.0010
# Epoch 26/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0192 - mae: 0.0841
# Epoch 26: val_loss did not improve from 0.03022
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 0.0192 - mae: 0.0841 - val_loss: 0.0333 - val_mae: 0.1276 - learning_rate: 0.0010
# Epoch 27/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0183 - mae: 0.0822
# Epoch 27: val_loss improved from 0.03022 to 0.02720, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0183 - mae: 0.0822 - val_loss: 0.0272 - val_mae: 0.1119 - learning_rate: 0.0010
# Epoch 28/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0184 - mae: 0.0824
# Epoch 28: val_loss did not improve from 0.02720
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0184 - mae: 0.0824 - val_loss: 0.0320 - val_mae: 0.1259 - learning_rate: 0.0010
# Epoch 29/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0181 - mae: 0.0836
# Epoch 29: val_loss did not improve from 0.02720
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0181 - mae: 0.0836 - val_loss: 0.0341 - val_mae: 0.1346 - learning_rate: 0.0010
# Epoch 30/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0180 - mae: 0.0824
# Epoch 30: val_loss did not improve from 0.02720
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0180 - mae: 0.0824 - val_loss: 0.0284 - val_mae: 0.1179 - learning_rate: 0.0010
# Epoch 31/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0180 - mae: 0.0830
# Epoch 31: val_loss did not improve from 0.02720
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0180 - mae: 0.0830 - val_loss: 0.0321 - val_mae: 0.1326 - learning_rate: 0.0010
# Epoch 32/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0180 - mae: 0.0843
# Epoch 32: val_loss did not improve from 0.02720
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0180 - mae: 0.0843 - val_loss: 0.0321 - val_mae: 0.1316 - learning_rate: 0.0010
# Epoch 33/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0170 - mae: 0.0816
# Epoch 33: val_loss improved from 0.02720 to 0.02680, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0170 - mae: 0.0816 - val_loss: 0.0268 - val_mae: 0.1128 - learning_rate: 0.0010
# Epoch 34/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0170 - mae: 0.0818
# Epoch 34: val_loss did not improve from 0.02680
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0170 - mae: 0.0818 - val_loss: 0.0289 - val_mae: 0.1199 - learning_rate: 0.0010
# Epoch 35/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0166 - mae: 0.0808
# Epoch 35: val_loss improved from 0.02680 to 0.02569, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0166 - mae: 0.0807 - val_loss: 0.0257 - val_mae: 0.1139 - learning_rate: 0.0010
# Epoch 36/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0158 - mae: 0.0782
# Epoch 36: val_loss did not improve from 0.02569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0158 - mae: 0.0782 - val_loss: 0.0268 - val_mae: 0.1123 - learning_rate: 0.0010
# Epoch 37/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0174 - mae: 0.0854
# Epoch 37: val_loss did not improve from 0.02569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0174 - mae: 0.0854 - val_loss: 0.0271 - val_mae: 0.1182 - learning_rate: 0.0010
# Epoch 38/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0159 - mae: 0.0786
# Epoch 38: val_loss did not improve from 0.02569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0159 - mae: 0.0786 - val_loss: 0.0293 - val_mae: 0.1248 - learning_rate: 0.0010
# Epoch 39/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0154 - mae: 0.0768
# Epoch 39: val_loss did not improve from 0.02569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0154 - mae: 0.0768 - val_loss: 0.0297 - val_mae: 0.1249 - learning_rate: 0.0010
# Epoch 40/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0152 - mae: 0.0777
# Epoch 40: val_loss did not improve from 0.02569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0152 - mae: 0.0777 - val_loss: 0.0289 - val_mae: 0.1207 - learning_rate: 0.0010
# Epoch 41/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0150 - mae: 0.0769
# Epoch 41: val_loss did not improve from 0.02569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0150 - mae: 0.0769 - val_loss: 0.0266 - val_mae: 0.1135 - learning_rate: 0.0010
# Epoch 42/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0151 - mae: 0.0777
# Epoch 42: val_loss did not improve from 0.02569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0151 - mae: 0.0777 - val_loss: 0.0334 - val_mae: 0.1358 - learning_rate: 0.0010
# Epoch 43/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0168 - mae: 0.0840
# Epoch 43: val_loss did not improve from 0.02569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0168 - mae: 0.0839 - val_loss: 0.0258 - val_mae: 0.1175 - learning_rate: 0.0010
# Epoch 44/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0152 - mae: 0.0780
# Epoch 44: val_loss did not improve from 0.02569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0152 - mae: 0.0780 - val_loss: 0.0276 - val_mae: 0.1187 - learning_rate: 0.0010
# Epoch 45/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0142 - mae: 0.0752
# Epoch 45: val_loss did not improve from 0.02569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0142 - mae: 0.0752 - val_loss: 0.0295 - val_mae: 0.1258 - learning_rate: 0.0010
# Epoch 46/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0149 - mae: 0.0774
# Epoch 46: val_loss did not improve from 0.02569
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0148 - mae: 0.0773 - val_loss: 0.0273 - val_mae: 0.1166 - learning_rate: 0.0010
# Epoch 47/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0141 - mae: 0.0757
# Epoch 47: val_loss improved from 0.02569 to 0.02066, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0141 - mae: 0.0757 - val_loss: 0.0207 - val_mae: 0.0993 - learning_rate: 0.0010
# Epoch 48/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0145 - mae: 0.0770
# Epoch 48: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0145 - mae: 0.0770 - val_loss: 0.0256 - val_mae: 0.1119 - learning_rate: 0.0010
# Epoch 49/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0155 - mae: 0.0812
# Epoch 49: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0155 - mae: 0.0812 - val_loss: 0.0265 - val_mae: 0.1141 - learning_rate: 0.0010
# Epoch 50/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0142 - mae: 0.0761
# Epoch 50: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0142 - mae: 0.0761 - val_loss: 0.0261 - val_mae: 0.1183 - learning_rate: 0.0010
# Epoch 51/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0144 - mae: 0.0770
# Epoch 51: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0144 - mae: 0.0770 - val_loss: 0.0301 - val_mae: 0.1242 - learning_rate: 0.0010
# Epoch 52/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0140 - mae: 0.0754
# Epoch 52: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0140 - mae: 0.0754 - val_loss: 0.0319 - val_mae: 0.1267 - learning_rate: 0.0010
# Epoch 53/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0147 - mae: 0.0785
# Epoch 53: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0147 - mae: 0.0786 - val_loss: 0.0248 - val_mae: 0.1133 - learning_rate: 0.0010
# Epoch 54/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0148 - mae: 0.0781
# Epoch 54: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 0.0148 - mae: 0.0781 - val_loss: 0.0260 - val_mae: 0.1185 - learning_rate: 0.0010
# Epoch 55/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0135 - mae: 0.0741
# Epoch 55: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0135 - mae: 0.0741 - val_loss: 0.0275 - val_mae: 0.1211 - learning_rate: 0.0010
# Epoch 56/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0132 - mae: 0.0727
# Epoch 56: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0132 - mae: 0.0727 - val_loss: 0.0274 - val_mae: 0.1203 - learning_rate: 0.0010
# Epoch 57/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0129 - mae: 0.0724
# Epoch 57: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0129 - mae: 0.0724 - val_loss: 0.0274 - val_mae: 0.1243 - learning_rate: 0.0010
# Epoch 58/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0136 - mae: 0.0749
# Epoch 58: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0136 - mae: 0.0749 - val_loss: 0.0274 - val_mae: 0.1227 - learning_rate: 0.0010
# Epoch 59/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0133 - mae: 0.0736
# Epoch 59: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0133 - mae: 0.0736 - val_loss: 0.0293 - val_mae: 0.1269 - learning_rate: 0.0010
# Epoch 60/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0134 - mae: 0.0742
# Epoch 60: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0134 - mae: 0.0742 - val_loss: 0.0308 - val_mae: 0.1322 - learning_rate: 0.0010
# Epoch 61/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0125 - mae: 0.0710
# Epoch 61: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0125 - mae: 0.0710 - val_loss: 0.0257 - val_mae: 0.1149 - learning_rate: 0.0010
# Epoch 62/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0127 - mae: 0.0723
# Epoch 62: val_loss did not improve from 0.02066
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0127 - mae: 0.0723 - val_loss: 0.0276 - val_mae: 0.1232 - learning_rate: 0.0010
# Epoch 63/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0122 - mae: 0.0705
# Epoch 63: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0122 - mae: 0.0705 - val_loss: 0.0258 - val_mae: 0.1199 - learning_rate: 5.0000e-04
# Epoch 64/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0112 - mae: 0.0668
# Epoch 64: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0112 - mae: 0.0667 - val_loss: 0.0269 - val_mae: 0.1245 - learning_rate: 5.0000e-04
# Epoch 65/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0108 - mae: 0.0647
# Epoch 65: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0108 - mae: 0.0647 - val_loss: 0.0227 - val_mae: 0.1105 - learning_rate: 5.0000e-04
# Epoch 66/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0108 - mae: 0.0648
# Epoch 66: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0108 - mae: 0.0648 - val_loss: 0.0247 - val_mae: 0.1145 - learning_rate: 5.0000e-04
# Epoch 67/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0106 - mae: 0.0650
# Epoch 67: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0106 - mae: 0.0650 - val_loss: 0.0267 - val_mae: 0.1265 - learning_rate: 5.0000e-04
# Epoch 68/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0107 - mae: 0.0654
# Epoch 68: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0107 - mae: 0.0654 - val_loss: 0.0233 - val_mae: 0.1130 - learning_rate: 5.0000e-04
# Epoch 69/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0107 - mae: 0.0654
# Epoch 69: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0107 - mae: 0.0654 - val_loss: 0.0232 - val_mae: 0.1129 - learning_rate: 5.0000e-04
# Epoch 70/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0108 - mae: 0.0658
# Epoch 70: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0108 - mae: 0.0658 - val_loss: 0.0263 - val_mae: 0.1198 - learning_rate: 5.0000e-04
# Epoch 71/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0104 - mae: 0.0641
# Epoch 71: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0104 - mae: 0.0641 - val_loss: 0.0265 - val_mae: 0.1217 - learning_rate: 5.0000e-04
# Epoch 72/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0103 - mae: 0.0643
# Epoch 72: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0103 - mae: 0.0643 - val_loss: 0.0261 - val_mae: 0.1219 - learning_rate: 5.0000e-04
# Epoch 73/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0109 - mae: 0.0668
# Epoch 73: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0109 - mae: 0.0668 - val_loss: 0.0251 - val_mae: 0.1165 - learning_rate: 5.0000e-04
# Epoch 74/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0106 - mae: 0.0656
# Epoch 74: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0106 - mae: 0.0655 - val_loss: 0.0254 - val_mae: 0.1196 - learning_rate: 5.0000e-04
# Epoch 75/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0103 - mae: 0.0641
# Epoch 75: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0103 - mae: 0.0641 - val_loss: 0.0260 - val_mae: 0.1219 - learning_rate: 5.0000e-04
# Epoch 76/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0107 - mae: 0.0668
# Epoch 76: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0107 - mae: 0.0668 - val_loss: 0.0261 - val_mae: 0.1191 - learning_rate: 5.0000e-04
# Epoch 77/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0104 - mae: 0.0655
# Epoch 77: val_loss did not improve from 0.02066
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0104 - mae: 0.0655 - val_loss: 0.0266 - val_mae: 0.1258 - learning_rate: 5.0000e-04
# Epoch 78/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0102 - mae: 0.0642
# Epoch 78: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0102 - mae: 0.0642 - val_loss: 0.0276 - val_mae: 0.1259 - learning_rate: 2.5000e-04
# Epoch 79/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0096 - mae: 0.0617
# Epoch 79: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0096 - mae: 0.0617 - val_loss: 0.0241 - val_mae: 0.1131 - learning_rate: 2.5000e-04
# Epoch 80/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0094 - mae: 0.0611
# Epoch 80: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 0.0094 - mae: 0.0611 - val_loss: 0.0261 - val_mae: 0.1206 - learning_rate: 2.5000e-04
# Epoch 81/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0092 - mae: 0.0602
# Epoch 81: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 0.0092 - mae: 0.0602 - val_loss: 0.0240 - val_mae: 0.1138 - learning_rate: 2.5000e-04
# Epoch 82/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0090 - mae: 0.0592
# Epoch 82: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 0.0090 - mae: 0.0593 - val_loss: 0.0230 - val_mae: 0.1120 - learning_rate: 2.5000e-04
# Epoch 83/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0091 - mae: 0.0595
# Epoch 83: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0091 - mae: 0.0595 - val_loss: 0.0247 - val_mae: 0.1168 - learning_rate: 2.5000e-04
# Epoch 84/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0090 - mae: 0.0591
# Epoch 84: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0090 - mae: 0.0591 - val_loss: 0.0260 - val_mae: 0.1226 - learning_rate: 2.5000e-04
# Epoch 85/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0092 - mae: 0.0605
# Epoch 85: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0092 - mae: 0.0605 - val_loss: 0.0221 - val_mae: 0.1089 - learning_rate: 2.5000e-04
# Epoch 86/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0090 - mae: 0.0597
# Epoch 86: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0090 - mae: 0.0597 - val_loss: 0.0265 - val_mae: 0.1241 - learning_rate: 2.5000e-04
# Epoch 87/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0088 - mae: 0.0587
# Epoch 87: val_loss did not improve from 0.02066
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0088 - mae: 0.0587 - val_loss: 0.0306 - val_mae: 0.1321 - learning_rate: 2.5000e-04
# Epoch 87: early stopping
# Restoring model weights from the end of the best epoch: 47.

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import  mean_absolute_error

# model  = load_model("/kaggle/input/m/tensorflow2/default/1/best_lstm_model_reg.keras")
# پیش‌بینی روی داده تست-
y_pred_scaled = final_model.predict(X_windows_test)  # (N, 1)

# برگرداندن به مقیاس اصلی
y_pred_original = y_scaler.inverse_transform(y_pred_scaled)
y_true_original = y_scaler.inverse_transform(y_windows_test)




mae = mean_absolute_error(y_true_original, y_pred_original)
mae2 = mean_absolute_error(y_windows_test, y_pred_scaled)

print(f"Test MAE(scaled): {mae2:.3f}")
print(f"Test MAE(true value): {mae:.3f}")
# Out:
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step
# Test MAE(scaled): 0.172
# Test MAE(true value): 3.578

# %%
import matplotlib.pyplot as plt

# Set font sizes and styles for publication
plt.rcParams.update({
    'font.size': 14,
    'axes.labelsize': 16,
    'axes.titlesize': 18,
    'legend.fontsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'font.family': 'serif',  # Optional: use serif font (common in papers)
    'figure.figsize': (8, 5)
})

# Plot training & validation loss
plt.plot(history.history["loss"], label="Training Loss", linewidth=2.5, color='tab:blue')
plt.plot(history.history["val_loss"], label="Validation Loss", linewidth=2.5, color='tab:red')

# Add title and axis labels
plt.title("Model Training Progress", fontsize=18, pad=20)
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")

# Improve layout and add grid
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.legend(frameon=True, loc='upper right', shadow=False, edgecolor='black')

# Use tight layout to prevent clipping
plt.tight_layout()

# Save high-resolution figure for your article
plt.savefig("training_validation_loss.pdf", format='pdf', dpi=300, bbox_inches='tight')
plt.savefig("training_validation_loss.png", format='png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import pickle

with open('training_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
y_true_original.shape
# Out:
# (16793, 100)

# %%
y_pred_original.shape
# Out:
# (16793, 100)

# %%
# time = np.arange(1, y_true_original.shape[0]+1) * 0.01
# time = time.reshape(-1, 1)

plt.figure(figsize=(15,10))
plt.plot(y_true_original[222,:])
plt.plot(y_pred_original[222,:])
plt.grid()
