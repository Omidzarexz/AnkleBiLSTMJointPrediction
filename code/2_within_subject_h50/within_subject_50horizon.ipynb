# %%
# !git clone https://github.com/Omidzarexz/AnkleBiLSTMJointPrediction
# Out:
# fatal: destination path 'AnkleBiLSTMJointPrediction' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt


# df_clean_train_12feature_cross_subject = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_train_12feature_cross_subject.csv")
# df_clean_test_12feature_cross_subject  = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_test_12feature_cross_subject.csv")


# df_clean_train_16feature_cross_subject = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_train_16feature_cross_subject.csv")
# df_clean_test_16feature_cross_subject  = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_test_16feature_cross_subject.csv")


df_clean_train_16feature_within_subject = pd.read_csv("/content/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_train_16feature_within_subject_txt25.csv")
df_clean_test_16feature_within_subject  = pd.read_csv("/content/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_test_16feature_within_subject_txt25.csv")

df_clean_train = df_clean_train_16feature_within_subject
df_clean_test  = df_clean_test_16feature_within_subject

# %%
from scipy.signal import butter, filtfilt

def low_pass_butter(signal, cutoff=10, fs=100, order=2):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return filtfilt(b, a, signal)
feature_columns = [
    'MPU1_Acc_X', 'MPU1_Acc_Y', 'MPU1_Acc_Z',
    'MPU1_Gyro_X', 'MPU1_Gyro_Y', 'MPU1_Gyro_Z',
    'MPU1_Roll','MPU1_Pitch',
    'MPU2_Acc_X', 'MPU2_Acc_Y', 'MPU2_Acc_Z',
    'MPU2_Gyro_X', 'MPU2_Gyro_Y', 'MPU2_Gyro_Z',
    'MPU2_Roll','MPU2_Pitch'
]




df_filtered_trainig = pd.DataFrame()
df_filtered_test    = pd.DataFrame()
for col in feature_columns:
    df_filtered_trainig[col] = low_pass_butter( df_clean_train[col].values
                                        , cutoff=5 # Hz
                                        , fs=100  # Hz
                                        , order=2  )
    df_filtered_test[col] = low_pass_butter( df_clean_test[col].values
                                        , cutoff=5 # Hz
                                        , fs=100  # Hz
                                        , order=2  )







print("\ndf_filtered_trainig shape:",df_filtered_trainig.shape)
print("\ndf_filtered_test shape:",df_filtered_test.shape)
# Out:
# df_filtered_trainig shape: (16500, 16)
#
# df_filtered_test shape: (992, 16)

# %%
from sklearn.preprocessing import  MinMaxScaler


scaler = MinMaxScaler(feature_range=(-1, 1))
X_data_train = scaler.fit_transform(df_filtered_trainig[feature_columns].values)  # (T, 12)


y_scaler = MinMaxScaler(feature_range=(-1, 1))
y_data_train = y_scaler.fit_transform(df_clean_train['angle'].values.reshape(-1, 1))





X_data_test = scaler.transform(df_filtered_test[feature_columns].values)

y_data_test = y_scaler.transform(df_clean_test["angle"].values.reshape(-1,1))


# تنظیمات پنجره
window_size = 200   #
horizon = 50        #
step_size = 20      #

# تابع پنجره‌بندی
def create_windows_with_labels(X, y, window_size, horizon, step_size):
    X_windows = []
    y_windows = []
    for i in range(0,  len(X) - window_size - horizon + 1, step_size):
        X_windows.append(X[i:i + window_size])
        y_windows.append(y[i + window_size : i + window_size + horizon])  # برچسب آخرین نمونه در پنجره
    return np.array(X_windows), np.array(y_windows)

# ایجاد پنجره‌ها
X_windows, y_windows = create_windows_with_labels(X_data_train, y_data_train,
                                                  window_size, horizon, step_size)
if horizon==1:
    y_windows = y_windows.reshape(-1,1)
else:
    y_windows = np.squeeze(y_windows, axis=2)





print(f"✅   (X_windows):(samples, time steps, features) → {X_windows.shape}")
print(f"✅  (y_windows): {y_windows.shape}")

step_size_for_test = 1
X_windows_test, y_windows_test = create_windows_with_labels(X_data_test, y_data_test,
                                                            window_size, horizon, step_size_for_test)

if horizon==1:
    y_windows_test = y_windows_test.reshape(-1,1)
else:
    y_windows_test = np.squeeze(y_windows_test, axis=2)

print(f"\n✅   (X_windows_test):(samples, time steps, features) → {X_windows_test.shape}")
print(f"✅  (y_windows_test): {y_windows_test.shape}")
# Out:
# ✅   (X_windows):(samples, time steps, features) → (813, 200, 16)
# ✅  (y_windows): (813, 50)
#
# ✅   (X_windows_test):(samples, time steps, features) → (743, 200, 16)
# ✅  (y_windows_test): (743, 50)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from keras.layers import Bidirectional

from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, GlobalAveragePooling1D
from tensorflow.keras.layers import Input, Dense, GRU, Bidirectional, Dropout, ReLU, TimeDistributed, LayerNormalization
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l2

LEARNING_RATE = 0.001
lambda_loss_amount = 0.0005



def build_bi_lstm_model(input_shape, horizon=1, lambda_loss_amount=1e-4, learning_rate=1e-3):
    inputs = Input(shape=input_shape, name="input")

    # Dense projection per timestep
    x = TimeDistributed(Dense(128, kernel_regularizer=l2(lambda_loss_amount)))(inputs)
    x = ReLU()(x)

    # Stacked BiGRU layers
    x = Bidirectional(LSTM(128, return_sequences=True,
                           kernel_regularizer=l2(lambda_loss_amount)))(x)
    x = LayerNormalization()(x)
    x = Dropout(0.3)(x)


    x = Bidirectional(LSTM(128, return_sequences=False,
                           kernel_regularizer=l2(lambda_loss_amount)))(x)
    x = Dropout(0.3)(x)



    # Output
    outputs = Dense(horizon, activation='linear')(x)

    # Model compile
    model = Model(inputs=inputs, outputs=outputs, name="BiLSTM_reg")
    model.compile(optimizer=optimizers.Adam(learning_rate=learning_rate),
                  loss='mse',
                  metrics=['mae'])
    return model

final_model = build_bi_lstm_model(input_shape=(X_windows.shape[1],X_windows.shape[2]),horizon=horizon)

# final_model.summary()

plot_model(final_model, show_shapes=True , dpi=80)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from sklearn.model_selection import train_test_split


X_train, X_val, y_train, y_val = train_test_split( X_windows, y_windows, test_size=0.2,
                                                   shuffle=False, random_state=42)


callbacks = [
    ModelCheckpoint('best_lstm_model_reg.keras', save_best_only=True, monitor='val_loss',verbose=1),
    EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True,verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=5e-6,verbose=1)
]

history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=500,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.3987 - mae: 0.4268
# Epoch 1: val_loss improved from inf to 0.20027, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 317ms/step - loss: 0.3932 - mae: 0.4223 - val_loss: 0.2003 - val_mae: 0.2395 - learning_rate: 0.0010
# Epoch 2/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2231 - mae: 0.2703
# Epoch 2: val_loss improved from 0.20027 to 0.16562, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.2214 - mae: 0.2684 - val_loss: 0.1656 - val_mae: 0.1938 - learning_rate: 0.0010
# Epoch 3/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1842 - mae: 0.2259
# Epoch 3: val_loss improved from 0.16562 to 0.14884, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.1836 - mae: 0.2253 - val_loss: 0.1488 - val_mae: 0.1743 - learning_rate: 0.0010
# Epoch 4/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1663 - mae: 0.2081
# Epoch 4: val_loss improved from 0.14884 to 0.13041, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1656 - mae: 0.2073 - val_loss: 0.1304 - val_mae: 0.1480 - learning_rate: 0.0010
# Epoch 5/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1516 - mae: 0.1934
# Epoch 5: val_loss improved from 0.13041 to 0.12026, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.1512 - mae: 0.1932 - val_loss: 0.1203 - val_mae: 0.1385 - learning_rate: 0.0010
# Epoch 6/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1375 - mae: 0.1785
# Epoch 6: val_loss improved from 0.12026 to 0.11077, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.1371 - mae: 0.1783 - val_loss: 0.1108 - val_mae: 0.1313 - learning_rate: 0.0010
# Epoch 7/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1295 - mae: 0.1738
# Epoch 7: val_loss improved from 0.11077 to 0.10915, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.1290 - mae: 0.1732 - val_loss: 0.1091 - val_mae: 0.1344 - learning_rate: 0.0010
# Epoch 8/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1201 - mae: 0.1664
# Epoch 8: val_loss improved from 0.10915 to 0.10235, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.1198 - mae: 0.1660 - val_loss: 0.1023 - val_mae: 0.1263 - learning_rate: 0.0010
# Epoch 9/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1147 - mae: 0.1628
# Epoch 9: val_loss improved from 0.10235 to 0.09019, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.1144 - mae: 0.1624 - val_loss: 0.0902 - val_mae: 0.1082 - learning_rate: 0.0010
# Epoch 10/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1061 - mae: 0.1545
# Epoch 10: val_loss did not improve from 0.09019
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.1058 - mae: 0.1542 - val_loss: 0.0934 - val_mae: 0.1215 - learning_rate: 0.0010
# Epoch 11/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1008 - mae: 0.1499
# Epoch 11: val_loss did not improve from 0.09019
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.1008 - mae: 0.1500 - val_loss: 0.0953 - val_mae: 0.1315 - learning_rate: 0.0010
# Epoch 12/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0970 - mae: 0.1486
# Epoch 12: val_loss improved from 0.09019 to 0.08336, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0970 - mae: 0.1487 - val_loss: 0.0834 - val_mae: 0.1181 - learning_rate: 0.0010
# Epoch 13/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0917 - mae: 0.1447
# Epoch 13: val_loss improved from 0.08336 to 0.08210, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0916 - mae: 0.1446 - val_loss: 0.0821 - val_mae: 0.1165 - learning_rate: 0.0010
# Epoch 14/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0883 - mae: 0.1416
# Epoch 14: val_loss improved from 0.08210 to 0.07696, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0882 - mae: 0.1417 - val_loss: 0.0770 - val_mae: 0.1115 - learning_rate: 0.0010
# Epoch 15/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0841 - mae: 0.1383
# Epoch 15: val_loss improved from 0.07696 to 0.07203, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0842 - mae: 0.1386 - val_loss: 0.0720 - val_mae: 0.1049 - learning_rate: 0.0010
# Epoch 16/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0836 - mae: 0.1409
# Epoch 16: val_loss did not improve from 0.07203
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0836 - mae: 0.1410 - val_loss: 0.0733 - val_mae: 0.1107 - learning_rate: 0.0010
# Epoch 17/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0777 - mae: 0.1331
# Epoch 17: val_loss did not improve from 0.07203
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0779 - mae: 0.1337 - val_loss: 0.0741 - val_mae: 0.1181 - learning_rate: 0.0010
# Epoch 18/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0750 - mae: 0.1322
# Epoch 18: val_loss improved from 0.07203 to 0.06774, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0749 - mae: 0.1321 - val_loss: 0.0677 - val_mae: 0.1061 - learning_rate: 0.0010
# Epoch 19/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0721 - mae: 0.1292
# Epoch 19: val_loss did not improve from 0.06774
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0720 - mae: 0.1291 - val_loss: 0.0692 - val_mae: 0.1158 - learning_rate: 0.0010
# Epoch 20/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0701 - mae: 0.1281
# Epoch 20: val_loss improved from 0.06774 to 0.06562, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0701 - mae: 0.1281 - val_loss: 0.0656 - val_mae: 0.1132 - learning_rate: 0.0010
# Epoch 21/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0672 - mae: 0.1264
# Epoch 21: val_loss improved from 0.06562 to 0.06340, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0672 - mae: 0.1263 - val_loss: 0.0634 - val_mae: 0.1088 - learning_rate: 0.0010
# Epoch 22/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0647 - mae: 0.1230
# Epoch 22: val_loss did not improve from 0.06340
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0647 - mae: 0.1231 - val_loss: 0.0675 - val_mae: 0.1168 - learning_rate: 0.0010
# Epoch 23/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0647 - mae: 0.1255
# Epoch 23: val_loss improved from 0.06340 to 0.05727, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0647 - mae: 0.1256 - val_loss: 0.0573 - val_mae: 0.0986 - learning_rate: 0.0010
# Epoch 24/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0633 - mae: 0.1257
# Epoch 24: val_loss did not improve from 0.05727
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0633 - mae: 0.1258 - val_loss: 0.0605 - val_mae: 0.1116 - learning_rate: 0.0010
# Epoch 25/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0623 - mae: 0.1256
# Epoch 25: val_loss did not improve from 0.05727
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0622 - mae: 0.1254 - val_loss: 0.0586 - val_mae: 0.1131 - learning_rate: 0.0010
# Epoch 26/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0610 - mae: 0.1252
# Epoch 26: val_loss improved from 0.05727 to 0.05455, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0611 - mae: 0.1253 - val_loss: 0.0545 - val_mae: 0.1022 - learning_rate: 0.0010
# Epoch 27/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0620 - mae: 0.1294
# Epoch 27: val_loss did not improve from 0.05455
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0620 - mae: 0.1295 - val_loss: 0.0578 - val_mae: 0.1110 - learning_rate: 0.0010
# Epoch 28/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0589 - mae: 0.1252
# Epoch 28: val_loss did not improve from 0.05455
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0589 - mae: 0.1251 - val_loss: 0.0624 - val_mae: 0.1201 - learning_rate: 0.0010
# Epoch 29/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0578 - mae: 0.1254
# Epoch 29: val_loss did not improve from 0.05455
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0577 - mae: 0.1252 - val_loss: 0.0559 - val_mae: 0.1131 - learning_rate: 0.0010
# Epoch 30/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0553 - mae: 0.1219
# Epoch 30: val_loss improved from 0.05455 to 0.05136, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0552 - mae: 0.1217 - val_loss: 0.0514 - val_mae: 0.1038 - learning_rate: 0.0010
# Epoch 31/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0515 - mae: 0.1148
# Epoch 31: val_loss improved from 0.05136 to 0.05128, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0516 - mae: 0.1151 - val_loss: 0.0513 - val_mae: 0.1029 - learning_rate: 0.0010
# Epoch 32/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0506 - mae: 0.1140
# Epoch 32: val_loss improved from 0.05128 to 0.04891, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0506 - mae: 0.1141 - val_loss: 0.0489 - val_mae: 0.0973 - learning_rate: 0.0010
# Epoch 33/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0497 - mae: 0.1131
# Epoch 33: val_loss did not improve from 0.04891
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0497 - mae: 0.1133 - val_loss: 0.0527 - val_mae: 0.1092 - learning_rate: 0.0010
# Epoch 34/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0485 - mae: 0.1121
# Epoch 34: val_loss improved from 0.04891 to 0.04476, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0485 - mae: 0.1121 - val_loss: 0.0448 - val_mae: 0.0928 - learning_rate: 0.0010
# Epoch 35/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0475 - mae: 0.1116
# Epoch 35: val_loss did not improve from 0.04476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0476 - mae: 0.1117 - val_loss: 0.0487 - val_mae: 0.1074 - learning_rate: 0.0010
# Epoch 36/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0466 - mae: 0.1114
# Epoch 36: val_loss improved from 0.04476 to 0.04473, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0466 - mae: 0.1114 - val_loss: 0.0447 - val_mae: 0.0979 - learning_rate: 0.0010
# Epoch 37/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0446 - mae: 0.1074
# Epoch 37: val_loss did not improve from 0.04473
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0446 - mae: 0.1074 - val_loss: 0.0471 - val_mae: 0.1043 - learning_rate: 0.0010
# Epoch 38/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0450 - mae: 0.1112
# Epoch 38: val_loss did not improve from 0.04473
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0450 - mae: 0.1110 - val_loss: 0.0459 - val_mae: 0.1044 - learning_rate: 0.0010
# Epoch 39/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0446 - mae: 0.1107
# Epoch 39: val_loss improved from 0.04473 to 0.04287, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0445 - mae: 0.1105 - val_loss: 0.0429 - val_mae: 0.0971 - learning_rate: 0.0010
# Epoch 40/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0432 - mae: 0.1076
# Epoch 40: val_loss did not improve from 0.04287
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0434 - mae: 0.1081 - val_loss: 0.0434 - val_mae: 0.0955 - learning_rate: 0.0010
# Epoch 41/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0445 - mae: 0.1118
# Epoch 41: val_loss improved from 0.04287 to 0.04233, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0445 - mae: 0.1118 - val_loss: 0.0423 - val_mae: 0.0971 - learning_rate: 0.0010
# Epoch 42/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0423 - mae: 0.1085
# Epoch 42: val_loss did not improve from 0.04233
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0423 - mae: 0.1086 - val_loss: 0.0485 - val_mae: 0.1116 - learning_rate: 0.0010
# Epoch 43/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0418 - mae: 0.1087
# Epoch 43: val_loss did not improve from 0.04233
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0418 - mae: 0.1088 - val_loss: 0.0476 - val_mae: 0.1087 - learning_rate: 0.0010
# Epoch 44/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0414 - mae: 0.1089
# Epoch 44: val_loss improved from 0.04233 to 0.03961, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0412 - mae: 0.1086 - val_loss: 0.0396 - val_mae: 0.0953 - learning_rate: 0.0010
# Epoch 45/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0393 - mae: 0.1052
# Epoch 45: val_loss did not improve from 0.03961
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0393 - mae: 0.1052 - val_loss: 0.0417 - val_mae: 0.0998 - learning_rate: 0.0010
# Epoch 46/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0395 - mae: 0.1069
# Epoch 46: val_loss did not improve from 0.03961
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0396 - mae: 0.1070 - val_loss: 0.0421 - val_mae: 0.1041 - learning_rate: 0.0010
# Epoch 47/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0394 - mae: 0.1077
# Epoch 47: val_loss did not improve from 0.03961
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0394 - mae: 0.1077 - val_loss: 0.0416 - val_mae: 0.1057 - learning_rate: 0.0010
# Epoch 48/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0378 - mae: 0.1051
# Epoch 48: val_loss did not improve from 0.03961
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0379 - mae: 0.1056 - val_loss: 0.0397 - val_mae: 0.1003 - learning_rate: 0.0010
# Epoch 49/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0386 - mae: 0.1072
# Epoch 49: val_loss did not improve from 0.03961
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0386 - mae: 0.1072 - val_loss: 0.0407 - val_mae: 0.1031 - learning_rate: 0.0010
# Epoch 50/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0375 - mae: 0.1063
# Epoch 50: val_loss improved from 0.03961 to 0.03921, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0375 - mae: 0.1061 - val_loss: 0.0392 - val_mae: 0.1003 - learning_rate: 0.0010
# Epoch 51/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0358 - mae: 0.1021
# Epoch 51: val_loss did not improve from 0.03921
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0359 - mae: 0.1025 - val_loss: 0.0396 - val_mae: 0.1004 - learning_rate: 0.0010
# Epoch 52/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0347 - mae: 0.0999
# Epoch 52: val_loss did not improve from 0.03921
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0348 - mae: 0.1001 - val_loss: 0.0432 - val_mae: 0.1084 - learning_rate: 0.0010
# Epoch 53/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0340 - mae: 0.0998
# Epoch 53: val_loss improved from 0.03921 to 0.03721, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0341 - mae: 0.0998 - val_loss: 0.0372 - val_mae: 0.0965 - learning_rate: 0.0010
# Epoch 54/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0345 - mae: 0.1014
# Epoch 54: val_loss did not improve from 0.03721
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0347 - mae: 0.1017 - val_loss: 0.0411 - val_mae: 0.1042 - learning_rate: 0.0010
# Epoch 55/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0344 - mae: 0.1011
# Epoch 55: val_loss did not improve from 0.03721
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0343 - mae: 0.1009 - val_loss: 0.0414 - val_mae: 0.1056 - learning_rate: 0.0010
# Epoch 56/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0363 - mae: 0.1078
# Epoch 56: val_loss improved from 0.03721 to 0.03571, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0364 - mae: 0.1081 - val_loss: 0.0357 - val_mae: 0.1010 - learning_rate: 0.0010
# Epoch 57/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0407 - mae: 0.1163
# Epoch 57: val_loss did not improve from 0.03571
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0407 - mae: 0.1163 - val_loss: 0.0373 - val_mae: 0.1012 - learning_rate: 0.0010
# Epoch 58/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0388 - mae: 0.1132
# Epoch 58: val_loss did not improve from 0.03571
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0388 - mae: 0.1132 - val_loss: 0.0379 - val_mae: 0.1029 - learning_rate: 0.0010
# Epoch 59/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0369 - mae: 0.1107
# Epoch 59: val_loss did not improve from 0.03571
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0368 - mae: 0.1106 - val_loss: 0.0383 - val_mae: 0.1052 - learning_rate: 0.0010
# Epoch 60/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0353 - mae: 0.1070
# Epoch 60: val_loss did not improve from 0.03571
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0354 - mae: 0.1073 - val_loss: 0.0420 - val_mae: 0.1132 - learning_rate: 0.0010
# Epoch 61/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0324 - mae: 0.1002
# Epoch 61: val_loss did not improve from 0.03571
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0325 - mae: 0.1004 - val_loss: 0.0385 - val_mae: 0.1066 - learning_rate: 0.0010
# Epoch 62/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0333 - mae: 0.1039
# Epoch 62: val_loss did not improve from 0.03571
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0332 - mae: 0.1037 - val_loss: 0.0365 - val_mae: 0.1004 - learning_rate: 0.0010
# Epoch 63/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0324 - mae: 0.1019
# Epoch 63: val_loss did not improve from 0.03571
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0324 - mae: 0.1019 - val_loss: 0.0377 - val_mae: 0.1055 - learning_rate: 0.0010
# Epoch 64/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0322 - mae: 0.1009
# Epoch 64: val_loss did not improve from 0.03571
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0322 - mae: 0.1008 - val_loss: 0.0363 - val_mae: 0.0989 - learning_rate: 0.0010
# Epoch 65/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0315 - mae: 0.0996
# Epoch 65: val_loss did not improve from 0.03571
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0314 - mae: 0.0996 - val_loss: 0.0367 - val_mae: 0.1011 - learning_rate: 0.0010
# Epoch 66/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0299 - mae: 0.0971
# Epoch 66: val_loss did not improve from 0.03571
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0299 - mae: 0.0971 - val_loss: 0.0365 - val_mae: 0.1013 - learning_rate: 0.0010
# Epoch 67/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0290 - mae: 0.0946
# Epoch 67: val_loss improved from 0.03571 to 0.03263, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0291 - mae: 0.0949 - val_loss: 0.0326 - val_mae: 0.0930 - learning_rate: 0.0010
# Epoch 68/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0299 - mae: 0.0983
# Epoch 68: val_loss did not improve from 0.03263
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0298 - mae: 0.0982 - val_loss: 0.0333 - val_mae: 0.0974 - learning_rate: 0.0010
# Epoch 69/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0295 - mae: 0.0977
# Epoch 69: val_loss did not improve from 0.03263
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0295 - mae: 0.0978 - val_loss: 0.0343 - val_mae: 0.0986 - learning_rate: 0.0010
# Epoch 70/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0296 - mae: 0.0984
# Epoch 70: val_loss did not improve from 0.03263
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0296 - mae: 0.0984 - val_loss: 0.0330 - val_mae: 0.0983 - learning_rate: 0.0010
# Epoch 71/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0302 - mae: 0.1007
# Epoch 71: val_loss did not improve from 0.03263
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0301 - mae: 0.1005 - val_loss: 0.0348 - val_mae: 0.0983 - learning_rate: 0.0010
# Epoch 72/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0284 - mae: 0.0963
# Epoch 72: val_loss improved from 0.03263 to 0.03184, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0284 - mae: 0.0963 - val_loss: 0.0318 - val_mae: 0.0950 - learning_rate: 0.0010
# Epoch 73/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0275 - mae: 0.0939
# Epoch 73: val_loss did not improve from 0.03184
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0275 - mae: 0.0938 - val_loss: 0.0420 - val_mae: 0.1150 - learning_rate: 0.0010
# Epoch 74/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0293 - mae: 0.0996
# Epoch 74: val_loss improved from 0.03184 to 0.03104, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0293 - mae: 0.0995 - val_loss: 0.0310 - val_mae: 0.0949 - learning_rate: 0.0010
# Epoch 75/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0289 - mae: 0.0997
# Epoch 75: val_loss did not improve from 0.03104
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0289 - mae: 0.0997 - val_loss: 0.0372 - val_mae: 0.1093 - learning_rate: 0.0010
# Epoch 76/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0296 - mae: 0.1005
# Epoch 76: val_loss did not improve from 0.03104
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0295 - mae: 0.1003 - val_loss: 0.0400 - val_mae: 0.1125 - learning_rate: 0.0010
# Epoch 77/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0272 - mae: 0.0939
# Epoch 77: val_loss did not improve from 0.03104
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0272 - mae: 0.0941 - val_loss: 0.0315 - val_mae: 0.0934 - learning_rate: 0.0010
# Epoch 78/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0265 - mae: 0.0929
# Epoch 78: val_loss did not improve from 0.03104
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0265 - mae: 0.0929 - val_loss: 0.0375 - val_mae: 0.1075 - learning_rate: 0.0010
# Epoch 79/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0285 - mae: 0.1000
# Epoch 79: val_loss did not improve from 0.03104
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0285 - mae: 0.1000 - val_loss: 0.0338 - val_mae: 0.1001 - learning_rate: 0.0010
# Epoch 80/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0253 - mae: 0.0903
# Epoch 80: val_loss improved from 0.03104 to 0.03028, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0254 - mae: 0.0905 - val_loss: 0.0303 - val_mae: 0.0957 - learning_rate: 0.0010
# Epoch 81/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0265 - mae: 0.0944
# Epoch 81: val_loss did not improve from 0.03028
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0265 - mae: 0.0944 - val_loss: 0.0318 - val_mae: 0.0960 - learning_rate: 0.0010
# Epoch 82/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0246 - mae: 0.0900
# Epoch 82: val_loss did not improve from 0.03028
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0246 - mae: 0.0901 - val_loss: 0.0311 - val_mae: 0.0964 - learning_rate: 0.0010
# Epoch 83/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0259 - mae: 0.0941
# Epoch 83: val_loss did not improve from 0.03028
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0258 - mae: 0.0941 - val_loss: 0.0323 - val_mae: 0.1002 - learning_rate: 0.0010
# Epoch 84/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0256 - mae: 0.0940
# Epoch 84: val_loss improved from 0.03028 to 0.02980, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0256 - mae: 0.0940 - val_loss: 0.0298 - val_mae: 0.0931 - learning_rate: 0.0010
# Epoch 85/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0264 - mae: 0.0952
# Epoch 85: val_loss did not improve from 0.02980
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0263 - mae: 0.0952 - val_loss: 0.0348 - val_mae: 0.1049 - learning_rate: 0.0010
# Epoch 86/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0253 - mae: 0.0936
# Epoch 86: val_loss improved from 0.02980 to 0.02955, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0253 - mae: 0.0935 - val_loss: 0.0296 - val_mae: 0.0944 - learning_rate: 0.0010
# Epoch 87/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0263 - mae: 0.0957
# Epoch 87: val_loss did not improve from 0.02955
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0263 - mae: 0.0958 - val_loss: 0.0316 - val_mae: 0.0988 - learning_rate: 0.0010
# Epoch 88/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0247 - mae: 0.0918
# Epoch 88: val_loss did not improve from 0.02955
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0247 - mae: 0.0919 - val_loss: 0.0301 - val_mae: 0.0984 - learning_rate: 0.0010
# Epoch 89/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0254 - mae: 0.0947
# Epoch 89: val_loss improved from 0.02955 to 0.02942, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0254 - mae: 0.0948 - val_loss: 0.0294 - val_mae: 0.0955 - learning_rate: 0.0010
# Epoch 90/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0255 - mae: 0.0954
# Epoch 90: val_loss did not improve from 0.02942
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0256 - mae: 0.0953 - val_loss: 0.0335 - val_mae: 0.1049 - learning_rate: 0.0010
# Epoch 91/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0249 - mae: 0.0944
# Epoch 91: val_loss did not improve from 0.02942
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0250 - mae: 0.0943 - val_loss: 0.0298 - val_mae: 0.0955 - learning_rate: 0.0010
# Epoch 92/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0235 - mae: 0.0903
# Epoch 92: val_loss improved from 0.02942 to 0.02812, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0235 - mae: 0.0904 - val_loss: 0.0281 - val_mae: 0.0926 - learning_rate: 0.0010
# Epoch 93/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0234 - mae: 0.0894
# Epoch 93: val_loss did not improve from 0.02812
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0233 - mae: 0.0894 - val_loss: 0.0320 - val_mae: 0.1013 - learning_rate: 0.0010
# Epoch 94/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0233 - mae: 0.0904
# Epoch 94: val_loss improved from 0.02812 to 0.02728, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0233 - mae: 0.0902 - val_loss: 0.0273 - val_mae: 0.0906 - learning_rate: 0.0010
# Epoch 95/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0237 - mae: 0.0909
# Epoch 95: val_loss did not improve from 0.02728
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0238 - mae: 0.0910 - val_loss: 0.0370 - val_mae: 0.1109 - learning_rate: 0.0010
# Epoch 96/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0238 - mae: 0.0928
# Epoch 96: val_loss did not improve from 0.02728
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0239 - mae: 0.0930 - val_loss: 0.0281 - val_mae: 0.0931 - learning_rate: 0.0010
# Epoch 97/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0250 - mae: 0.0955
# Epoch 97: val_loss did not improve from 0.02728
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0249 - mae: 0.0953 - val_loss: 0.0307 - val_mae: 0.0998 - learning_rate: 0.0010
# Epoch 98/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0232 - mae: 0.0896
# Epoch 98: val_loss did not improve from 0.02728
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0231 - mae: 0.0895 - val_loss: 0.0369 - val_mae: 0.1134 - learning_rate: 0.0010
# Epoch 99/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0241 - mae: 0.0938
# Epoch 99: val_loss did not improve from 0.02728
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0240 - mae: 0.0935 - val_loss: 0.0288 - val_mae: 0.0984 - learning_rate: 0.0010
# Epoch 100/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0246 - mae: 0.0954
# Epoch 100: val_loss did not improve from 0.02728
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0246 - mae: 0.0954 - val_loss: 0.0327 - val_mae: 0.1036 - learning_rate: 0.0010
# Epoch 101/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0262 - mae: 0.0987
# Epoch 101: val_loss did not improve from 0.02728
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0263 - mae: 0.0988 - val_loss: 0.0434 - val_mae: 0.1232 - learning_rate: 0.0010
# Epoch 102/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0248 - mae: 0.0961
# Epoch 102: val_loss did not improve from 0.02728
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0248 - mae: 0.0959 - val_loss: 0.0329 - val_mae: 0.1080 - learning_rate: 0.0010
# Epoch 103/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0244 - mae: 0.0964
# Epoch 103: val_loss did not improve from 0.02728
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0244 - mae: 0.0963 - val_loss: 0.0350 - val_mae: 0.1119 - learning_rate: 0.0010
# Epoch 104/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0232 - mae: 0.0914
# Epoch 104: val_loss did not improve from 0.02728
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0233 - mae: 0.0915 - val_loss: 0.0312 - val_mae: 0.1055 - learning_rate: 0.0010
# Epoch 105/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0238 - mae: 0.0947
# Epoch 105: val_loss did not improve from 0.02728
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0238 - mae: 0.0946 - val_loss: 0.0345 - val_mae: 0.1062 - learning_rate: 0.0010
# Epoch 106/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0238 - mae: 0.0937
# Epoch 106: val_loss did not improve from 0.02728
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0240 - mae: 0.0941 - val_loss: 0.0278 - val_mae: 0.0954 - learning_rate: 0.0010
# Epoch 107/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0236 - mae: 0.0926
# Epoch 107: val_loss improved from 0.02728 to 0.02564, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0235 - mae: 0.0926 - val_loss: 0.0256 - val_mae: 0.0882 - learning_rate: 0.0010
# Epoch 108/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0240 - mae: 0.0937
# Epoch 108: val_loss did not improve from 0.02564
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0239 - mae: 0.0935 - val_loss: 0.0305 - val_mae: 0.1026 - learning_rate: 0.0010
# Epoch 109/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0222 - mae: 0.0897
# Epoch 109: val_loss did not improve from 0.02564
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0222 - mae: 0.0897 - val_loss: 0.0280 - val_mae: 0.0954 - learning_rate: 0.0010
# Epoch 110/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0222 - mae: 0.0884
# Epoch 110: val_loss did not improve from 0.02564
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0222 - mae: 0.0885 - val_loss: 0.0288 - val_mae: 0.0969 - learning_rate: 0.0010
# Epoch 111/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0213 - mae: 0.0878
# Epoch 111: val_loss did not improve from 0.02564
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0213 - mae: 0.0879 - val_loss: 0.0282 - val_mae: 0.0971 - learning_rate: 0.0010
# Epoch 112/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0215 - mae: 0.0883
# Epoch 112: val_loss did not improve from 0.02564
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0215 - mae: 0.0883 - val_loss: 0.0268 - val_mae: 0.0933 - learning_rate: 0.0010
# Epoch 113/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0205 - mae: 0.0851
# Epoch 113: val_loss did not improve from 0.02564
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0205 - mae: 0.0852 - val_loss: 0.0285 - val_mae: 0.0973 - learning_rate: 0.0010
# Epoch 114/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0206 - mae: 0.0865
# Epoch 114: val_loss improved from 0.02564 to 0.02484, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0206 - mae: 0.0864 - val_loss: 0.0248 - val_mae: 0.0880 - learning_rate: 0.0010
# Epoch 115/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0212 - mae: 0.0873
# Epoch 115: val_loss did not improve from 0.02484
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0213 - mae: 0.0875 - val_loss: 0.0273 - val_mae: 0.0940 - learning_rate: 0.0010
# Epoch 116/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0209 - mae: 0.0876
# Epoch 116: val_loss did not improve from 0.02484
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0209 - mae: 0.0874 - val_loss: 0.0275 - val_mae: 0.0952 - learning_rate: 0.0010
# Epoch 117/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0199 - mae: 0.0849
# Epoch 117: val_loss did not improve from 0.02484
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0199 - mae: 0.0848 - val_loss: 0.0283 - val_mae: 0.0993 - learning_rate: 0.0010
# Epoch 118/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0205 - mae: 0.0869
# Epoch 118: val_loss did not improve from 0.02484
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0206 - mae: 0.0869 - val_loss: 0.0249 - val_mae: 0.0900 - learning_rate: 0.0010
# Epoch 119/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0197 - mae: 0.0846
# Epoch 119: val_loss did not improve from 0.02484
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0197 - mae: 0.0846 - val_loss: 0.0310 - val_mae: 0.1015 - learning_rate: 0.0010
# Epoch 120/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0198 - mae: 0.0857
# Epoch 120: val_loss did not improve from 0.02484
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0198 - mae: 0.0858 - val_loss: 0.0270 - val_mae: 0.0957 - learning_rate: 0.0010
# Epoch 121/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0202 - mae: 0.0870
# Epoch 121: val_loss did not improve from 0.02484
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0202 - mae: 0.0871 - val_loss: 0.0398 - val_mae: 0.1178 - learning_rate: 0.0010
# Epoch 122/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0215 - mae: 0.0901
# Epoch 122: val_loss did not improve from 0.02484
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0213 - mae: 0.0896 - val_loss: 0.0273 - val_mae: 0.0962 - learning_rate: 0.0010
# Epoch 123/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0201 - mae: 0.0868
# Epoch 123: val_loss improved from 0.02484 to 0.02455, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0201 - mae: 0.0866 - val_loss: 0.0245 - val_mae: 0.0876 - learning_rate: 0.0010
# Epoch 124/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0193 - mae: 0.0849
# Epoch 124: val_loss did not improve from 0.02455
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0193 - mae: 0.0847 - val_loss: 0.0281 - val_mae: 0.0973 - learning_rate: 0.0010
# Epoch 125/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0199 - mae: 0.0864
# Epoch 125: val_loss did not improve from 0.02455
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0199 - mae: 0.0863 - val_loss: 0.0292 - val_mae: 0.1018 - learning_rate: 0.0010
# Epoch 126/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0191 - mae: 0.0838
# Epoch 126: val_loss did not improve from 0.02455
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0192 - mae: 0.0840 - val_loss: 0.0279 - val_mae: 0.0980 - learning_rate: 0.0010
# Epoch 127/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0199 - mae: 0.0869
# Epoch 127: val_loss did not improve from 0.02455
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0199 - mae: 0.0868 - val_loss: 0.0256 - val_mae: 0.0902 - learning_rate: 0.0010
# Epoch 128/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0194 - mae: 0.0849
# Epoch 128: val_loss did not improve from 0.02455
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0194 - mae: 0.0849 - val_loss: 0.0333 - val_mae: 0.1086 - learning_rate: 0.0010
# Epoch 129/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0204 - mae: 0.0886
# Epoch 129: val_loss did not improve from 0.02455
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0203 - mae: 0.0883 - val_loss: 0.0257 - val_mae: 0.0958 - learning_rate: 0.0010
# Epoch 130/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0191 - mae: 0.0845
# Epoch 130: val_loss did not improve from 0.02455
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0191 - mae: 0.0845 - val_loss: 0.0369 - val_mae: 0.1154 - learning_rate: 0.0010
# Epoch 131/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0198 - mae: 0.0877
# Epoch 131: val_loss improved from 0.02455 to 0.02404, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0198 - mae: 0.0875 - val_loss: 0.0240 - val_mae: 0.0915 - learning_rate: 0.0010
# Epoch 132/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0192 - mae: 0.0844
# Epoch 132: val_loss did not improve from 0.02404
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0191 - mae: 0.0843 - val_loss: 0.0288 - val_mae: 0.1016 - learning_rate: 0.0010
# Epoch 133/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0183 - mae: 0.0818
# Epoch 133: val_loss did not improve from 0.02404
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0183 - mae: 0.0819 - val_loss: 0.0260 - val_mae: 0.0923 - learning_rate: 0.0010
# Epoch 134/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0186 - mae: 0.0833
# Epoch 134: val_loss did not improve from 0.02404
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0187 - mae: 0.0834 - val_loss: 0.0333 - val_mae: 0.1083 - learning_rate: 0.0010
# Epoch 135/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0203 - mae: 0.0888
# Epoch 135: val_loss did not improve from 0.02404
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0203 - mae: 0.0888 - val_loss: 0.0252 - val_mae: 0.0921 - learning_rate: 0.0010
# Epoch 136/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0217 - mae: 0.0922
# Epoch 136: val_loss did not improve from 0.02404
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0217 - mae: 0.0921 - val_loss: 0.0255 - val_mae: 0.0917 - learning_rate: 0.0010
# Epoch 137/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0211 - mae: 0.0908
# Epoch 137: val_loss did not improve from 0.02404
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0211 - mae: 0.0907 - val_loss: 0.0292 - val_mae: 0.1001 - learning_rate: 0.0010
# Epoch 138/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0200 - mae: 0.0886
# Epoch 138: val_loss did not improve from 0.02404
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0200 - mae: 0.0887 - val_loss: 0.0245 - val_mae: 0.0931 - learning_rate: 0.0010
# Epoch 139/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0192 - mae: 0.0860
# Epoch 139: val_loss did not improve from 0.02404
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0191 - mae: 0.0859 - val_loss: 0.0265 - val_mae: 0.0994 - learning_rate: 0.0010
# Epoch 140/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0183 - mae: 0.0835
# Epoch 140: val_loss did not improve from 0.02404
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0183 - mae: 0.0835 - val_loss: 0.0275 - val_mae: 0.0963 - learning_rate: 0.0010
# Epoch 141/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0181 - mae: 0.0824
# Epoch 141: val_loss did not improve from 0.02404
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0181 - mae: 0.0826 - val_loss: 0.0246 - val_mae: 0.0912 - learning_rate: 0.0010
# Epoch 142/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0190 - mae: 0.0851
# Epoch 142: val_loss improved from 0.02404 to 0.02380, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0190 - mae: 0.0850 - val_loss: 0.0238 - val_mae: 0.0913 - learning_rate: 0.0010
# Epoch 143/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0180 - mae: 0.0836
# Epoch 143: val_loss did not improve from 0.02380
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0180 - mae: 0.0835 - val_loss: 0.0258 - val_mae: 0.0923 - learning_rate: 0.0010
# Epoch 144/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0175 - mae: 0.0810
# Epoch 144: val_loss did not improve from 0.02380
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0176 - mae: 0.0814 - val_loss: 0.0306 - val_mae: 0.1057 - learning_rate: 0.0010
# Epoch 145/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0193 - mae: 0.0878
# Epoch 145: val_loss did not improve from 0.02380
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0192 - mae: 0.0874 - val_loss: 0.0283 - val_mae: 0.1010 - learning_rate: 0.0010
# Epoch 146/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0180 - mae: 0.0837
# Epoch 146: val_loss did not improve from 0.02380
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0181 - mae: 0.0839 - val_loss: 0.0265 - val_mae: 0.0982 - learning_rate: 0.0010
# Epoch 147/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0180 - mae: 0.0832
# Epoch 147: val_loss did not improve from 0.02380
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0179 - mae: 0.0830 - val_loss: 0.0255 - val_mae: 0.0942 - learning_rate: 0.0010
# Epoch 148/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0173 - mae: 0.0804
# Epoch 148: val_loss did not improve from 0.02380
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0174 - mae: 0.0809 - val_loss: 0.0246 - val_mae: 0.0941 - learning_rate: 0.0010
# Epoch 149/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0174 - mae: 0.0815
# Epoch 149: val_loss improved from 0.02380 to 0.02336, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0175 - mae: 0.0816 - val_loss: 0.0234 - val_mae: 0.0891 - learning_rate: 0.0010
# Epoch 150/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0166 - mae: 0.0787
# Epoch 150: val_loss did not improve from 0.02336
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0166 - mae: 0.0788 - val_loss: 0.0256 - val_mae: 0.0963 - learning_rate: 0.0010
# Epoch 151/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0170 - mae: 0.0807
# Epoch 151: val_loss did not improve from 0.02336
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0170 - mae: 0.0807 - val_loss: 0.0260 - val_mae: 0.0972 - learning_rate: 0.0010
# Epoch 152/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0175 - mae: 0.0831
# Epoch 152: val_loss improved from 0.02336 to 0.02301, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.0175 - mae: 0.0831 - val_loss: 0.0230 - val_mae: 0.0891 - learning_rate: 0.0010
# Epoch 153/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0182 - mae: 0.0841
# Epoch 153: val_loss did not improve from 0.02301
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0181 - mae: 0.0837 - val_loss: 0.0276 - val_mae: 0.0997 - learning_rate: 0.0010
# Epoch 154/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0168 - mae: 0.0793
# Epoch 154: val_loss did not improve from 0.02301
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0168 - mae: 0.0795 - val_loss: 0.0241 - val_mae: 0.0943 - learning_rate: 0.0010
# Epoch 155/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0175 - mae: 0.0833
# Epoch 155: val_loss did not improve from 0.02301
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0176 - mae: 0.0834 - val_loss: 0.0273 - val_mae: 0.0978 - learning_rate: 0.0010
# Epoch 156/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0171 - mae: 0.0821
# Epoch 156: val_loss improved from 0.02301 to 0.02230, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0171 - mae: 0.0822 - val_loss: 0.0223 - val_mae: 0.0881 - learning_rate: 0.0010
# Epoch 157/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0178 - mae: 0.0837
# Epoch 157: val_loss did not improve from 0.02230
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0178 - mae: 0.0836 - val_loss: 0.0341 - val_mae: 0.1097 - learning_rate: 0.0010
# Epoch 158/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0177 - mae: 0.0839
# Epoch 158: val_loss did not improve from 0.02230
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0177 - mae: 0.0838 - val_loss: 0.0245 - val_mae: 0.0913 - learning_rate: 0.0010
# Epoch 159/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0173 - mae: 0.0824
# Epoch 159: val_loss did not improve from 0.02230
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0173 - mae: 0.0822 - val_loss: 0.0254 - val_mae: 0.0930 - learning_rate: 0.0010
# Epoch 160/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0167 - mae: 0.0806
# Epoch 160: val_loss improved from 0.02230 to 0.02169, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0166 - mae: 0.0805 - val_loss: 0.0217 - val_mae: 0.0853 - learning_rate: 0.0010
# Epoch 161/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0161 - mae: 0.0788
# Epoch 161: val_loss did not improve from 0.02169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0162 - mae: 0.0789 - val_loss: 0.0256 - val_mae: 0.0973 - learning_rate: 0.0010
# Epoch 162/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0180 - mae: 0.0848
# Epoch 162: val_loss did not improve from 0.02169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0180 - mae: 0.0848 - val_loss: 0.0232 - val_mae: 0.0909 - learning_rate: 0.0010
# Epoch 163/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0187 - mae: 0.0881
# Epoch 163: val_loss did not improve from 0.02169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0187 - mae: 0.0878 - val_loss: 0.0271 - val_mae: 0.1014 - learning_rate: 0.0010
# Epoch 164/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0176 - mae: 0.0849
# Epoch 164: val_loss did not improve from 0.02169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0177 - mae: 0.0849 - val_loss: 0.0223 - val_mae: 0.0893 - learning_rate: 0.0010
# Epoch 165/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0202 - mae: 0.0901
# Epoch 165: val_loss did not improve from 0.02169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0204 - mae: 0.0909 - val_loss: 0.0291 - val_mae: 0.1098 - learning_rate: 0.0010
# Epoch 166/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0205 - mae: 0.0931
# Epoch 166: val_loss did not improve from 0.02169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0205 - mae: 0.0931 - val_loss: 0.0317 - val_mae: 0.1086 - learning_rate: 0.0010
# Epoch 167/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0211 - mae: 0.0920
# Epoch 167: val_loss did not improve from 0.02169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0211 - mae: 0.0921 - val_loss: 0.0289 - val_mae: 0.1042 - learning_rate: 0.0010
# Epoch 168/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0202 - mae: 0.0895
# Epoch 168: val_loss did not improve from 0.02169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0201 - mae: 0.0894 - val_loss: 0.0257 - val_mae: 0.0959 - learning_rate: 0.0010
# Epoch 169/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0198 - mae: 0.0877
# Epoch 169: val_loss did not improve from 0.02169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0198 - mae: 0.0877 - val_loss: 0.0283 - val_mae: 0.1005 - learning_rate: 0.0010
# Epoch 170/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0185 - mae: 0.0852
# Epoch 170: val_loss did not improve from 0.02169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0185 - mae: 0.0852 - val_loss: 0.0241 - val_mae: 0.0922 - learning_rate: 0.0010
# Epoch 171/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0178 - mae: 0.0835
# Epoch 171: val_loss did not improve from 0.02169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0178 - mae: 0.0833 - val_loss: 0.0260 - val_mae: 0.0957 - learning_rate: 0.0010
# Epoch 172/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0178 - mae: 0.0827
# Epoch 172: val_loss did not improve from 0.02169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0177 - mae: 0.0826 - val_loss: 0.0249 - val_mae: 0.0918 - learning_rate: 0.0010
# Epoch 173/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0171 - mae: 0.0813
# Epoch 173: val_loss did not improve from 0.02169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0171 - mae: 0.0810 - val_loss: 0.0241 - val_mae: 0.0892 - learning_rate: 0.0010
# Epoch 174/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0163 - mae: 0.0786
# Epoch 174: val_loss did not improve from 0.02169
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0164 - mae: 0.0790 - val_loss: 0.0288 - val_mae: 0.1013 - learning_rate: 0.0010
# Epoch 175/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0168 - mae: 0.0807
# Epoch 175: val_loss did not improve from 0.02169
#
# Epoch 175: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0167 - mae: 0.0805 - val_loss: 0.0224 - val_mae: 0.0895 - learning_rate: 0.0010
# Epoch 176/500
# ...
# Epoch 211/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0125 - mae: 0.0685
# Epoch 211: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0125 - mae: 0.0684 - val_loss: 0.0212 - val_mae: 0.0862 - learning_rate: 2.5000e-04
# Epoch 212/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0127 - mae: 0.0693
# Epoch 212: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0127 - mae: 0.0694 - val_loss: 0.0205 - val_mae: 0.0858 - learning_rate: 2.5000e-04
# Epoch 213/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0128 - mae: 0.0701
# Epoch 213: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0128 - mae: 0.0701 - val_loss: 0.0211 - val_mae: 0.0874 - learning_rate: 2.5000e-04
# Epoch 214/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0128 - mae: 0.0701
# Epoch 214: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0128 - mae: 0.0701 - val_loss: 0.0208 - val_mae: 0.0863 - learning_rate: 2.5000e-04
# Epoch 215/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0128 - mae: 0.0703
# Epoch 215: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0128 - mae: 0.0702 - val_loss: 0.0215 - val_mae: 0.0874 - learning_rate: 2.5000e-04
# Epoch 216/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0128 - mae: 0.0692
# Epoch 216: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0128 - mae: 0.0691 - val_loss: 0.0210 - val_mae: 0.0874 - learning_rate: 2.5000e-04
# Epoch 217/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0126 - mae: 0.0688
# Epoch 217: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0126 - mae: 0.0686 - val_loss: 0.0213 - val_mae: 0.0869 - learning_rate: 2.5000e-04
# Epoch 218/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0124 - mae: 0.0684
# Epoch 218: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0124 - mae: 0.0684 - val_loss: 0.0225 - val_mae: 0.0907 - learning_rate: 2.5000e-04
# Epoch 219/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0124 - mae: 0.0678
# Epoch 219: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0124 - mae: 0.0679 - val_loss: 0.0206 - val_mae: 0.0863 - learning_rate: 2.5000e-04
# Epoch 220/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0126 - mae: 0.0684
# Epoch 220: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0126 - mae: 0.0686 - val_loss: 0.0211 - val_mae: 0.0872 - learning_rate: 2.5000e-04
# Epoch 221/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0125 - mae: 0.0688
# Epoch 221: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0125 - mae: 0.0688 - val_loss: 0.0218 - val_mae: 0.0884 - learning_rate: 2.5000e-04
# Epoch 222/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0124 - mae: 0.0686
# Epoch 222: val_loss did not improve from 0.02048
#
# Epoch 222: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0125 - mae: 0.0687 - val_loss: 0.0212 - val_mae: 0.0877 - learning_rate: 2.5000e-04
# Epoch 223/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0126 - mae: 0.0688
# Epoch 223: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0126 - mae: 0.0686 - val_loss: 0.0215 - val_mae: 0.0882 - learning_rate: 1.2500e-04
# Epoch 224/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0119 - mae: 0.0657
# Epoch 224: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0119 - mae: 0.0658 - val_loss: 0.0206 - val_mae: 0.0860 - learning_rate: 1.2500e-04
# Epoch 225/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0123 - mae: 0.0687
# Epoch 225: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0123 - mae: 0.0688 - val_loss: 0.0213 - val_mae: 0.0873 - learning_rate: 1.2500e-04
# Epoch 226/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0122 - mae: 0.0676
# Epoch 226: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0122 - mae: 0.0676 - val_loss: 0.0215 - val_mae: 0.0880 - learning_rate: 1.2500e-04
# Epoch 227/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0119 - mae: 0.0662
# Epoch 227: val_loss did not improve from 0.02048
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0119 - mae: 0.0662 - val_loss: 0.0225 - val_mae: 0.0906 - learning_rate: 1.2500e-04
# Epoch 228/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0120 - mae: 0.0670
# Epoch 228: val_loss improved from 0.02048 to 0.02045, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.0120 - mae: 0.0670 - val_loss: 0.0205 - val_mae: 0.0860 - learning_rate: 1.2500e-04
# Epoch 229/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0118 - mae: 0.0664
# Epoch 229: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0118 - mae: 0.0665 - val_loss: 0.0213 - val_mae: 0.0876 - learning_rate: 1.2500e-04
# Epoch 230/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0116 - mae: 0.0650
# Epoch 230: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0117 - mae: 0.0651 - val_loss: 0.0210 - val_mae: 0.0874 - learning_rate: 1.2500e-04
# Epoch 231/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0121 - mae: 0.0672
# Epoch 231: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0121 - mae: 0.0672 - val_loss: 0.0215 - val_mae: 0.0888 - learning_rate: 1.2500e-04
# Epoch 232/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0121 - mae: 0.0677
# Epoch 232: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0121 - mae: 0.0679 - val_loss: 0.0221 - val_mae: 0.0899 - learning_rate: 1.2500e-04
# Epoch 233/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0119 - mae: 0.0662
# Epoch 233: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0119 - mae: 0.0662 - val_loss: 0.0214 - val_mae: 0.0879 - learning_rate: 1.2500e-04
# Epoch 234/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0117 - mae: 0.0658
# Epoch 234: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0117 - mae: 0.0659 - val_loss: 0.0216 - val_mae: 0.0885 - learning_rate: 1.2500e-04
# Epoch 235/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0118 - mae: 0.0664
# Epoch 235: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0118 - mae: 0.0664 - val_loss: 0.0221 - val_mae: 0.0897 - learning_rate: 1.2500e-04
# Epoch 236/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0121 - mae: 0.0675
# Epoch 236: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0121 - mae: 0.0675 - val_loss: 0.0220 - val_mae: 0.0900 - learning_rate: 1.2500e-04
# Epoch 237/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0119 - mae: 0.0667
# Epoch 237: val_loss did not improve from 0.02045
#
# Epoch 237: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0119 - mae: 0.0667 - val_loss: 0.0217 - val_mae: 0.0890 - learning_rate: 1.2500e-04
# Epoch 238/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0120 - mae: 0.0671
# Epoch 238: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0120 - mae: 0.0669 - val_loss: 0.0208 - val_mae: 0.0865 - learning_rate: 6.2500e-05
# Epoch 239/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0116 - mae: 0.0655
# Epoch 239: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0116 - mae: 0.0654 - val_loss: 0.0215 - val_mae: 0.0879 - learning_rate: 6.2500e-05
# Epoch 240/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0114 - mae: 0.0646
# Epoch 240: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0115 - mae: 0.0648 - val_loss: 0.0219 - val_mae: 0.0888 - learning_rate: 6.2500e-05
# Epoch 241/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0117 - mae: 0.0660
# Epoch 241: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0116 - mae: 0.0659 - val_loss: 0.0217 - val_mae: 0.0890 - learning_rate: 6.2500e-05
# Epoch 242/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0120 - mae: 0.0670
# Epoch 242: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0119 - mae: 0.0668 - val_loss: 0.0214 - val_mae: 0.0878 - learning_rate: 6.2500e-05
# Epoch 243/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0114 - mae: 0.0645
# Epoch 243: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0114 - mae: 0.0646 - val_loss: 0.0217 - val_mae: 0.0887 - learning_rate: 6.2500e-05
# Epoch 244/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0116 - mae: 0.0646
# Epoch 244: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0116 - mae: 0.0645 - val_loss: 0.0213 - val_mae: 0.0875 - learning_rate: 6.2500e-05
# Epoch 245/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0119 - mae: 0.0660
# Epoch 245: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0119 - mae: 0.0660 - val_loss: 0.0215 - val_mae: 0.0884 - learning_rate: 6.2500e-05
# Epoch 246/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0118 - mae: 0.0661
# Epoch 246: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0118 - mae: 0.0659 - val_loss: 0.0211 - val_mae: 0.0871 - learning_rate: 6.2500e-05
# Epoch 247/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0118 - mae: 0.0667
# Epoch 247: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0118 - mae: 0.0668 - val_loss: 0.0219 - val_mae: 0.0893 - learning_rate: 6.2500e-05
# Epoch 248/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0117 - mae: 0.0660
# Epoch 248: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0117 - mae: 0.0660 - val_loss: 0.0207 - val_mae: 0.0865 - learning_rate: 6.2500e-05
# Epoch 249/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0115 - mae: 0.0646
# Epoch 249: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0115 - mae: 0.0648 - val_loss: 0.0214 - val_mae: 0.0882 - learning_rate: 6.2500e-05
# Epoch 250/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0117 - mae: 0.0659
# Epoch 250: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0117 - mae: 0.0657 - val_loss: 0.0207 - val_mae: 0.0863 - learning_rate: 6.2500e-05
# Epoch 251/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0117 - mae: 0.0660
# Epoch 251: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0117 - mae: 0.0660 - val_loss: 0.0209 - val_mae: 0.0871 - learning_rate: 6.2500e-05
# Epoch 252/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0114 - mae: 0.0642
# Epoch 252: val_loss did not improve from 0.02045
#
# Epoch 252: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0114 - mae: 0.0643 - val_loss: 0.0213 - val_mae: 0.0880 - learning_rate: 6.2500e-05
# Epoch 253/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0112 - mae: 0.0640
# Epoch 253: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0112 - mae: 0.0642 - val_loss: 0.0212 - val_mae: 0.0879 - learning_rate: 3.1250e-05
# Epoch 254/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0114 - mae: 0.0649
# Epoch 254: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0114 - mae: 0.0649 - val_loss: 0.0211 - val_mae: 0.0879 - learning_rate: 3.1250e-05
# Epoch 255/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0114 - mae: 0.0651
# Epoch 255: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0115 - mae: 0.0652 - val_loss: 0.0213 - val_mae: 0.0880 - learning_rate: 3.1250e-05
# Epoch 256/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0114 - mae: 0.0644
# Epoch 256: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0114 - mae: 0.0646 - val_loss: 0.0213 - val_mae: 0.0876 - learning_rate: 3.1250e-05
# Epoch 257/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0115 - mae: 0.0658
# Epoch 257: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0115 - mae: 0.0658 - val_loss: 0.0212 - val_mae: 0.0877 - learning_rate: 3.1250e-05
# Epoch 258/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0117 - mae: 0.0661
# Epoch 258: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0117 - mae: 0.0662 - val_loss: 0.0213 - val_mae: 0.0882 - learning_rate: 3.1250e-05
# Epoch 259/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0112 - mae: 0.0645
# Epoch 259: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0113 - mae: 0.0645 - val_loss: 0.0213 - val_mae: 0.0882 - learning_rate: 3.1250e-05
# Epoch 260/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0115 - mae: 0.0648
# Epoch 260: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0115 - mae: 0.0648 - val_loss: 0.0212 - val_mae: 0.0879 - learning_rate: 3.1250e-05
# Epoch 261/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0110 - mae: 0.0632
# Epoch 261: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0110 - mae: 0.0633 - val_loss: 0.0210 - val_mae: 0.0872 - learning_rate: 3.1250e-05
# Epoch 262/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0115 - mae: 0.0650
# Epoch 262: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0115 - mae: 0.0649 - val_loss: 0.0212 - val_mae: 0.0877 - learning_rate: 3.1250e-05
# Epoch 263/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0114 - mae: 0.0654
# Epoch 263: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0114 - mae: 0.0655 - val_loss: 0.0214 - val_mae: 0.0880 - learning_rate: 3.1250e-05
# Epoch 264/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0115 - mae: 0.0654
# Epoch 264: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0115 - mae: 0.0656 - val_loss: 0.0216 - val_mae: 0.0884 - learning_rate: 3.1250e-05
# Epoch 265/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0113 - mae: 0.0647
# Epoch 265: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0113 - mae: 0.0645 - val_loss: 0.0211 - val_mae: 0.0876 - learning_rate: 3.1250e-05
# Epoch 266/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0114 - mae: 0.0637
# Epoch 266: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0113 - mae: 0.0637 - val_loss: 0.0213 - val_mae: 0.0882 - learning_rate: 3.1250e-05
# Epoch 267/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0115 - mae: 0.0650
# Epoch 267: val_loss did not improve from 0.02045
#
# Epoch 267: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0115 - mae: 0.0652 - val_loss: 0.0210 - val_mae: 0.0874 - learning_rate: 3.1250e-05
# Epoch 268/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0117 - mae: 0.0658
# Epoch 268: val_loss did not improve from 0.02045
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0117 - mae: 0.0659 - val_loss: 0.0210 - val_mae: 0.0872 - learning_rate: 1.5625e-05
# Epoch 268: early stopping
# Restoring model weights from the end of the best epoch: 228.

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import  mean_absolute_error

# model  = load_model("/content/best_lstm_model_reg.keras")
# پیش‌بینی روی داده تست-
y_pred_scaled = final_model.predict(X_windows_test)  # (N, 1)

# برگرداندن به مقیاس اصلی
y_pred_original = y_scaler.inverse_transform(y_pred_scaled)
y_true_original = y_scaler.inverse_transform(y_windows_test)




mae = mean_absolute_error(y_true_original, y_pred_original)
mae2 = mean_absolute_error(y_windows_test, y_pred_scaled)

print(f"Test MAE(scaled): {mae2:.3f}")
print(f"Test MAE(true value): {mae:.3f}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step
# Test MAE(scaled): 0.080
# Test MAE(true value): 1.154

# %%
import matplotlib.pyplot as plt

# Set font sizes and styles for publication
plt.rcParams.update({
    'font.size': 14,
    'axes.labelsize': 16,
    'axes.titlesize': 18,
    'legend.fontsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'font.family': 'serif',  # Optional: use serif font (common in papers)
    'figure.figsize': (8, 5)
})

# Plot training & validation loss
plt.plot(history.history["loss"], label="Training Loss", linewidth=2.5, color='tab:blue')
plt.plot(history.history["val_loss"], label="Validation Loss", linewidth=2.5, color='tab:red')

# Add title and axis labels
plt.title("Model Training Progress", fontsize=18, pad=20)
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")

# Improve layout and add grid
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.legend(frameon=True, loc='upper right', shadow=False, edgecolor='black')

# Use tight layout to prevent clipping
plt.tight_layout()

# Save high-resolution figure for your article
plt.savefig("training_validation_loss.pdf", format='pdf', dpi=300, bbox_inches='tight')
plt.savefig("training_validation_loss.png", format='png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import pickle

with open('training_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
# time = np.arange(1, y_true_original.shape[0]+1) * 0.01
# time = time.reshape(-1, 1)

plt.figure(figsize=(15,10))
plt.plot(y_true_original[222,:])
plt.plot(y_pred_original[222,:])
plt.grid()
