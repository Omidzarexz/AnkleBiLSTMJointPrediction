# %%
# !git clone https://github.com/Omidzarexz/AnkleBiLSTMJointPrediction
# Out:
# Cloning into 'AnkleBiLSTMJointPrediction'...
# remote: Enumerating objects: 206, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 206 (delta 45), reused 14 (delta 14), pack-reused 129 (from 1)
# Receiving objects: 100% (206/206), 27.42 MiB | 15.44 MiB/s, done.
# Resolving deltas: 100% (99/99), done.

# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt


# df_clean_train_12feature_cross_subject = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_train_12feature_cross_subject.csv")
# df_clean_test_12feature_cross_subject  = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_test_12feature_cross_subject.csv")


# df_clean_train_16feature_cross_subject = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_train_16feature_cross_subject.csv")
# df_clean_test_16feature_cross_subject  = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_test_16feature_cross_subject.csv")


df_clean_train_16feature_within_subject = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_train_16feature_within_subject_txt25.csv")
df_clean_test_16feature_within_subject  = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_test_16feature_within_subject_txt25.csv")

df_clean_train = df_clean_train_16feature_within_subject
df_clean_test  = df_clean_test_16feature_within_subject

# %%
from scipy.signal import butter, filtfilt

def low_pass_butter(signal, cutoff=10, fs=100, order=2):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return filtfilt(b, a, signal)
feature_columns = [
    'MPU1_Acc_X', 'MPU1_Acc_Y', 'MPU1_Acc_Z',
    'MPU1_Gyro_X', 'MPU1_Gyro_Y', 'MPU1_Gyro_Z',
    'MPU1_Roll','MPU1_Pitch',
    'MPU2_Acc_X', 'MPU2_Acc_Y', 'MPU2_Acc_Z',
    'MPU2_Gyro_X', 'MPU2_Gyro_Y', 'MPU2_Gyro_Z',
    'MPU2_Roll','MPU2_Pitch'
]




df_filtered_trainig = pd.DataFrame()
df_filtered_test    = pd.DataFrame()
for col in feature_columns:
    df_filtered_trainig[col] = low_pass_butter( df_clean_train[col].values
                                        , cutoff=5 # Hz
                                        , fs=100  # Hz
                                        , order=2  )
    df_filtered_test[col] = low_pass_butter( df_clean_test[col].values
                                        , cutoff=5 # Hz
                                        , fs=100  # Hz
                                        , order=2  )







print("\ndf_filtered_trainig shape:",df_filtered_trainig.shape)
print("\ndf_filtered_test shape:",df_filtered_test.shape)
# Out:
# df_filtered_trainig shape: (16500, 16)
#
# df_filtered_test shape: (992, 16)

# %%
from sklearn.preprocessing import  MinMaxScaler


scaler = MinMaxScaler(feature_range=(-1, 1))
X_data_train = scaler.fit_transform(df_filtered_trainig[feature_columns].values)  # (T, 12)


y_scaler = MinMaxScaler(feature_range=(-1, 1))
y_data_train = y_scaler.fit_transform(df_clean_train['angle'].values.reshape(-1, 1))





X_data_test = scaler.transform(df_filtered_test[feature_columns].values)

y_data_test = y_scaler.transform(df_clean_test["angle"].values.reshape(-1,1))


# تنظیمات پنجره
window_size = 200   #
horizon = 50        #
step_size = 20      #

# تابع پنجره‌بندی
def create_windows_with_labels(X, y, window_size, horizon, step_size):
    X_windows = []
    y_windows = []
    for i in range(0,  len(X) - window_size - horizon + 1, step_size):
        X_windows.append(X[i:i + window_size])
        y_windows.append(y[i + window_size : i + window_size + horizon])  # برچسب آخرین نمونه در پنجره
    return np.array(X_windows), np.array(y_windows)

# ایجاد پنجره‌ها
X_windows, y_windows = create_windows_with_labels(X_data_train, y_data_train,
                                                  window_size, horizon, step_size)
if horizon==1:
    y_windows = y_windows.reshape(-1,1)
else:
    y_windows = np.squeeze(y_windows, axis=2)





print(f"✅   (X_windows):(samples, time steps, features) → {X_windows.shape}")
print(f"✅  (y_windows): {y_windows.shape}")

step_size_for_test = 1
X_windows_test, y_windows_test = create_windows_with_labels(X_data_test, y_data_test,
                                                            window_size, horizon, step_size_for_test)

if horizon==1:
    y_windows_test = y_windows_test.reshape(-1,1)
else:
    y_windows_test = np.squeeze(y_windows_test, axis=2)

print(f"\n✅   (X_windows_test):(samples, time steps, features) → {X_windows_test.shape}")
print(f"✅  (y_windows_test): {y_windows_test.shape}")
# Out:
# ✅   (X_windows):(samples, time steps, features) → (813, 200, 16)
# ✅  (y_windows): (813, 50)
#
# ✅   (X_windows_test):(samples, time steps, features) → (743, 200, 16)
# ✅  (y_windows_test): (743, 50)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from keras.layers import Bidirectional
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, GlobalAveragePooling1D
from tensorflow.keras.layers import Input, Dense, GRU, Bidirectional, Dropout, ReLU, TimeDistributed, LayerNormalization
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l2


LEARNING_RATE = 0.001
lambda_loss_amount = 0.0005


base_model  = load_model("/kaggle/input/h50-cross-subject/tensorflow2/default/1/best_lstm_model_reg.keras")





# Freeze early layers (optional)
for layer in base_model.layers[:4]:
    layer.trainable = False


x = base_model.layers[3].output  #
x = LayerNormalization(name='layer_norm_TL_1')(x)
x = Dropout(0.3, name='dropout_TL_1')(x)

x = Bidirectional(LSTM(32, return_sequences=True,
                           kernel_regularizer=l2(lambda_loss_amount)), name='bi_lstm_TL_1')(x)
x = LayerNormalization(name='layer_norm_TL_2')(x)
x = Dropout(0.3, name='dropout_TL_2')(x)

x = Bidirectional(LSTM(32, return_sequences=False,
                           kernel_regularizer=l2(lambda_loss_amount)), name='bi_lstm_TL_2')(x)
x = Dropout(0.3, name='dropout_TL_3')(x)

outputs = Dense(horizon, activation='linear', name='Dense_TL_1')(x)


transfer_model = models.Model(inputs=base_model.input, outputs=outputs)



# # Recompile
transfer_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                       loss='mae',
                       metrics=['mae'])

transfer_model.summary()
plot_model(transfer_model, show_shapes=True , dpi=45)


X_train, X_val, y_train, y_val = train_test_split( X_windows, y_windows, test_size=0.2,
                                                   shuffle=False, random_state=42)


callbacks = [
    ModelCheckpoint('best_lstm_model_reg.keras', save_best_only=True, monitor='val_loss',verbose=1),
    EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True,verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=1e-6,verbose=1)
]

history = transfer_model.fit(
    X_windows, y_windows,
    validation_data=(X_val, y_val),
    epochs=600,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 200, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 200, 128)       │         2,176 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 200, 256)       │       263,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_norm_TL_1                 │ (None, 200, 256)       │           512 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_TL_1 (Dropout)          │ (None, 200, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bi_lstm_TL_1 (Bidirectional)    │ (None, 200, 64)        │        73,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_norm_TL_2                 │ (None, 200, 64)        │           128 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_TL_2 (Dropout)          │ (None, 200, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bi_lstm_TL_2 (Bidirectional)    │ (None, 64)             │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_TL_3 (Dropout)          │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_TL_1 (Dense)              │ (None, 50)             │         3,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 368,050 (1.40 MB)
#  Trainable params: 102,706 (401.20 KB)
#  Non-trainable params: 265,344 (1.01 MB)
# Epoch 1/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.6982 - mae: 0.4455
# Epoch 1: val_loss improved from inf to 0.56258, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 447ms/step - loss: 0.6955 - mae: 0.4432 - val_loss: 0.5626 - val_mae: 0.3242 - learning_rate: 0.0010
# Epoch 2/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.5803 - mae: 0.3467
# Epoch 2: val_loss improved from 0.56258 to 0.48789, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.5790 - mae: 0.3457 - val_loss: 0.4879 - val_mae: 0.2704 - learning_rate: 0.0010
# Epoch 3/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.5103 - mae: 0.2977
# Epoch 3: val_loss improved from 0.48789 to 0.41881, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.5095 - mae: 0.2972 - val_loss: 0.4188 - val_mae: 0.2221 - learning_rate: 0.0010
# Epoch 4/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4573 - mae: 0.2650
# Epoch 4: val_loss improved from 0.41881 to 0.36693, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.4565 - mae: 0.2646 - val_loss: 0.3669 - val_mae: 0.1891 - learning_rate: 0.0010
# Epoch 5/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4142 - mae: 0.2403
# Epoch 5: val_loss improved from 0.36693 to 0.32565, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.4136 - mae: 0.2400 - val_loss: 0.3256 - val_mae: 0.1646 - learning_rate: 0.0010
# Epoch 6/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3786 - mae: 0.2211
# Epoch 6: val_loss improved from 0.32565 to 0.29594, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.3782 - mae: 0.2210 - val_loss: 0.2959 - val_mae: 0.1498 - learning_rate: 0.0010
# Epoch 7/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3519 - mae: 0.2089
# Epoch 7: val_loss improved from 0.29594 to 0.26993, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.3516 - mae: 0.2088 - val_loss: 0.2699 - val_mae: 0.1369 - learning_rate: 0.0010
# Epoch 8/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3265 - mae: 0.1962
# Epoch 8: val_loss improved from 0.26993 to 0.25074, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.3263 - mae: 0.1962 - val_loss: 0.2507 - val_mae: 0.1293 - learning_rate: 0.0010
# Epoch 9/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3061 - mae: 0.1870
# Epoch 9: val_loss improved from 0.25074 to 0.23232, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.3059 - mae: 0.1870 - val_loss: 0.2323 - val_mae: 0.1211 - learning_rate: 0.0010
# Epoch 10/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2908 - mae: 0.1817
# Epoch 10: val_loss improved from 0.23232 to 0.21656, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.2906 - mae: 0.1816 - val_loss: 0.2166 - val_mae: 0.1142 - learning_rate: 0.0010
# Epoch 11/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2776 - mae: 0.1771
# Epoch 11: val_loss improved from 0.21656 to 0.20638, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.2773 - mae: 0.1770 - val_loss: 0.2064 - val_mae: 0.1118 - learning_rate: 0.0010
# Epoch 12/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2597 - mae: 0.1668
# Epoch 12: val_loss improved from 0.20638 to 0.19897, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.2596 - mae: 0.1668 - val_loss: 0.1990 - val_mae: 0.1113 - learning_rate: 0.0010
# Epoch 13/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2470 - mae: 0.1608
# Epoch 13: val_loss improved from 0.19897 to 0.19114, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.2470 - mae: 0.1609 - val_loss: 0.1911 - val_mae: 0.1096 - learning_rate: 0.0010
# Epoch 14/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2416 - mae: 0.1614
# Epoch 14: val_loss improved from 0.19114 to 0.17885, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.2415 - mae: 0.1614 - val_loss: 0.1788 - val_mae: 0.1027 - learning_rate: 0.0010
# Epoch 15/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2332 - mae: 0.1583
# Epoch 15: val_loss improved from 0.17885 to 0.17099, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.2332 - mae: 0.1583 - val_loss: 0.1710 - val_mae: 0.0997 - learning_rate: 0.0010
# Epoch 16/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2271 - mae: 0.1568
# Epoch 16: val_loss improved from 0.17099 to 0.16834, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.2271 - mae: 0.1568 - val_loss: 0.1683 - val_mae: 0.1013 - learning_rate: 0.0010
# Epoch 17/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2210 - mae: 0.1548
# Epoch 17: val_loss improved from 0.16834 to 0.16033, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.2209 - mae: 0.1548 - val_loss: 0.1603 - val_mae: 0.0971 - learning_rate: 0.0010
# Epoch 18/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2131 - mae: 0.1507
# Epoch 18: val_loss improved from 0.16033 to 0.15900, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.2130 - mae: 0.1506 - val_loss: 0.1590 - val_mae: 0.0992 - learning_rate: 0.0010
# Epoch 19/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2063 - mae: 0.1472
# Epoch 19: val_loss improved from 0.15900 to 0.14891, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.2064 - mae: 0.1474 - val_loss: 0.1489 - val_mae: 0.0923 - learning_rate: 0.0010
# Epoch 20/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2034 - mae: 0.1475
# Epoch 20: val_loss improved from 0.14891 to 0.14844, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.2033 - mae: 0.1475 - val_loss: 0.1484 - val_mae: 0.0948 - learning_rate: 0.0010
# Epoch 21/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2001 - mae: 0.1470
# Epoch 21: val_loss did not improve from 0.14844
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.2000 - mae: 0.1470 - val_loss: 0.1489 - val_mae: 0.0979 - learning_rate: 0.0010
# Epoch 22/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1962 - mae: 0.1457
# Epoch 22: val_loss improved from 0.14844 to 0.14257, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.1961 - mae: 0.1456 - val_loss: 0.1426 - val_mae: 0.0939 - learning_rate: 0.0010
# Epoch 23/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1888 - mae: 0.1406
# Epoch 23: val_loss improved from 0.14257 to 0.14136, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1888 - mae: 0.1406 - val_loss: 0.1414 - val_mae: 0.0948 - learning_rate: 0.0010
# Epoch 24/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1874 - mae: 0.1413
# Epoch 24: val_loss improved from 0.14136 to 0.14040, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.1874 - mae: 0.1413 - val_loss: 0.1404 - val_mae: 0.0958 - learning_rate: 0.0010
# Epoch 25/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1814 - mae: 0.1372
# Epoch 25: val_loss improved from 0.14040 to 0.13858, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.1814 - mae: 0.1373 - val_loss: 0.1386 - val_mae: 0.0959 - learning_rate: 0.0010
# Epoch 26/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1810 - mae: 0.1387
# Epoch 26: val_loss improved from 0.13858 to 0.13470, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.1810 - mae: 0.1387 - val_loss: 0.1347 - val_mae: 0.0938 - learning_rate: 0.0010
# Epoch 27/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1780 - mae: 0.1374
# Epoch 27: val_loss improved from 0.13470 to 0.13309, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1781 - mae: 0.1375 - val_loss: 0.1331 - val_mae: 0.0938 - learning_rate: 0.0010
# Epoch 28/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1721 - mae: 0.1331
# Epoch 28: val_loss improved from 0.13309 to 0.12805, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1722 - mae: 0.1332 - val_loss: 0.1281 - val_mae: 0.0901 - learning_rate: 0.0010
# Epoch 29/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1728 - mae: 0.1352
# Epoch 29: val_loss improved from 0.12805 to 0.12291, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1728 - mae: 0.1352 - val_loss: 0.1229 - val_mae: 0.0863 - learning_rate: 0.0010
# Epoch 30/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1713 - mae: 0.1350
# Epoch 30: val_loss did not improve from 0.12291
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1714 - mae: 0.1351 - val_loss: 0.1269 - val_mae: 0.0916 - learning_rate: 0.0010
# Epoch 31/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1676 - mae: 0.1326
# Epoch 31: val_loss improved from 0.12291 to 0.12185, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1676 - mae: 0.1326 - val_loss: 0.1218 - val_mae: 0.0878 - learning_rate: 0.0010
# Epoch 32/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1641 - mae: 0.1303
# Epoch 32: val_loss improved from 0.12185 to 0.12098, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1640 - mae: 0.1302 - val_loss: 0.1210 - val_mae: 0.0880 - learning_rate: 0.0010
# Epoch 33/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1676 - mae: 0.1349
# Epoch 33: val_loss did not improve from 0.12098
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1675 - mae: 0.1348 - val_loss: 0.1234 - val_mae: 0.0915 - learning_rate: 0.0010
# Epoch 34/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1630 - mae: 0.1313
# Epoch 34: val_loss improved from 0.12098 to 0.11876, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.1630 - mae: 0.1313 - val_loss: 0.1188 - val_mae: 0.0878 - learning_rate: 0.0010
# Epoch 35/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1611 - mae: 0.1302
# Epoch 35: val_loss improved from 0.11876 to 0.11774, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1611 - mae: 0.1303 - val_loss: 0.1177 - val_mae: 0.0877 - learning_rate: 0.0010
# Epoch 36/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1595 - mae: 0.1297
# Epoch 36: val_loss improved from 0.11774 to 0.11711, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1597 - mae: 0.1298 - val_loss: 0.1171 - val_mae: 0.0879 - learning_rate: 0.0010
# Epoch 37/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1580 - mae: 0.1290
# Epoch 37: val_loss improved from 0.11711 to 0.11535, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1581 - mae: 0.1291 - val_loss: 0.1153 - val_mae: 0.0869 - learning_rate: 0.0010
# Epoch 38/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1576 - mae: 0.1293
# Epoch 38: val_loss improved from 0.11535 to 0.11136, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1576 - mae: 0.1293 - val_loss: 0.1114 - val_mae: 0.0837 - learning_rate: 0.0010
# Epoch 39/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1545 - mae: 0.1270
# Epoch 39: val_loss did not improve from 0.11136
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1545 - mae: 0.1271 - val_loss: 0.1147 - val_mae: 0.0878 - learning_rate: 0.0010
# Epoch 40/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1515 - mae: 0.1247
# Epoch 40: val_loss did not improve from 0.11136
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1516 - mae: 0.1249 - val_loss: 0.1163 - val_mae: 0.0902 - learning_rate: 0.0010
# Epoch 41/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1499 - mae: 0.1238
# Epoch 41: val_loss did not improve from 0.11136
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1499 - mae: 0.1238 - val_loss: 0.1116 - val_mae: 0.0860 - learning_rate: 0.0010
# Epoch 42/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1529 - mae: 0.1275
# Epoch 42: val_loss did not improve from 0.11136
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1528 - mae: 0.1274 - val_loss: 0.1161 - val_mae: 0.0912 - learning_rate: 0.0010
# Epoch 43/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1493 - mae: 0.1245
# Epoch 43: val_loss did not improve from 0.11136
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1492 - mae: 0.1244 - val_loss: 0.1120 - val_mae: 0.0877 - learning_rate: 0.0010
# Epoch 44/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1487 - mae: 0.1245
# Epoch 44: val_loss improved from 0.11136 to 0.10927, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1487 - mae: 0.1245 - val_loss: 0.1093 - val_mae: 0.0855 - learning_rate: 0.0010
# Epoch 45/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1470 - mae: 0.1233
# Epoch 45: val_loss improved from 0.10927 to 0.10461, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.1471 - mae: 0.1234 - val_loss: 0.1046 - val_mae: 0.0814 - learning_rate: 0.0010
# Epoch 46/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1475 - mae: 0.1244
# Epoch 46: val_loss did not improve from 0.10461
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1475 - mae: 0.1243 - val_loss: 0.1070 - val_mae: 0.0843 - learning_rate: 0.0010
# Epoch 47/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1443 - mae: 0.1217
# Epoch 47: val_loss did not improve from 0.10461
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1446 - mae: 0.1220 - val_loss: 0.1054 - val_mae: 0.0832 - learning_rate: 0.0010
# Epoch 48/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1469 - mae: 0.1248
# Epoch 48: val_loss did not improve from 0.10461
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1469 - mae: 0.1247 - val_loss: 0.1142 - val_mae: 0.0924 - learning_rate: 0.0010
# Epoch 49/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1490 - mae: 0.1273
# Epoch 49: val_loss did not improve from 0.10461
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1489 - mae: 0.1271 - val_loss: 0.1062 - val_mae: 0.0847 - learning_rate: 0.0010
# Epoch 50/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1438 - mae: 0.1224
# Epoch 50: val_loss improved from 0.10461 to 0.10054, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1439 - mae: 0.1225 - val_loss: 0.1005 - val_mae: 0.0795 - learning_rate: 0.0010
# Epoch 51/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1425 - mae: 0.1215
# Epoch 51: val_loss did not improve from 0.10054
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1426 - mae: 0.1217 - val_loss: 0.1055 - val_mae: 0.0848 - learning_rate: 0.0010
# Epoch 52/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1439 - mae: 0.1233
# Epoch 52: val_loss did not improve from 0.10054
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1438 - mae: 0.1233 - val_loss: 0.1030 - val_mae: 0.0827 - learning_rate: 0.0010
# Epoch 53/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1396 - mae: 0.1194
# Epoch 53: val_loss did not improve from 0.10054
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1397 - mae: 0.1195 - val_loss: 0.1012 - val_mae: 0.0813 - learning_rate: 0.0010
# Epoch 54/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1446 - mae: 0.1248
# Epoch 54: val_loss did not improve from 0.10054
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1445 - mae: 0.1247 - val_loss: 0.1012 - val_mae: 0.0816 - learning_rate: 0.0010
# Epoch 55/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1420 - mae: 0.1225
# Epoch 55: val_loss did not improve from 0.10054
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1420 - mae: 0.1226 - val_loss: 0.1006 - val_mae: 0.0814 - learning_rate: 0.0010
# Epoch 56/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1378 - mae: 0.1187
# Epoch 56: val_loss did not improve from 0.10054
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1378 - mae: 0.1187 - val_loss: 0.1031 - val_mae: 0.0842 - learning_rate: 0.0010
# Epoch 57/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1410 - mae: 0.1222
# Epoch 57: val_loss did not improve from 0.10054
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1410 - mae: 0.1222 - val_loss: 0.1033 - val_mae: 0.0848 - learning_rate: 0.0010
# Epoch 58/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1391 - mae: 0.1207
# Epoch 58: val_loss improved from 0.10054 to 0.09925, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1390 - mae: 0.1206 - val_loss: 0.0993 - val_mae: 0.0810 - learning_rate: 0.0010
# Epoch 59/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1403 - mae: 0.1221
# Epoch 59: val_loss improved from 0.09925 to 0.09676, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1402 - mae: 0.1220 - val_loss: 0.0968 - val_mae: 0.0788 - learning_rate: 0.0010
# Epoch 60/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1362 - mae: 0.1183
# Epoch 60: val_loss did not improve from 0.09676
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1362 - mae: 0.1183 - val_loss: 0.0985 - val_mae: 0.0808 - learning_rate: 0.0010
# Epoch 61/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1345 - mae: 0.1169
# Epoch 61: val_loss did not improve from 0.09676
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1346 - mae: 0.1170 - val_loss: 0.0993 - val_mae: 0.0820 - learning_rate: 0.0010
# Epoch 62/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1354 - mae: 0.1181
# Epoch 62: val_loss improved from 0.09676 to 0.09667, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1354 - mae: 0.1181 - val_loss: 0.0967 - val_mae: 0.0795 - learning_rate: 0.0010
# Epoch 63/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1327 - mae: 0.1156
# Epoch 63: val_loss did not improve from 0.09667
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1328 - mae: 0.1157 - val_loss: 0.0969 - val_mae: 0.0800 - learning_rate: 0.0010
# Epoch 64/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1314 - mae: 0.1145
# Epoch 64: val_loss did not improve from 0.09667
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1316 - mae: 0.1147 - val_loss: 0.1011 - val_mae: 0.0845 - learning_rate: 0.0010
# Epoch 65/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1338 - mae: 0.1172
# Epoch 65: val_loss did not improve from 0.09667
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1338 - mae: 0.1172 - val_loss: 0.0976 - val_mae: 0.0812 - learning_rate: 0.0010
# Epoch 66/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1359 - mae: 0.1195
# Epoch 66: val_loss improved from 0.09667 to 0.09538, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1359 - mae: 0.1195 - val_loss: 0.0954 - val_mae: 0.0793 - learning_rate: 0.0010
# Epoch 67/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1323 - mae: 0.1162
# Epoch 67: val_loss did not improve from 0.09538
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1324 - mae: 0.1163 - val_loss: 0.1009 - val_mae: 0.0850 - learning_rate: 0.0010
# Epoch 68/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1313 - mae: 0.1154
# Epoch 68: val_loss improved from 0.09538 to 0.09466, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1313 - mae: 0.1155 - val_loss: 0.0947 - val_mae: 0.0790 - learning_rate: 0.0010
# Epoch 69/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1330 - mae: 0.1174
# Epoch 69: val_loss did not improve from 0.09466
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1330 - mae: 0.1173 - val_loss: 0.0998 - val_mae: 0.0842 - learning_rate: 0.0010
# Epoch 70/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1345 - mae: 0.1190
# Epoch 70: val_loss did not improve from 0.09466
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1344 - mae: 0.1189 - val_loss: 0.0957 - val_mae: 0.0803 - learning_rate: 0.0010
# Epoch 71/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1312 - mae: 0.1159
# Epoch 71: val_loss improved from 0.09466 to 0.09462, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1313 - mae: 0.1160 - val_loss: 0.0946 - val_mae: 0.0794 - learning_rate: 0.0010
# Epoch 72/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1290 - mae: 0.1138
# Epoch 72: val_loss did not improve from 0.09462
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1291 - mae: 0.1139 - val_loss: 0.0960 - val_mae: 0.0810 - learning_rate: 0.0010
# Epoch 73/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1320 - mae: 0.1170
# Epoch 73: val_loss improved from 0.09462 to 0.09406, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1319 - mae: 0.1170 - val_loss: 0.0941 - val_mae: 0.0792 - learning_rate: 0.0010
# Epoch 74/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1333 - mae: 0.1185
# Epoch 74: val_loss did not improve from 0.09406
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1332 - mae: 0.1184 - val_loss: 0.0958 - val_mae: 0.0812 - learning_rate: 0.0010
# Epoch 75/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1321 - mae: 0.1175
# Epoch 75: val_loss did not improve from 0.09406
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1320 - mae: 0.1175 - val_loss: 0.0941 - val_mae: 0.0797 - learning_rate: 0.0010
# Epoch 76/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1305 - mae: 0.1161
# Epoch 76: val_loss did not improve from 0.09406
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1307 - mae: 0.1162 - val_loss: 0.1030 - val_mae: 0.0887 - learning_rate: 0.0010
# Epoch 77/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1294 - mae: 0.1152
# Epoch 77: val_loss improved from 0.09406 to 0.09321, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1293 - mae: 0.1151 - val_loss: 0.0932 - val_mae: 0.0790 - learning_rate: 0.0010
# Epoch 78/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1265 - mae: 0.1124
# Epoch 78: val_loss improved from 0.09321 to 0.09150, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.1265 - mae: 0.1124 - val_loss: 0.0915 - val_mae: 0.0775 - learning_rate: 0.0010
# Epoch 79/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1278 - mae: 0.1138
# Epoch 79: val_loss did not improve from 0.09150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1278 - mae: 0.1138 - val_loss: 0.0923 - val_mae: 0.0785 - learning_rate: 0.0010
# Epoch 80/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1297 - mae: 0.1160
# Epoch 80: val_loss did not improve from 0.09150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1299 - mae: 0.1161 - val_loss: 0.0951 - val_mae: 0.0814 - learning_rate: 0.0010
# Epoch 81/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1301 - mae: 0.1165
# Epoch 81: val_loss did not improve from 0.09150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1302 - mae: 0.1165 - val_loss: 0.0931 - val_mae: 0.0795 - learning_rate: 0.0010
# Epoch 82/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1269 - mae: 0.1133
# Epoch 82: val_loss did not improve from 0.09150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1270 - mae: 0.1135 - val_loss: 0.0962 - val_mae: 0.0827 - learning_rate: 0.0010
# Epoch 83/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1264 - mae: 0.1129
# Epoch 83: val_loss improved from 0.09150 to 0.08846, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1265 - mae: 0.1130 - val_loss: 0.0885 - val_mae: 0.0751 - learning_rate: 0.0010
# Epoch 84/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1285 - mae: 0.1151
# Epoch 84: val_loss did not improve from 0.08846
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1284 - mae: 0.1150 - val_loss: 0.0920 - val_mae: 0.0787 - learning_rate: 0.0010
# Epoch 85/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1293 - mae: 0.1161
# Epoch 85: val_loss did not improve from 0.08846
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1292 - mae: 0.1159 - val_loss: 0.0940 - val_mae: 0.0808 - learning_rate: 0.0010
# Epoch 86/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1275 - mae: 0.1144
# Epoch 86: val_loss did not improve from 0.08846
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1275 - mae: 0.1144 - val_loss: 0.0905 - val_mae: 0.0774 - learning_rate: 0.0010
# Epoch 87/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1295 - mae: 0.1165
# Epoch 87: val_loss did not improve from 0.08846
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1295 - mae: 0.1164 - val_loss: 0.0934 - val_mae: 0.0804 - learning_rate: 0.0010
# Epoch 88/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1202 - mae: 0.1072
# Epoch 88: val_loss did not improve from 0.08846
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1203 - mae: 0.1074 - val_loss: 0.0904 - val_mae: 0.0776 - learning_rate: 0.0010
# Epoch 89/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1220 - mae: 0.1092
# Epoch 89: val_loss did not improve from 0.08846
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.1221 - mae: 0.1093 - val_loss: 0.0887 - val_mae: 0.0760 - learning_rate: 0.0010
# Epoch 90/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1257 - mae: 0.1130
# Epoch 90: val_loss improved from 0.08846 to 0.08718, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.1257 - mae: 0.1130 - val_loss: 0.0872 - val_mae: 0.0747 - learning_rate: 0.0010
# Epoch 91/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1235 - mae: 0.1110
# Epoch 91: val_loss did not improve from 0.08718
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1236 - mae: 0.1111 - val_loss: 0.0900 - val_mae: 0.0776 - learning_rate: 0.0010
# Epoch 92/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1267 - mae: 0.1143
# Epoch 92: val_loss did not improve from 0.08718
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1267 - mae: 0.1143 - val_loss: 0.0926 - val_mae: 0.0803 - learning_rate: 0.0010
# Epoch 93/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1281 - mae: 0.1158
# Epoch 93: val_loss did not improve from 0.08718
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1280 - mae: 0.1157 - val_loss: 0.0888 - val_mae: 0.0766 - learning_rate: 0.0010
# Epoch 94/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1220 - mae: 0.1098
# Epoch 94: val_loss improved from 0.08718 to 0.08671, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1222 - mae: 0.1100 - val_loss: 0.0867 - val_mae: 0.0746 - learning_rate: 0.0010
# Epoch 95/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1269 - mae: 0.1148
# Epoch 95: val_loss did not improve from 0.08671
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1268 - mae: 0.1147 - val_loss: 0.0957 - val_mae: 0.0837 - learning_rate: 0.0010
# Epoch 96/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1270 - mae: 0.1150
# Epoch 96: val_loss did not improve from 0.08671
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1270 - mae: 0.1149 - val_loss: 0.0896 - val_mae: 0.0776 - learning_rate: 0.0010
# Epoch 97/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1258 - mae: 0.1138
# Epoch 97: val_loss did not improve from 0.08671
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1258 - mae: 0.1138 - val_loss: 0.0912 - val_mae: 0.0793 - learning_rate: 0.0010
# Epoch 98/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1249 - mae: 0.1129
# Epoch 98: val_loss did not improve from 0.08671
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1249 - mae: 0.1130 - val_loss: 0.0869 - val_mae: 0.0750 - learning_rate: 0.0010
# Epoch 99/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1216 - mae: 0.1097
# Epoch 99: val_loss did not improve from 0.08671
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1217 - mae: 0.1098 - val_loss: 0.0897 - val_mae: 0.0779 - learning_rate: 0.0010
# Epoch 100/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1234 - mae: 0.1117
# Epoch 100: val_loss did not improve from 0.08671
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1235 - mae: 0.1117 - val_loss: 0.0977 - val_mae: 0.0861 - learning_rate: 0.0010
# Epoch 101/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1248 - mae: 0.1131
# Epoch 101: val_loss did not improve from 0.08671
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1249 - mae: 0.1132 - val_loss: 0.0872 - val_mae: 0.0756 - learning_rate: 0.0010
# Epoch 102/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1262 - mae: 0.1146
# Epoch 102: val_loss did not improve from 0.08671
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1262 - mae: 0.1145 - val_loss: 0.0889 - val_mae: 0.0773 - learning_rate: 0.0010
# Epoch 103/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1237 - mae: 0.1121
# Epoch 103: val_loss did not improve from 0.08671
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1238 - mae: 0.1122 - val_loss: 0.0905 - val_mae: 0.0789 - learning_rate: 0.0010
# Epoch 104/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1246 - mae: 0.1131
# Epoch 104: val_loss did not improve from 0.08671
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1246 - mae: 0.1130 - val_loss: 0.0871 - val_mae: 0.0756 - learning_rate: 0.0010
# Epoch 105/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1236 - mae: 0.1121
# Epoch 105: val_loss improved from 0.08671 to 0.08469, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1237 - mae: 0.1122 - val_loss: 0.0847 - val_mae: 0.0733 - learning_rate: 0.0010
# Epoch 106/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1170 - mae: 0.1056
# Epoch 106: val_loss did not improve from 0.08469
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1173 - mae: 0.1059 - val_loss: 0.0893 - val_mae: 0.0780 - learning_rate: 0.0010
# Epoch 107/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1204 - mae: 0.1091
# Epoch 107: val_loss did not improve from 0.08469
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1204 - mae: 0.1091 - val_loss: 0.0880 - val_mae: 0.0768 - learning_rate: 0.0010
# Epoch 108/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1217 - mae: 0.1105
# Epoch 108: val_loss did not improve from 0.08469
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1217 - mae: 0.1105 - val_loss: 0.0849 - val_mae: 0.0739 - learning_rate: 0.0010
# Epoch 109/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1195 - mae: 0.1084
# Epoch 109: val_loss improved from 0.08469 to 0.08416, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1195 - mae: 0.1084 - val_loss: 0.0842 - val_mae: 0.0731 - learning_rate: 0.0010
# Epoch 110/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1203 - mae: 0.1092
# Epoch 110: val_loss did not improve from 0.08416
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1204 - mae: 0.1094 - val_loss: 0.0859 - val_mae: 0.0749 - learning_rate: 0.0010
# Epoch 111/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1181 - mae: 0.1071
# Epoch 111: val_loss did not improve from 0.08416
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1182 - mae: 0.1073 - val_loss: 0.0890 - val_mae: 0.0782 - learning_rate: 0.0010
# Epoch 112/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1218 - mae: 0.1110
# Epoch 112: val_loss did not improve from 0.08416
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1218 - mae: 0.1110 - val_loss: 0.0906 - val_mae: 0.0799 - learning_rate: 0.0010
# Epoch 113/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1236 - mae: 0.1129
# Epoch 113: val_loss did not improve from 0.08416
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1236 - mae: 0.1129 - val_loss: 0.0904 - val_mae: 0.0797 - learning_rate: 0.0010
# Epoch 114/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1226 - mae: 0.1118
# Epoch 114: val_loss did not improve from 0.08416
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1225 - mae: 0.1117 - val_loss: 0.0911 - val_mae: 0.0803 - learning_rate: 0.0010
# Epoch 115/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1225 - mae: 0.1117
# Epoch 115: val_loss improved from 0.08416 to 0.08363, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1224 - mae: 0.1116 - val_loss: 0.0836 - val_mae: 0.0729 - learning_rate: 0.0010
# Epoch 116/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1203 - mae: 0.1096
# Epoch 116: val_loss did not improve from 0.08363
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1203 - mae: 0.1096 - val_loss: 0.0857 - val_mae: 0.0750 - learning_rate: 0.0010
# Epoch 117/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1208 - mae: 0.1101
# Epoch 117: val_loss improved from 0.08363 to 0.08265, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1207 - mae: 0.1101 - val_loss: 0.0826 - val_mae: 0.0721 - learning_rate: 0.0010
# Epoch 118/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1220 - mae: 0.1115
# Epoch 118: val_loss did not improve from 0.08265
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1220 - mae: 0.1114 - val_loss: 0.0864 - val_mae: 0.0759 - learning_rate: 0.0010
# Epoch 119/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1185 - mae: 0.1080
# Epoch 119: val_loss did not improve from 0.08265
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1186 - mae: 0.1081 - val_loss: 0.0867 - val_mae: 0.0762 - learning_rate: 0.0010
# Epoch 120/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1177 - mae: 0.1072
# Epoch 120: val_loss did not improve from 0.08265
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1178 - mae: 0.1073 - val_loss: 0.0869 - val_mae: 0.0764 - learning_rate: 0.0010
# Epoch 121/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1196 - mae: 0.1092
# Epoch 121: val_loss did not improve from 0.08265
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1197 - mae: 0.1092 - val_loss: 0.0845 - val_mae: 0.0741 - learning_rate: 0.0010
# Epoch 122/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1218 - mae: 0.1114
# Epoch 122: val_loss did not improve from 0.08265
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1218 - mae: 0.1114 - val_loss: 0.0838 - val_mae: 0.0734 - learning_rate: 0.0010
# Epoch 123/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1217 - mae: 0.1113
# Epoch 123: val_loss did not improve from 0.08265
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1217 - mae: 0.1113 - val_loss: 0.0889 - val_mae: 0.0785 - learning_rate: 0.0010
# Epoch 124/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1199 - mae: 0.1095
# Epoch 124: val_loss did not improve from 0.08265
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1199 - mae: 0.1095 - val_loss: 0.0866 - val_mae: 0.0763 - learning_rate: 0.0010
# Epoch 125/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1205 - mae: 0.1102
# Epoch 125: val_loss did not improve from 0.08265
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1204 - mae: 0.1101 - val_loss: 0.0880 - val_mae: 0.0778 - learning_rate: 0.0010
# Epoch 126/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1209 - mae: 0.1106
# Epoch 126: val_loss improved from 0.08265 to 0.08218, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1209 - mae: 0.1106 - val_loss: 0.0822 - val_mae: 0.0720 - learning_rate: 0.0010
# Epoch 127/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1207 - mae: 0.1106
# Epoch 127: val_loss did not improve from 0.08218
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1207 - mae: 0.1105 - val_loss: 0.0851 - val_mae: 0.0750 - learning_rate: 0.0010
# Epoch 128/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1185 - mae: 0.1084
# Epoch 128: val_loss improved from 0.08218 to 0.08013, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1185 - mae: 0.1084 - val_loss: 0.0801 - val_mae: 0.0701 - learning_rate: 0.0010
# Epoch 129/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1181 - mae: 0.1081
# Epoch 129: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1180 - mae: 0.1080 - val_loss: 0.0850 - val_mae: 0.0751 - learning_rate: 0.0010
# Epoch 130/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1205 - mae: 0.1106
# Epoch 130: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1205 - mae: 0.1106 - val_loss: 0.0868 - val_mae: 0.0770 - learning_rate: 0.0010
# Epoch 131/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1171 - mae: 0.1073
# Epoch 131: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1171 - mae: 0.1073 - val_loss: 0.0810 - val_mae: 0.0712 - learning_rate: 0.0010
# Epoch 132/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1169 - mae: 0.1071
# Epoch 132: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1170 - mae: 0.1072 - val_loss: 0.0855 - val_mae: 0.0757 - learning_rate: 0.0010
# Epoch 133/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1157 - mae: 0.1060
# Epoch 133: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1159 - mae: 0.1061 - val_loss: 0.0827 - val_mae: 0.0730 - learning_rate: 0.0010
# Epoch 134/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1183 - mae: 0.1086
# Epoch 134: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1184 - mae: 0.1087 - val_loss: 0.0817 - val_mae: 0.0720 - learning_rate: 0.0010
# Epoch 135/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1193 - mae: 0.1096
# Epoch 135: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1194 - mae: 0.1097 - val_loss: 0.0832 - val_mae: 0.0736 - learning_rate: 0.0010
# Epoch 136/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1178 - mae: 0.1081
# Epoch 136: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1177 - mae: 0.1081 - val_loss: 0.0825 - val_mae: 0.0729 - learning_rate: 0.0010
# Epoch 137/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1189 - mae: 0.1093
# Epoch 137: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1189 - mae: 0.1093 - val_loss: 0.0867 - val_mae: 0.0772 - learning_rate: 0.0010
# Epoch 138/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1140 - mae: 0.1044
# Epoch 138: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1142 - mae: 0.1046 - val_loss: 0.0810 - val_mae: 0.0714 - learning_rate: 0.0010
# Epoch 139/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1188 - mae: 0.1093
# Epoch 139: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1188 - mae: 0.1092 - val_loss: 0.0851 - val_mae: 0.0756 - learning_rate: 0.0010
# Epoch 140/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1150 - mae: 0.1055
# Epoch 140: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1152 - mae: 0.1057 - val_loss: 0.0836 - val_mae: 0.0741 - learning_rate: 0.0010
# Epoch 141/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1183 - mae: 0.1088
# Epoch 141: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1182 - mae: 0.1087 - val_loss: 0.0809 - val_mae: 0.0714 - learning_rate: 0.0010
# Epoch 142/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1171 - mae: 0.1077
# Epoch 142: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1173 - mae: 0.1079 - val_loss: 0.0842 - val_mae: 0.0749 - learning_rate: 0.0010
# Epoch 143/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1167 - mae: 0.1073
# Epoch 143: val_loss improved from 0.08013 to 0.08013, saving model to best_lstm_model_reg.keras
#
# Epoch 143: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1168 - mae: 0.1075 - val_loss: 0.0801 - val_mae: 0.0707 - learning_rate: 0.0010
# Epoch 144/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1185 - mae: 0.1091
# Epoch 144: val_loss did not improve from 0.08013
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1184 - mae: 0.1090 - val_loss: 0.0804 - val_mae: 0.0711 - learning_rate: 5.0000e-04
# Epoch 145/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1155 - mae: 0.1062
# Epoch 145: val_loss improved from 0.08013 to 0.07853, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1155 - mae: 0.1062 - val_loss: 0.0785 - val_mae: 0.0693 - learning_rate: 5.0000e-04
# Epoch 146/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1158 - mae: 0.1066
# Epoch 146: val_loss improved from 0.07853 to 0.07610, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1157 - mae: 0.1064 - val_loss: 0.0761 - val_mae: 0.0670 - learning_rate: 5.0000e-04
# Epoch 147/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1137 - mae: 0.1046
# Epoch 147: val_loss did not improve from 0.07610
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1138 - mae: 0.1047 - val_loss: 0.0785 - val_mae: 0.0694 - learning_rate: 5.0000e-04
# Epoch 148/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1123 - mae: 0.1032
# Epoch 148: val_loss did not improve from 0.07610
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1123 - mae: 0.1033 - val_loss: 0.0766 - val_mae: 0.0677 - learning_rate: 5.0000e-04
# Epoch 149/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1127 - mae: 0.1037
# Epoch 149: val_loss improved from 0.07610 to 0.07606, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1127 - mae: 0.1037 - val_loss: 0.0761 - val_mae: 0.0672 - learning_rate: 5.0000e-04
# Epoch 150/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1114 - mae: 0.1026
# Epoch 150: val_loss did not improve from 0.07606
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1115 - mae: 0.1026 - val_loss: 0.0796 - val_mae: 0.0708 - learning_rate: 5.0000e-04
# Epoch 151/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1134 - mae: 0.1046
# Epoch 151: val_loss did not improve from 0.07606
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1132 - mae: 0.1044 - val_loss: 0.0767 - val_mae: 0.0679 - learning_rate: 5.0000e-04
# Epoch 152/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1086 - mae: 0.0998
# Epoch 152: val_loss did not improve from 0.07606
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1087 - mae: 0.0999 - val_loss: 0.0766 - val_mae: 0.0679 - learning_rate: 5.0000e-04
# Epoch 153/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1118 - mae: 0.1031
# Epoch 153: val_loss did not improve from 0.07606
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1118 - mae: 0.1031 - val_loss: 0.0769 - val_mae: 0.0682 - learning_rate: 5.0000e-04
# Epoch 154/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1096 - mae: 0.1009
# Epoch 154: val_loss did not improve from 0.07606
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1096 - mae: 0.1009 - val_loss: 0.0792 - val_mae: 0.0706 - learning_rate: 5.0000e-04
# Epoch 155/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1123 - mae: 0.1037
# Epoch 155: val_loss improved from 0.07606 to 0.07597, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1123 - mae: 0.1037 - val_loss: 0.0760 - val_mae: 0.0674 - learning_rate: 5.0000e-04
# Epoch 156/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1106 - mae: 0.1020
# Epoch 156: val_loss did not improve from 0.07597
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1107 - mae: 0.1021 - val_loss: 0.0767 - val_mae: 0.0681 - learning_rate: 5.0000e-04
# Epoch 157/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1103 - mae: 0.1017
# Epoch 157: val_loss improved from 0.07597 to 0.07561, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1105 - mae: 0.1019 - val_loss: 0.0756 - val_mae: 0.0671 - learning_rate: 5.0000e-04
# Epoch 158/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1116 - mae: 0.1031
# Epoch 158: val_loss did not improve from 0.07561
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1116 - mae: 0.1030 - val_loss: 0.0809 - val_mae: 0.0724 - learning_rate: 5.0000e-04
# Epoch 159/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1113 - mae: 0.1028
# Epoch 159: val_loss improved from 0.07561 to 0.07482, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1112 - mae: 0.1027 - val_loss: 0.0748 - val_mae: 0.0663 - learning_rate: 5.0000e-04
# Epoch 160/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1072 - mae: 0.0987
# Epoch 160: val_loss did not improve from 0.07482
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1073 - mae: 0.0988 - val_loss: 0.0751 - val_mae: 0.0666 - learning_rate: 5.0000e-04
# Epoch 161/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1112 - mae: 0.1027
# Epoch 161: val_loss improved from 0.07482 to 0.07363, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1112 - mae: 0.1027 - val_loss: 0.0736 - val_mae: 0.0652 - learning_rate: 5.0000e-04
# Epoch 162/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1101 - mae: 0.1016
# Epoch 162: val_loss did not improve from 0.07363
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1100 - mae: 0.1016 - val_loss: 0.0757 - val_mae: 0.0674 - learning_rate: 5.0000e-04
# Epoch 163/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1078 - mae: 0.0994
# Epoch 163: val_loss did not improve from 0.07363
# ...
# Epoch 415/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0937 - mae: 0.0874
# Epoch 415: val_loss did not improve from 0.05973
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0938 - mae: 0.0874 - val_loss: 0.0599 - val_mae: 0.0535 - learning_rate: 7.8125e-06
# Epoch 416/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0956 - mae: 0.0892
# Epoch 416: val_loss did not improve from 0.05973
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0956 - mae: 0.0892 - val_loss: 0.0599 - val_mae: 0.0535 - learning_rate: 7.8125e-06
# Epoch 417/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0960 - mae: 0.0896
# Epoch 417: val_loss did not improve from 0.05973
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0960 - mae: 0.0896 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 7.8125e-06
# Epoch 418/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0939 - mae: 0.0876
# Epoch 418: val_loss did not improve from 0.05973
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0939 - mae: 0.0875 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 7.8125e-06
# Epoch 419/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0933 - mae: 0.0870
# Epoch 419: val_loss did not improve from 0.05973
#
# Epoch 419: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0933 - mae: 0.0869 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 7.8125e-06
# Epoch 420/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0959 - mae: 0.0895
# Epoch 420: val_loss improved from 0.05973 to 0.05971, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0959 - mae: 0.0895 - val_loss: 0.0597 - val_mae: 0.0533 - learning_rate: 3.9063e-06
# Epoch 421/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0940 - mae: 0.0876
# Epoch 421: val_loss improved from 0.05971 to 0.05960, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0941 - mae: 0.0877 - val_loss: 0.0596 - val_mae: 0.0532 - learning_rate: 3.9063e-06
# Epoch 422/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0923 - mae: 0.0859
# Epoch 422: val_loss improved from 0.05960 to 0.05948, saving model to best_lstm_model_reg.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0923 - mae: 0.0859 - val_loss: 0.0595 - val_mae: 0.0531 - learning_rate: 3.9063e-06
# Epoch 423/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0927 - mae: 0.0863
# Epoch 423: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0928 - mae: 0.0864 - val_loss: 0.0595 - val_mae: 0.0531 - learning_rate: 3.9063e-06
# Epoch 424/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0967 - mae: 0.0903
# Epoch 424: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0967 - mae: 0.0903 - val_loss: 0.0596 - val_mae: 0.0533 - learning_rate: 3.9063e-06
# Epoch 425/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0955 - mae: 0.0891
# Epoch 425: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0955 - mae: 0.0891 - val_loss: 0.0597 - val_mae: 0.0533 - learning_rate: 3.9063e-06
# Epoch 426/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0984 - mae: 0.0920
# Epoch 426: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0983 - mae: 0.0919 - val_loss: 0.0597 - val_mae: 0.0533 - learning_rate: 3.9063e-06
# Epoch 427/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0935 - mae: 0.0871
# Epoch 427: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0934 - mae: 0.0870 - val_loss: 0.0597 - val_mae: 0.0533 - learning_rate: 3.9063e-06
# Epoch 428/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0964 - mae: 0.0901
# Epoch 428: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0964 - mae: 0.0900 - val_loss: 0.0597 - val_mae: 0.0533 - learning_rate: 3.9063e-06
# Epoch 429/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0968 - mae: 0.0904
# Epoch 429: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0967 - mae: 0.0903 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 3.9063e-06
# Epoch 430/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0952 - mae: 0.0888
# Epoch 430: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0952 - mae: 0.0888 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 3.9063e-06
# Epoch 431/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0967 - mae: 0.0903
# Epoch 431: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0966 - mae: 0.0903 - val_loss: 0.0597 - val_mae: 0.0533 - learning_rate: 3.9063e-06
# Epoch 432/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0931 - mae: 0.0867
# Epoch 432: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0931 - mae: 0.0867 - val_loss: 0.0598 - val_mae: 0.0535 - learning_rate: 3.9063e-06
# Epoch 433/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0954 - mae: 0.0890
# Epoch 433: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0955 - mae: 0.0891 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 3.9063e-06
# Epoch 434/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0943 - mae: 0.0879
# Epoch 434: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0942 - mae: 0.0878 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 3.9063e-06
# Epoch 435/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0990 - mae: 0.0926
# Epoch 435: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0988 - mae: 0.0924 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 3.9063e-06
# Epoch 436/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0938 - mae: 0.0874
# Epoch 436: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0939 - mae: 0.0875 - val_loss: 0.0597 - val_mae: 0.0533 - learning_rate: 3.9063e-06
# Epoch 437/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0945 - mae: 0.0882
# Epoch 437: val_loss did not improve from 0.05948
#
# Epoch 437: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0945 - mae: 0.0882 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 3.9063e-06
# Epoch 438/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0955 - mae: 0.0891
# Epoch 438: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0955 - mae: 0.0891 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.9531e-06
# Epoch 439/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0945 - mae: 0.0881
# Epoch 439: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0945 - mae: 0.0882 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.9531e-06
# Epoch 440/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0956 - mae: 0.0892
# Epoch 440: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0955 - mae: 0.0891 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.9531e-06
# Epoch 441/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0950 - mae: 0.0886
# Epoch 441: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0950 - mae: 0.0886 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.9531e-06
# Epoch 442/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0949 - mae: 0.0885
# Epoch 442: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0949 - mae: 0.0885 - val_loss: 0.0599 - val_mae: 0.0535 - learning_rate: 1.9531e-06
# Epoch 443/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0926 - mae: 0.0862
# Epoch 443: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0926 - mae: 0.0862 - val_loss: 0.0599 - val_mae: 0.0535 - learning_rate: 1.9531e-06
# Epoch 444/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0950 - mae: 0.0886
# Epoch 444: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0950 - mae: 0.0887 - val_loss: 0.0599 - val_mae: 0.0535 - learning_rate: 1.9531e-06
# Epoch 445/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0948 - mae: 0.0884
# Epoch 445: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0948 - mae: 0.0884 - val_loss: 0.0598 - val_mae: 0.0535 - learning_rate: 1.9531e-06
# Epoch 446/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0954 - mae: 0.0890
# Epoch 446: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0954 - mae: 0.0890 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.9531e-06
# Epoch 447/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0945 - mae: 0.0881
# Epoch 447: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0946 - mae: 0.0882 - val_loss: 0.0597 - val_mae: 0.0534 - learning_rate: 1.9531e-06
# Epoch 448/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0923 - mae: 0.0859
# Epoch 448: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0924 - mae: 0.0860 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.9531e-06
# Epoch 449/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0950 - mae: 0.0887
# Epoch 449: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0950 - mae: 0.0886 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.9531e-06
# Epoch 450/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0934 - mae: 0.0870
# Epoch 450: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0935 - mae: 0.0871 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.9531e-06
# Epoch 451/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0937 - mae: 0.0874
# Epoch 451: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0938 - mae: 0.0874 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.9531e-06
# Epoch 452/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0917 - mae: 0.0854
# Epoch 452: val_loss did not improve from 0.05948
#
# Epoch 452: ReduceLROnPlateau reducing learning rate to 1e-06.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0918 - mae: 0.0854 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.9531e-06
# Epoch 453/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0959 - mae: 0.0895
# Epoch 453: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0960 - mae: 0.0896 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.0000e-06
# Epoch 454/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0946 - mae: 0.0883
# Epoch 454: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0947 - mae: 0.0883 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.0000e-06
# Epoch 455/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0958 - mae: 0.0894
# Epoch 455: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0957 - mae: 0.0893 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.0000e-06
# Epoch 456/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0980 - mae: 0.0916
# Epoch 456: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0979 - mae: 0.0915 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.0000e-06
# Epoch 457/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0947 - mae: 0.0883
# Epoch 457: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0946 - mae: 0.0882 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.0000e-06
# Epoch 458/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0967 - mae: 0.0903
# Epoch 458: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0966 - mae: 0.0902 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.0000e-06
# Epoch 459/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0952 - mae: 0.0888
# Epoch 459: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0951 - mae: 0.0887 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.0000e-06
# Epoch 460/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0940 - mae: 0.0877
# Epoch 460: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0941 - mae: 0.0878 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.0000e-06
# Epoch 461/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0942 - mae: 0.0879
# Epoch 461: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0943 - mae: 0.0879 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.0000e-06
# Epoch 462/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0939 - mae: 0.0875
# Epoch 462: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0940 - mae: 0.0876 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.0000e-06
# Epoch 463/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0935 - mae: 0.0871
# Epoch 463: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0936 - mae: 0.0872 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.0000e-06
# Epoch 464/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0944 - mae: 0.0881
# Epoch 464: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0945 - mae: 0.0881 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.0000e-06
# Epoch 465/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0938 - mae: 0.0874
# Epoch 465: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0937 - mae: 0.0873 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.0000e-06
# Epoch 466/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0945 - mae: 0.0882
# Epoch 466: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0945 - mae: 0.0881 - val_loss: 0.0598 - val_mae: 0.0534 - learning_rate: 1.0000e-06
# Epoch 467/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0939 - mae: 0.0875
# Epoch 467: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0939 - mae: 0.0875 - val_loss: 0.0598 - val_mae: 0.0535 - learning_rate: 1.0000e-06
# Epoch 468/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0934 - mae: 0.0870
# Epoch 468: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0934 - mae: 0.0870 - val_loss: 0.0599 - val_mae: 0.0535 - learning_rate: 1.0000e-06
# Epoch 469/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0940 - mae: 0.0877
# Epoch 469: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0940 - mae: 0.0876 - val_loss: 0.0599 - val_mae: 0.0535 - learning_rate: 1.0000e-06
# Epoch 470/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0946 - mae: 0.0882
# Epoch 470: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0945 - mae: 0.0882 - val_loss: 0.0599 - val_mae: 0.0536 - learning_rate: 1.0000e-06
# Epoch 471/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0949 - mae: 0.0885
# Epoch 471: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0948 - mae: 0.0884 - val_loss: 0.0599 - val_mae: 0.0536 - learning_rate: 1.0000e-06
# Epoch 472/600
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0932 - mae: 0.0868
# Epoch 472: val_loss did not improve from 0.05948
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0932 - mae: 0.0868 - val_loss: 0.0599 - val_mae: 0.0535 - learning_rate: 1.0000e-06
# Epoch 472: early stopping
# Restoring model weights from the end of the best epoch: 422.

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import  mean_absolute_error

# model  = load_model("/kaggle/input/m/tensorflow2/default/1/best_lstm_model_reg.keras")
# پیش‌بینی روی داده تست-
y_pred_scaled = transfer_model.predict(X_windows_test)  # (N, 1)

# برگرداندن به مقیاس اصلی
y_pred_original = y_scaler.inverse_transform(y_pred_scaled)
y_true_original = y_scaler.inverse_transform(y_windows_test)




mae = mean_absolute_error(y_true_original, y_pred_original)
mae2 = mean_absolute_error(y_windows_test, y_pred_scaled)

print(f"Test MAE(scaled): {mae2:.3f}")
print(f"Test MAE(true value): {mae:.3f}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step
# Test MAE(scaled): 0.075
# Test MAE(true value): 1.081

# %%
import matplotlib.pyplot as plt

# Set font sizes and styles for publication
plt.rcParams.update({
    'font.size': 14,
    'axes.labelsize': 16,
    'axes.titlesize': 18,
    'legend.fontsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'font.family': 'serif',  # Optional: use serif font (common in papers)
    'figure.figsize': (8, 5)
})

# Plot training & validation loss
plt.plot(history.history["loss"], label="Training Loss", linewidth=2.5, color='tab:blue')
plt.plot(history.history["val_loss"], label="Validation Loss", linewidth=2.5, color='tab:red')

# Add title and axis labels
plt.title("Model Training Progress", fontsize=18, pad=20)
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")

# Improve layout and add grid
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.legend(frameon=True, loc='upper right', shadow=False, edgecolor='black')

# Use tight layout to prevent clipping
plt.tight_layout()

# Save high-resolution figure for your article
# plt.savefig("training_validation_loss.pdf", format='pdf', dpi=300, bbox_inches='tight')
# plt.savefig("training_validation_loss.png", format='png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import pickle

with open('training_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
y_true_original.shape
# Out:
# (16793, 100)

# %%
y_pred_original.shape
# Out:
# (16793, 100)

# %%
# time = np.arange(1, y_true_original.shape[0]+1) * 0.01
# time = time.reshape(-1, 1)

plt.figure(figsize=(15,10))
plt.plot(y_true_original[222,:])
plt.plot(y_pred_original[222,:])
plt.grid()
