# %%
# !git clone https://github.com/Omidzarexz/AnkleBiLSTMJointPrediction
# Out:
# fatal: destination path 'AnkleBiLSTMJointPrediction' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt


# df_clean_train_12feature_cross_subject = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_train_12feature_cross_subject.csv")
# df_clean_test_12feature_cross_subject  = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_test_12feature_cross_subject.csv")


# df_clean_train_16feature_cross_subject = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_train_16feature_cross_subject.csv")
# df_clean_test_16feature_cross_subject  = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_test_16feature_cross_subject.csv")


df_clean_train_16feature_within_subject = pd.read_csv("/content/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_train_16feature_within_subject_txt25.csv")
df_clean_test_16feature_within_subject  = pd.read_csv("/content/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_test_16feature_within_subject_txt25.csv")

df_clean_train = df_clean_train_16feature_within_subject
df_clean_test  = df_clean_test_16feature_within_subject

# %%
from scipy.signal import butter, filtfilt

def low_pass_butter(signal, cutoff=10, fs=100, order=2):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return filtfilt(b, a, signal)
feature_columns = [
    'MPU1_Acc_X', 'MPU1_Acc_Y', 'MPU1_Acc_Z',
    'MPU1_Gyro_X', 'MPU1_Gyro_Y', 'MPU1_Gyro_Z',
    'MPU1_Roll','MPU1_Pitch',
    'MPU2_Acc_X', 'MPU2_Acc_Y', 'MPU2_Acc_Z',
    'MPU2_Gyro_X', 'MPU2_Gyro_Y', 'MPU2_Gyro_Z',
    'MPU2_Roll','MPU2_Pitch'
]




df_filtered_trainig = pd.DataFrame()
df_filtered_test    = pd.DataFrame()
for col in feature_columns:
    df_filtered_trainig[col] = low_pass_butter( df_clean_train[col].values
                                        , cutoff=5 # Hz
                                        , fs=100  # Hz
                                        , order=2  )
    df_filtered_test[col] = low_pass_butter( df_clean_test[col].values
                                        , cutoff=5 # Hz
                                        , fs=100  # Hz
                                        , order=2  )







print("\ndf_filtered_trainig shape:",df_filtered_trainig.shape)
print("\ndf_filtered_test shape:",df_filtered_test.shape)
# Out:
# df_filtered_trainig shape: (16500, 16)
#
# df_filtered_test shape: (992, 16)

# %%
from sklearn.preprocessing import  MinMaxScaler


scaler = MinMaxScaler(feature_range=(-1, 1))
X_data_train = scaler.fit_transform(df_filtered_trainig[feature_columns].values)  # (T, 12)


y_scaler = MinMaxScaler(feature_range=(-1, 1))
y_data_train = y_scaler.fit_transform(df_clean_train['angle'].values.reshape(-1, 1))





X_data_test = scaler.transform(df_filtered_test[feature_columns].values)

y_data_test = y_scaler.transform(df_clean_test["angle"].values.reshape(-1,1))


# تنظیمات پنجره
window_size = 200   #
horizon = 20        #
step_size = 20      #

# تابع پنجره‌بندی
def create_windows_with_labels(X, y, window_size, horizon, step_size):
    X_windows = []
    y_windows = []
    for i in range(0,  len(X) - window_size - horizon + 1, step_size):
        X_windows.append(X[i:i + window_size])
        y_windows.append(y[i + window_size : i + window_size + horizon])  # برچسب آخرین نمونه در پنجره
    return np.array(X_windows), np.array(y_windows)

# ایجاد پنجره‌ها
X_windows, y_windows = create_windows_with_labels(X_data_train, y_data_train,
                                                  window_size, horizon, step_size)
if horizon==1:
    y_windows = y_windows.reshape(-1,1)
else:
    y_windows = np.squeeze(y_windows, axis=2)





print(f✅   (X_windows):(samples, time steps, features) → {X_windows.shape}")
print(f"  (y_windows): {y_windows.shape}")

step_size_for_test = 1
X_windows_test, y_windows_test = create_windows_with_labels(X_data_test, y_data_test,
                                                            window_size, horizon, step_size_for_test)

if horizon==1:
    y_windows_test = y_windows_test.reshape(-1,1)
else:
    y_windows_test = np.squeeze(y_windows_test, axis=2)

print(f"\n   (X_windows_test):(samples, time steps, features) → {X_windows_test.shape}")
print(f"  (y_windows_test): {y_windows_test.shape}")
# Out:
# ✅   (X_windows):(samples, time steps, features) → (815, 200, 16)
# ✅  (y_windows): (815, 20)
#
# ✅   (X_windows_test):(samples, time steps, features) → (773, 200, 16)
# ✅  (y_windows_test): (773, 20)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from keras.layers import Bidirectional

from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, GlobalAveragePooling1D
from tensorflow.keras.layers import Input, Dense, GRU, Bidirectional, Dropout, ReLU, TimeDistributed, LayerNormalization
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l2

LEARNING_RATE = 0.001
lambda_loss_amount = 0.0005



def build_bi_lstm_model(input_shape, horizon=1, lambda_loss_amount=1e-4, learning_rate=1e-3):
    inputs = Input(shape=input_shape, name="input")

    # Dense projection per timestep
    x = TimeDistributed(Dense(128, kernel_regularizer=l2(lambda_loss_amount)))(inputs)
    x = ReLU()(x)

    # Stacked BiGRU layers
    x = Bidirectional(LSTM(128, return_sequences=True,
                           kernel_regularizer=l2(lambda_loss_amount)))(x)
    x = LayerNormalization()(x)
    x = Dropout(0.3)(x)


    x = Bidirectional(LSTM(128, return_sequences=False,
                           kernel_regularizer=l2(lambda_loss_amount)))(x)
    x = Dropout(0.3)(x)



    # Output
    outputs = Dense(horizon, activation='linear')(x)

    # Model compile
    model = Model(inputs=inputs, outputs=outputs, name="BiLSTM_reg")
    model.compile(optimizer=optimizers.Adam(learning_rate=learning_rate),
                  loss='mse',
                  metrics=['mae'])
    return model

final_model = build_bi_lstm_model(input_shape=(X_windows.shape[1],X_windows.shape[2]),horizon=horizon)

# final_model.summary()

plot_model(final_model, show_shapes=True , dpi=80)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from sklearn.model_selection import train_test_split


X_train, X_val, y_train, y_val = train_test_split( X_windows, y_windows, test_size=0.2,
                                                   shuffle=False, random_state=42)


callbacks = [
    ModelCheckpoint('best_lstm_model_reg.keras', save_best_only=True, monitor='val_loss',verbose=1),
    EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True,verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=5e-6,verbose=1)
]

history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=500,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.4572 - mae: 0.4658
# Epoch 1: val_loss improved from inf to 0.18219, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 382ms/step - loss: 0.4415 - mae: 0.4537 - val_loss: 0.1822 - val_mae: 0.2090 - learning_rate: 0.0010
# Epoch 2/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2169 - mae: 0.2593
# Epoch 2: val_loss improved from 0.18219 to 0.15413, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.2151 - mae: 0.2572 - val_loss: 0.1541 - val_mae: 0.1667 - learning_rate: 0.0010
# Epoch 3/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1728 - mae: 0.2022
# Epoch 3: val_loss improved from 0.15413 to 0.13950, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1722 - mae: 0.2015 - val_loss: 0.1395 - val_mae: 0.1459 - learning_rate: 0.0010
# Epoch 4/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1550 - mae: 0.1812
# Epoch 4: val_loss improved from 0.13950 to 0.13067, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.1548 - mae: 0.1807 - val_loss: 0.1307 - val_mae: 0.1327 - learning_rate: 0.0010
# Epoch 5/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1426 - mae: 0.1633
# Epoch 5: val_loss improved from 0.13067 to 0.11672, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.1422 - mae: 0.1628 - val_loss: 0.1167 - val_mae: 0.1081 - learning_rate: 0.0010
# Epoch 6/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1282 - mae: 0.1432
# Epoch 6: val_loss improved from 0.11672 to 0.11141, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.1284 - mae: 0.1439 - val_loss: 0.1114 - val_mae: 0.1083 - learning_rate: 0.0010
# Epoch 7/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1233 - mae: 0.1423
# Epoch 7: val_loss improved from 0.11141 to 0.11043, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.1234 - mae: 0.1427 - val_loss: 0.1104 - val_mae: 0.1082 - learning_rate: 0.0010
# Epoch 8/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1211 - mae: 0.1434
# Epoch 8: val_loss improved from 0.11043 to 0.09903, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.1207 - mae: 0.1429 - val_loss: 0.0990 - val_mae: 0.0905 - learning_rate: 0.0010
# Epoch 9/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1134 - mae: 0.1344
# Epoch 9: val_loss improved from 0.09903 to 0.09676, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.1132 - mae: 0.1342 - val_loss: 0.0968 - val_mae: 0.0949 - learning_rate: 0.0010
# Epoch 10/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1098 - mae: 0.1348
# Epoch 10: val_loss did not improve from 0.09676
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.1094 - mae: 0.1342 - val_loss: 0.0969 - val_mae: 0.1032 - learning_rate: 0.0010
# Epoch 11/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1074 - mae: 0.1338
# Epoch 11: val_loss improved from 0.09676 to 0.09287, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.1071 - mae: 0.1335 - val_loss: 0.0929 - val_mae: 0.1045 - learning_rate: 0.0010
# Epoch 12/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1017 - mae: 0.1327
# Epoch 12: val_loss improved from 0.09287 to 0.08538, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.1016 - mae: 0.1324 - val_loss: 0.0854 - val_mae: 0.0873 - learning_rate: 0.0010
# Epoch 13/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0967 - mae: 0.1259
# Epoch 13: val_loss improved from 0.08538 to 0.08228, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0966 - mae: 0.1256 - val_loss: 0.0823 - val_mae: 0.0830 - learning_rate: 0.0010
# Epoch 14/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0924 - mae: 0.1196
# Epoch 14: val_loss improved from 0.08228 to 0.08076, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0923 - mae: 0.1197 - val_loss: 0.0808 - val_mae: 0.0898 - learning_rate: 0.0010
# Epoch 15/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0890 - mae: 0.1184
# Epoch 15: val_loss improved from 0.08076 to 0.07870, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0890 - mae: 0.1188 - val_loss: 0.0787 - val_mae: 0.0899 - learning_rate: 0.0010
# Epoch 16/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0857 - mae: 0.1152
# Epoch 16: val_loss improved from 0.07870 to 0.07493, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0858 - mae: 0.1157 - val_loss: 0.0749 - val_mae: 0.0878 - learning_rate: 0.0010
# Epoch 17/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0833 - mae: 0.1152
# Epoch 17: val_loss improved from 0.07493 to 0.07204, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0832 - mae: 0.1152 - val_loss: 0.0720 - val_mae: 0.0817 - learning_rate: 0.0010
# Epoch 18/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0799 - mae: 0.1116
# Epoch 18: val_loss improved from 0.07204 to 0.07030, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0798 - mae: 0.1113 - val_loss: 0.0703 - val_mae: 0.0824 - learning_rate: 0.0010
# Epoch 19/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0771 - mae: 0.1089
# Epoch 19: val_loss improved from 0.07030 to 0.06760, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0772 - mae: 0.1091 - val_loss: 0.0676 - val_mae: 0.0793 - learning_rate: 0.0010
# Epoch 20/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0765 - mae: 0.1125
# Epoch 20: val_loss improved from 0.06760 to 0.06666, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0763 - mae: 0.1120 - val_loss: 0.0667 - val_mae: 0.0831 - learning_rate: 0.0010
# Epoch 21/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0741 - mae: 0.1111
# Epoch 21: val_loss did not improve from 0.06666
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0740 - mae: 0.1107 - val_loss: 0.0689 - val_mae: 0.0997 - learning_rate: 0.0010
# Epoch 22/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0730 - mae: 0.1117
# Epoch 22: val_loss improved from 0.06666 to 0.06163, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0727 - mae: 0.1112 - val_loss: 0.0616 - val_mae: 0.0755 - learning_rate: 0.0010
# Epoch 23/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0683 - mae: 0.1039
# Epoch 23: val_loss did not improve from 0.06163
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0683 - mae: 0.1040 - val_loss: 0.0619 - val_mae: 0.0835 - learning_rate: 0.0010
# Epoch 24/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0664 - mae: 0.1038
# Epoch 24: val_loss improved from 0.06163 to 0.05959, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0664 - mae: 0.1037 - val_loss: 0.0596 - val_mae: 0.0782 - learning_rate: 0.0010
# Epoch 25/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0640 - mae: 0.0994
# Epoch 25: val_loss improved from 0.05959 to 0.05804, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0641 - mae: 0.0997 - val_loss: 0.0580 - val_mae: 0.0789 - learning_rate: 0.0010
# Epoch 26/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0626 - mae: 0.1002
# Epoch 26: val_loss improved from 0.05804 to 0.05704, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0626 - mae: 0.1002 - val_loss: 0.0570 - val_mae: 0.0795 - learning_rate: 0.0010
# Epoch 27/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0630 - mae: 0.1040
# Epoch 27: val_loss improved from 0.05704 to 0.05444, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0629 - mae: 0.1037 - val_loss: 0.0544 - val_mae: 0.0748 - learning_rate: 0.0010
# Epoch 28/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0595 - mae: 0.0976
# Epoch 28: val_loss improved from 0.05444 to 0.05383, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0596 - mae: 0.0979 - val_loss: 0.0538 - val_mae: 0.0776 - learning_rate: 0.0010
# Epoch 29/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0600 - mae: 0.1023
# Epoch 29: val_loss improved from 0.05383 to 0.05239, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0601 - mae: 0.1025 - val_loss: 0.0524 - val_mae: 0.0789 - learning_rate: 0.0010
# Epoch 30/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0586 - mae: 0.1016
# Epoch 30: val_loss improved from 0.05239 to 0.05039, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0585 - mae: 0.1015 - val_loss: 0.0504 - val_mae: 0.0723 - learning_rate: 0.0010
# Epoch 31/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0567 - mae: 0.0997
# Epoch 31: val_loss improved from 0.05039 to 0.04907, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0565 - mae: 0.0994 - val_loss: 0.0491 - val_mae: 0.0721 - learning_rate: 0.0010
# Epoch 32/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0531 - mae: 0.0916
# Epoch 32: val_loss improved from 0.04907 to 0.04866, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0531 - mae: 0.0918 - val_loss: 0.0487 - val_mae: 0.0743 - learning_rate: 0.0010
# Epoch 33/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0522 - mae: 0.0912
# Epoch 33: val_loss did not improve from 0.04866
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0522 - mae: 0.0914 - val_loss: 0.0497 - val_mae: 0.0809 - learning_rate: 0.0010
# Epoch 34/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0517 - mae: 0.0933
# Epoch 34: val_loss improved from 0.04866 to 0.04848, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0518 - mae: 0.0935 - val_loss: 0.0485 - val_mae: 0.0799 - learning_rate: 0.0010
# Epoch 35/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0521 - mae: 0.0979
# Epoch 35: val_loss did not improve from 0.04848
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0521 - mae: 0.0980 - val_loss: 0.0498 - val_mae: 0.0868 - learning_rate: 0.0010
# Epoch 36/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0519 - mae: 0.0990
# Epoch 36: val_loss improved from 0.04848 to 0.04457, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0518 - mae: 0.0988 - val_loss: 0.0446 - val_mae: 0.0724 - learning_rate: 0.0010
# Epoch 37/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0487 - mae: 0.0915
# Epoch 37: val_loss did not improve from 0.04457
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0488 - mae: 0.0918 - val_loss: 0.0475 - val_mae: 0.0898 - learning_rate: 0.0010
# Epoch 38/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0485 - mae: 0.0938
# Epoch 38: val_loss improved from 0.04457 to 0.04365, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0485 - mae: 0.0939 - val_loss: 0.0437 - val_mae: 0.0756 - learning_rate: 0.0010
# Epoch 39/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0464 - mae: 0.0901
# Epoch 39: val_loss did not improve from 0.04365
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0464 - mae: 0.0900 - val_loss: 0.0443 - val_mae: 0.0815 - learning_rate: 0.0010
# Epoch 40/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0459 - mae: 0.0903
# Epoch 40: val_loss improved from 0.04365 to 0.04141, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0460 - mae: 0.0904 - val_loss: 0.0414 - val_mae: 0.0723 - learning_rate: 0.0010
# Epoch 41/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0454 - mae: 0.0908
# Epoch 41: val_loss did not improve from 0.04141
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0454 - mae: 0.0909 - val_loss: 0.0427 - val_mae: 0.0812 - learning_rate: 0.0010
# Epoch 42/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0442 - mae: 0.0889
# Epoch 42: val_loss improved from 0.04141 to 0.03951, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0442 - mae: 0.0891 - val_loss: 0.0395 - val_mae: 0.0708 - learning_rate: 0.0010
# Epoch 43/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0438 - mae: 0.0902
# Epoch 43: val_loss did not improve from 0.03951
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0438 - mae: 0.0902 - val_loss: 0.0399 - val_mae: 0.0755 - learning_rate: 0.0010
# Epoch 44/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0433 - mae: 0.0916
# Epoch 44: val_loss improved from 0.03951 to 0.03805, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0432 - mae: 0.0915 - val_loss: 0.0380 - val_mae: 0.0688 - learning_rate: 0.0010
# Epoch 45/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0410 - mae: 0.0851
# Epoch 45: val_loss did not improve from 0.03805
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0411 - mae: 0.0855 - val_loss: 0.0410 - val_mae: 0.0840 - learning_rate: 0.0010
# Epoch 46/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0428 - mae: 0.0935
# Epoch 46: val_loss did not improve from 0.03805
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0427 - mae: 0.0932 - val_loss: 0.0384 - val_mae: 0.0777 - learning_rate: 0.0010
# Epoch 47/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0403 - mae: 0.0864
# Epoch 47: val_loss improved from 0.03805 to 0.03649, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0403 - mae: 0.0865 - val_loss: 0.0365 - val_mae: 0.0702 - learning_rate: 0.0010
# Epoch 48/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0400 - mae: 0.0881
# Epoch 48: val_loss did not improve from 0.03649
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0400 - mae: 0.0880 - val_loss: 0.0386 - val_mae: 0.0812 - learning_rate: 0.0010
# Epoch 49/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0398 - mae: 0.0903
# Epoch 49: val_loss did not improve from 0.03649
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0397 - mae: 0.0899 - val_loss: 0.0367 - val_mae: 0.0765 - learning_rate: 0.0010
# Epoch 50/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0383 - mae: 0.0857
# Epoch 50: val_loss improved from 0.03649 to 0.03525, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0382 - mae: 0.0857 - val_loss: 0.0352 - val_mae: 0.0733 - learning_rate: 0.0010
# Epoch 51/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0379 - mae: 0.0860
# Epoch 51: val_loss improved from 0.03525 to 0.03462, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0379 - mae: 0.0861 - val_loss: 0.0346 - val_mae: 0.0714 - learning_rate: 0.0010
# Epoch 52/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0363 - mae: 0.0828
# Epoch 52: val_loss improved from 0.03462 to 0.03415, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0364 - mae: 0.0831 - val_loss: 0.0341 - val_mae: 0.0700 - learning_rate: 0.0010
# Epoch 53/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0361 - mae: 0.0838
# Epoch 53: val_loss improved from 0.03415 to 0.03367, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0362 - mae: 0.0838 - val_loss: 0.0337 - val_mae: 0.0715 - learning_rate: 0.0010
# Epoch 54/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0354 - mae: 0.0834
# Epoch 54: val_loss improved from 0.03367 to 0.03274, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0354 - mae: 0.0835 - val_loss: 0.0327 - val_mae: 0.0703 - learning_rate: 0.0010
# Epoch 55/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0361 - mae: 0.0871
# Epoch 55: val_loss did not improve from 0.03274
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0363 - mae: 0.0876 - val_loss: 0.0369 - val_mae: 0.0904 - learning_rate: 0.0010
# Epoch 56/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0363 - mae: 0.0891
# Epoch 56: val_loss did not improve from 0.03274
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0362 - mae: 0.0890 - val_loss: 0.0336 - val_mae: 0.0763 - learning_rate: 0.0010
# Epoch 57/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0357 - mae: 0.0875
# Epoch 57: val_loss did not improve from 0.03274
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0357 - mae: 0.0876 - val_loss: 0.0329 - val_mae: 0.0764 - learning_rate: 0.0010
# Epoch 58/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0352 - mae: 0.0892
# Epoch 58: val_loss did not improve from 0.03274
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0353 - mae: 0.0894 - val_loss: 0.0334 - val_mae: 0.0819 - learning_rate: 0.0010
# Epoch 59/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0344 - mae: 0.0867
# Epoch 59: val_loss improved from 0.03274 to 0.03143, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0344 - mae: 0.0866 - val_loss: 0.0314 - val_mae: 0.0724 - learning_rate: 0.0010
# Epoch 60/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0334 - mae: 0.0828
# Epoch 60: val_loss improved from 0.03143 to 0.03022, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0334 - mae: 0.0831 - val_loss: 0.0302 - val_mae: 0.0686 - learning_rate: 0.0010
# Epoch 61/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0330 - mae: 0.0830
# Epoch 61: val_loss did not improve from 0.03022
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0329 - mae: 0.0831 - val_loss: 0.0310 - val_mae: 0.0745 - learning_rate: 0.0010
# Epoch 62/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0321 - mae: 0.0829
# Epoch 62: val_loss did not improve from 0.03022
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0321 - mae: 0.0828 - val_loss: 0.0313 - val_mae: 0.0788 - learning_rate: 0.0010
# Epoch 63/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0314 - mae: 0.0812
# Epoch 63: val_loss did not improve from 0.03022
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0315 - mae: 0.0816 - val_loss: 0.0326 - val_mae: 0.0839 - learning_rate: 0.0010
# Epoch 64/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0324 - mae: 0.0862
# Epoch 64: val_loss improved from 0.03022 to 0.02930, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0323 - mae: 0.0858 - val_loss: 0.0293 - val_mae: 0.0725 - learning_rate: 0.0010
# Epoch 65/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0297 - mae: 0.0776
# Epoch 65: val_loss improved from 0.02930 to 0.02897, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0298 - mae: 0.0779 - val_loss: 0.0290 - val_mae: 0.0711 - learning_rate: 0.0010
# Epoch 66/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0296 - mae: 0.0789
# Epoch 66: val_loss did not improve from 0.02897
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0296 - mae: 0.0789 - val_loss: 0.0295 - val_mae: 0.0754 - learning_rate: 0.0010
# Epoch 67/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0311 - mae: 0.0846
# Epoch 67: val_loss did not improve from 0.02897
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0309 - mae: 0.0842 - val_loss: 0.0311 - val_mae: 0.0812 - learning_rate: 0.0010
# Epoch 68/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0296 - mae: 0.0815
# Epoch 68: val_loss did not improve from 0.02897
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0296 - mae: 0.0813 - val_loss: 0.0294 - val_mae: 0.0770 - learning_rate: 0.0010
# Epoch 69/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0303 - mae: 0.0844
# Epoch 69: val_loss did not improve from 0.02897
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0302 - mae: 0.0842 - val_loss: 0.0295 - val_mae: 0.0804 - learning_rate: 0.0010
# Epoch 70/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0290 - mae: 0.0811
# Epoch 70: val_loss improved from 0.02897 to 0.02654, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0290 - mae: 0.0810 - val_loss: 0.0265 - val_mae: 0.0670 - learning_rate: 0.0010
# Epoch 71/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0285 - mae: 0.0806
# Epoch 71: val_loss did not improve from 0.02654
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0285 - mae: 0.0806 - val_loss: 0.0286 - val_mae: 0.0751 - learning_rate: 0.0010
# Epoch 72/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0281 - mae: 0.0804
# Epoch 72: val_loss did not improve from 0.02654
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0281 - mae: 0.0806 - val_loss: 0.0274 - val_mae: 0.0767 - learning_rate: 0.0010
# Epoch 73/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0281 - mae: 0.0809
# Epoch 73: val_loss did not improve from 0.02654
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0281 - mae: 0.0810 - val_loss: 0.0290 - val_mae: 0.0825 - learning_rate: 0.0010
# Epoch 74/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0277 - mae: 0.0804
# Epoch 74: val_loss did not improve from 0.02654
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0277 - mae: 0.0804 - val_loss: 0.0283 - val_mae: 0.0785 - learning_rate: 0.0010
# Epoch 75/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0275 - mae: 0.0800
# Epoch 75: val_loss improved from 0.02654 to 0.02608, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0276 - mae: 0.0802 - val_loss: 0.0261 - val_mae: 0.0708 - learning_rate: 0.0010
# Epoch 76/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0266 - mae: 0.0776
# Epoch 76: val_loss improved from 0.02608 to 0.02598, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0266 - mae: 0.0776 - val_loss: 0.0260 - val_mae: 0.0723 - learning_rate: 0.0010
# Epoch 77/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0273 - mae: 0.0819
# Epoch 77: val_loss did not improve from 0.02598
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0273 - mae: 0.0818 - val_loss: 0.0271 - val_mae: 0.0792 - learning_rate: 0.0010
# Epoch 78/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0258 - mae: 0.0764
# Epoch 78: val_loss improved from 0.02598 to 0.02485, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0259 - mae: 0.0768 - val_loss: 0.0249 - val_mae: 0.0688 - learning_rate: 0.0010
# Epoch 79/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0260 - mae: 0.0784
# Epoch 79: val_loss improved from 0.02485 to 0.02459, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0259 - mae: 0.0783 - val_loss: 0.0246 - val_mae: 0.0685 - learning_rate: 0.0010
# Epoch 80/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0261 - mae: 0.0797
# Epoch 80: val_loss improved from 0.02459 to 0.02391, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0261 - mae: 0.0795 - val_loss: 0.0239 - val_mae: 0.0674 - learning_rate: 0.0010
# Epoch 81/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0250 - mae: 0.0772
# Epoch 81: val_loss did not improve from 0.02391
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0250 - mae: 0.0772 - val_loss: 0.0251 - val_mae: 0.0732 - learning_rate: 0.0010
# Epoch 82/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0254 - mae: 0.0787
# Epoch 82: val_loss did not improve from 0.02391
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0254 - mae: 0.0785 - val_loss: 0.0255 - val_mae: 0.0776 - learning_rate: 0.0010
# Epoch 83/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0242 - mae: 0.0755
# Epoch 83: val_loss improved from 0.02391 to 0.02341, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0242 - mae: 0.0754 - val_loss: 0.0234 - val_mae: 0.0664 - learning_rate: 0.0010
# Epoch 84/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0239 - mae: 0.0746
# Epoch 84: val_loss did not improve from 0.02341
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0239 - mae: 0.0746 - val_loss: 0.0237 - val_mae: 0.0710 - learning_rate: 0.0010
# Epoch 85/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0239 - mae: 0.0757
# Epoch 85: val_loss did not improve from 0.02341
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0240 - mae: 0.0757 - val_loss: 0.0243 - val_mae: 0.0726 - learning_rate: 0.0010
# Epoch 86/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0250 - mae: 0.0794
# Epoch 86: val_loss improved from 0.02341 to 0.02301, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0249 - mae: 0.0790 - val_loss: 0.0230 - val_mae: 0.0693 - learning_rate: 0.0010
# Epoch 87/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0229 - mae: 0.0737
# Epoch 87: val_loss improved from 0.02301 to 0.02275, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0230 - mae: 0.0738 - val_loss: 0.0227 - val_mae: 0.0690 - learning_rate: 0.0010
# Epoch 88/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0222 - mae: 0.0706
# Epoch 88: val_loss improved from 0.02275 to 0.02217, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0222 - mae: 0.0709 - val_loss: 0.0222 - val_mae: 0.0661 - learning_rate: 0.0010
# Epoch 89/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0231 - mae: 0.0760
# Epoch 89: val_loss did not improve from 0.02217
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0232 - mae: 0.0762 - val_loss: 0.0230 - val_mae: 0.0714 - learning_rate: 0.0010
# Epoch 90/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0235 - mae: 0.0782
# Epoch 90: val_loss did not improve from 0.02217
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0234 - mae: 0.0776 - val_loss: 0.0230 - val_mae: 0.0723 - learning_rate: 0.0010
# Epoch 91/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0228 - mae: 0.0759
# Epoch 91: val_loss improved from 0.02217 to 0.02150, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0228 - mae: 0.0762 - val_loss: 0.0215 - val_mae: 0.0650 - learning_rate: 0.0010
# Epoch 92/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0225 - mae: 0.0741
# Epoch 92: val_loss did not improve from 0.02150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0225 - mae: 0.0742 - val_loss: 0.0224 - val_mae: 0.0709 - learning_rate: 0.0010
# Epoch 93/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0222 - mae: 0.0741
# Epoch 93: val_loss improved from 0.02150 to 0.02144, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0222 - mae: 0.0740 - val_loss: 0.0214 - val_mae: 0.0670 - learning_rate: 0.0010
# Epoch 94/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0213 - mae: 0.0717
# Epoch 94: val_loss did not improve from 0.02144
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0213 - mae: 0.0718 - val_loss: 0.0215 - val_mae: 0.0718 - learning_rate: 0.0010
# Epoch 95/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0218 - mae: 0.0752
# Epoch 95: val_loss did not improve from 0.02144
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0218 - mae: 0.0751 - val_loss: 0.0235 - val_mae: 0.0822 - learning_rate: 0.0010
# Epoch 96/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0230 - mae: 0.0800
# Epoch 96: val_loss did not improve from 0.02144
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0229 - mae: 0.0796 - val_loss: 0.0228 - val_mae: 0.0781 - learning_rate: 0.0010
# Epoch 97/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0207 - mae: 0.0720
# Epoch 97: val_loss improved from 0.02144 to 0.02056, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0208 - mae: 0.0724 - val_loss: 0.0206 - val_mae: 0.0700 - learning_rate: 0.0010
# Epoch 98/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0218 - mae: 0.0770
# Epoch 98: val_loss did not improve from 0.02056
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0218 - mae: 0.0769 - val_loss: 0.0220 - val_mae: 0.0738 - learning_rate: 0.0010
# Epoch 99/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0208 - mae: 0.0732
# Epoch 99: val_loss did not improve from 0.02056
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0207 - mae: 0.0731 - val_loss: 0.0219 - val_mae: 0.0731 - learning_rate: 0.0010
# Epoch 100/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0213 - mae: 0.0763
# Epoch 100: val_loss did not improve from 0.02056
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0213 - mae: 0.0764 - val_loss: 0.0218 - val_mae: 0.0751 - learning_rate: 0.0010
# Epoch 101/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0213 - mae: 0.0771
# Epoch 101: val_loss did not improve from 0.02056
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0212 - mae: 0.0768 - val_loss: 0.0207 - val_mae: 0.0704 - learning_rate: 0.0010
# Epoch 102/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0196 - mae: 0.0701
# Epoch 102: val_loss did not improve from 0.02056
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0197 - mae: 0.0703 - val_loss: 0.0208 - val_mae: 0.0712 - learning_rate: 0.0010
# Epoch 103/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0201 - mae: 0.0731
# Epoch 103: val_loss did not improve from 0.02056
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0201 - mae: 0.0730 - val_loss: 0.0210 - val_mae: 0.0744 - learning_rate: 0.0010
# Epoch 104/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0203 - mae: 0.0741
# Epoch 104: val_loss improved from 0.02056 to 0.01969, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0203 - mae: 0.0738 - val_loss: 0.0197 - val_mae: 0.0682 - learning_rate: 0.0010
# Epoch 105/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0199 - mae: 0.0731
# Epoch 105: val_loss did not improve from 0.01969
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0200 - mae: 0.0732 - val_loss: 0.0197 - val_mae: 0.0694 - learning_rate: 0.0010
# Epoch 106/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0199 - mae: 0.0723
# Epoch 106: val_loss improved from 0.01969 to 0.01935, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0199 - mae: 0.0724 - val_loss: 0.0193 - val_mae: 0.0676 - learning_rate: 0.0010
# Epoch 107/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0193 - mae: 0.0715
# Epoch 107: val_loss did not improve from 0.01935
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0193 - mae: 0.0716 - val_loss: 0.0212 - val_mae: 0.0756 - learning_rate: 0.0010
# Epoch 108/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0195 - mae: 0.0722
# Epoch 108: val_loss did not improve from 0.01935
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0195 - mae: 0.0722 - val_loss: 0.0206 - val_mae: 0.0753 - learning_rate: 0.0010
# Epoch 109/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0195 - mae: 0.0734
# Epoch 109: val_loss improved from 0.01935 to 0.01897, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0195 - mae: 0.0733 - val_loss: 0.0190 - val_mae: 0.0681 - learning_rate: 0.0010
# Epoch 110/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0189 - mae: 0.0716
# Epoch 110: val_loss improved from 0.01897 to 0.01872, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0189 - mae: 0.0717 - val_loss: 0.0187 - val_mae: 0.0669 - learning_rate: 0.0010
# Epoch 111/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0188 - mae: 0.0723
# Epoch 111: val_loss did not improve from 0.01872
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0189 - mae: 0.0723 - val_loss: 0.0203 - val_mae: 0.0756 - learning_rate: 0.0010
# Epoch 112/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0186 - mae: 0.0713
# Epoch 112: val_loss did not improve from 0.01872
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0187 - mae: 0.0716 - val_loss: 0.0203 - val_mae: 0.0763 - learning_rate: 0.0010
# Epoch 113/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0192 - mae: 0.0749
# Epoch 113: val_loss did not improve from 0.01872
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0192 - mae: 0.0748 - val_loss: 0.0204 - val_mae: 0.0740 - learning_rate: 0.0010
# Epoch 114/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0193 - mae: 0.0750
# Epoch 114: val_loss did not improve from 0.01872
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0193 - mae: 0.0751 - val_loss: 0.0264 - val_mae: 0.1004 - learning_rate: 0.0010
# Epoch 115/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0212 - mae: 0.0834
# Epoch 115: val_loss did not improve from 0.01872
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0210 - mae: 0.0826 - val_loss: 0.0191 - val_mae: 0.0720 - learning_rate: 0.0010
# Epoch 116/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0193 - mae: 0.0759
# Epoch 116: val_loss did not improve from 0.01872
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0194 - mae: 0.0762 - val_loss: 0.0201 - val_mae: 0.0756 - learning_rate: 0.0010
# Epoch 117/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0193 - mae: 0.0763
# Epoch 117: val_loss did not improve from 0.01872
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0193 - mae: 0.0764 - val_loss: 0.0195 - val_mae: 0.0749 - learning_rate: 0.0010
# Epoch 118/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0196 - mae: 0.0772
# Epoch 118: val_loss did not improve from 0.01872
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0195 - mae: 0.0766 - val_loss: 0.0217 - val_mae: 0.0835 - learning_rate: 0.0010
# Epoch 119/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0186 - mae: 0.0738
# Epoch 119: val_loss improved from 0.01872 to 0.01685, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0185 - mae: 0.0736 - val_loss: 0.0168 - val_mae: 0.0637 - learning_rate: 0.0010
# Epoch 120/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0180 - mae: 0.0725
# Epoch 120: val_loss did not improve from 0.01685
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0180 - mae: 0.0725 - val_loss: 0.0197 - val_mae: 0.0768 - learning_rate: 0.0010
# Epoch 121/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0189 - mae: 0.0768
# Epoch 121: val_loss did not improve from 0.01685
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0189 - mae: 0.0771 - val_loss: 0.0186 - val_mae: 0.0700 - learning_rate: 0.0010
# Epoch 122/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0194 - mae: 0.0779
# Epoch 122: val_loss did not improve from 0.01685
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0194 - mae: 0.0780 - val_loss: 0.0182 - val_mae: 0.0715 - learning_rate: 0.0010
# Epoch 123/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0181 - mae: 0.0744
# Epoch 123: val_loss did not improve from 0.01685
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0181 - mae: 0.0743 - val_loss: 0.0180 - val_mae: 0.0704 - learning_rate: 0.0010
# Epoch 124/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0176 - mae: 0.0717
# Epoch 124: val_loss did not improve from 0.01685
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0176 - mae: 0.0718 - val_loss: 0.0179 - val_mae: 0.0706 - learning_rate: 0.0010
# Epoch 125/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0178 - mae: 0.0726
# Epoch 125: val_loss did not improve from 0.01685
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0178 - mae: 0.0725 - val_loss: 0.0198 - val_mae: 0.0790 - learning_rate: 0.0010
# Epoch 126/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0176 - mae: 0.0725
# Epoch 126: val_loss did not improve from 0.01685
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0176 - mae: 0.0724 - val_loss: 0.0181 - val_mae: 0.0719 - learning_rate: 0.0010
# Epoch 127/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0165 - mae: 0.0681
# Epoch 127: val_loss did not improve from 0.01685
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0165 - mae: 0.0683 - val_loss: 0.0174 - val_mae: 0.0685 - learning_rate: 0.0010
# Epoch 128/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0178 - mae: 0.0746
# Epoch 128: val_loss did not improve from 0.01685
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0177 - mae: 0.0743 - val_loss: 0.0180 - val_mae: 0.0711 - learning_rate: 0.0010
# Epoch 129/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0165 - mae: 0.0685
# Epoch 129: val_loss did not improve from 0.01685
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0165 - mae: 0.0684 - val_loss: 0.0177 - val_mae: 0.0710 - learning_rate: 0.0010
# Epoch 130/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0179 - mae: 0.0753
# Epoch 130: val_loss did not improve from 0.01685
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0179 - mae: 0.0752 - val_loss: 0.0175 - val_mae: 0.0723 - learning_rate: 0.0010
# Epoch 131/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0172 - mae: 0.0728
# Epoch 131: val_loss did not improve from 0.01685
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0171 - mae: 0.0725 - val_loss: 0.0171 - val_mae: 0.0686 - learning_rate: 0.0010
# Epoch 132/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0161 - mae: 0.0691
# Epoch 132: val_loss did not improve from 0.01685
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0160 - mae: 0.0686 - val_loss: 0.0169 - val_mae: 0.0689 - learning_rate: 0.0010
# Epoch 133/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0161 - mae: 0.0689
# Epoch 133: val_loss improved from 0.01685 to 0.01613, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0161 - mae: 0.0691 - val_loss: 0.0161 - val_mae: 0.0671 - learning_rate: 0.0010
# Epoch 134/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0169 - mae: 0.0736
# Epoch 134: val_loss improved from 0.01613 to 0.01599, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0169 - mae: 0.0737 - val_loss: 0.0160 - val_mae: 0.0663 - learning_rate: 0.0010
# Epoch 135/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0163 - mae: 0.0709
# Epoch 135: val_loss improved from 0.01599 to 0.01585, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0163 - mae: 0.0707 - val_loss: 0.0159 - val_mae: 0.0654 - learning_rate: 0.0010
# Epoch 136/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0151 - mae: 0.0652
# Epoch 136: val_loss did not improve from 0.01585
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0152 - mae: 0.0655 - val_loss: 0.0189 - val_mae: 0.0776 - learning_rate: 0.0010
# Epoch 137/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0168 - mae: 0.0723
# Epoch 137: val_loss did not improve from 0.01585
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0167 - mae: 0.0720 - val_loss: 0.0173 - val_mae: 0.0741 - learning_rate: 0.0010
# Epoch 138/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0157 - mae: 0.0689
# Epoch 138: val_loss did not improve from 0.01585
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0157 - mae: 0.0690 - val_loss: 0.0168 - val_mae: 0.0692 - learning_rate: 0.0010
# Epoch 139/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0157 - mae: 0.0689
# Epoch 139: val_loss did not improve from 0.01585
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0157 - mae: 0.0690 - val_loss: 0.0162 - val_mae: 0.0687 - learning_rate: 0.0010
# Epoch 140/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0150 - mae: 0.0666
# Epoch 140: val_loss did not improve from 0.01585
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0150 - mae: 0.0666 - val_loss: 0.0169 - val_mae: 0.0715 - learning_rate: 0.0010
# Epoch 141/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0149 - mae: 0.0663
# Epoch 141: val_loss did not improve from 0.01585
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0150 - mae: 0.0665 - val_loss: 0.0166 - val_mae: 0.0708 - learning_rate: 0.0010
# Epoch 142/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0143 - mae: 0.0642
# Epoch 142: val_loss improved from 0.01585 to 0.01533, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0143 - mae: 0.0642 - val_loss: 0.0153 - val_mae: 0.0667 - learning_rate: 0.0010
# Epoch 143/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0147 - mae: 0.0668
# Epoch 143: val_loss did not improve from 0.01533
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0147 - mae: 0.0668 - val_loss: 0.0172 - val_mae: 0.0753 - learning_rate: 0.0010
# Epoch 144/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0146 - mae: 0.0654
# Epoch 144: val_loss did not improve from 0.01533
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0145 - mae: 0.0653 - val_loss: 0.0159 - val_mae: 0.0697 - learning_rate: 0.0010
# Epoch 145/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0142 - mae: 0.0647
# Epoch 145: val_loss did not improve from 0.01533
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0142 - mae: 0.0647 - val_loss: 0.0167 - val_mae: 0.0740 - learning_rate: 0.0010
# Epoch 146/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0146 - mae: 0.0662
# Epoch 146: val_loss did not improve from 0.01533
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0147 - mae: 0.0667 - val_loss: 0.0173 - val_mae: 0.0762 - learning_rate: 0.0010
# Epoch 147/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0156 - mae: 0.0721
# Epoch 147: val_loss did not improve from 0.01533
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0156 - mae: 0.0723 - val_loss: 0.0162 - val_mae: 0.0714 - learning_rate: 0.0010
# Epoch 148/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0159 - mae: 0.0730
# Epoch 148: val_loss did not improve from 0.01533
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0158 - mae: 0.0724 - val_loss: 0.0155 - val_mae: 0.0684 - learning_rate: 0.0010
# Epoch 149/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0147 - mae: 0.0676
# Epoch 149: val_loss did not improve from 0.01533
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0148 - mae: 0.0679 - val_loss: 0.0170 - val_mae: 0.0707 - learning_rate: 0.0010
# Epoch 150/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0152 - mae: 0.0697
# Epoch 150: val_loss did not improve from 0.01533
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0152 - mae: 0.0699 - val_loss: 0.0184 - val_mae: 0.0776 - learning_rate: 0.0010
# Epoch 151/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0164 - mae: 0.0750
# Epoch 151: val_loss improved from 0.01533 to 0.01476, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0163 - mae: 0.0747 - val_loss: 0.0148 - val_mae: 0.0646 - learning_rate: 0.0010
# Epoch 152/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0142 - mae: 0.0658
# Epoch 152: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0142 - mae: 0.0661 - val_loss: 0.0159 - val_mae: 0.0686 - learning_rate: 0.0010
# Epoch 153/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0143 - mae: 0.0671
# Epoch 153: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0143 - mae: 0.0670 - val_loss: 0.0162 - val_mae: 0.0699 - learning_rate: 0.0010
# Epoch 154/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0138 - mae: 0.0648
# Epoch 154: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0138 - mae: 0.0647 - val_loss: 0.0149 - val_mae: 0.0669 - learning_rate: 0.0010
# Epoch 155/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0137 - mae: 0.0655
# Epoch 155: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0137 - mae: 0.0655 - val_loss: 0.0151 - val_mae: 0.0691 - learning_rate: 0.0010
# Epoch 156/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0141 - mae: 0.0670
# Epoch 156: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0141 - mae: 0.0673 - val_loss: 0.0169 - val_mae: 0.0783 - learning_rate: 0.0010
# Epoch 157/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0144 - mae: 0.0689
# Epoch 157: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0144 - mae: 0.0688 - val_loss: 0.0154 - val_mae: 0.0707 - learning_rate: 0.0010
# Epoch 158/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0139 - mae: 0.0666
# Epoch 158: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0139 - mae: 0.0666 - val_loss: 0.0152 - val_mae: 0.0706 - learning_rate: 0.0010
# Epoch 159/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0136 - mae: 0.0651
# Epoch 159: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0136 - mae: 0.0652 - val_loss: 0.0155 - val_mae: 0.0694 - learning_rate: 0.0010
# Epoch 160/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0141 - mae: 0.0671
# Epoch 160: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0140 - mae: 0.0671 - val_loss: 0.0151 - val_mae: 0.0683 - learning_rate: 0.0010
# Epoch 161/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0127 - mae: 0.0616
# Epoch 161: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0128 - mae: 0.0618 - val_loss: 0.0155 - val_mae: 0.0729 - learning_rate: 0.0010
# Epoch 162/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0135 - mae: 0.0654
# Epoch 162: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0135 - mae: 0.0656 - val_loss: 0.0150 - val_mae: 0.0716 - learning_rate: 0.0010
# Epoch 163/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0131 - mae: 0.0643
# Epoch 163: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0131 - mae: 0.0644 - val_loss: 0.0169 - val_mae: 0.0797 - learning_rate: 0.0010
# Epoch 164/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0145 - mae: 0.0712
# Epoch 164: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0145 - mae: 0.0712 - val_loss: 0.0150 - val_mae: 0.0725 - learning_rate: 0.0010
# Epoch 165/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0144 - mae: 0.0701
# Epoch 165: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0143 - mae: 0.0699 - val_loss: 0.0162 - val_mae: 0.0741 - learning_rate: 0.0010
# Epoch 166/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0140 - mae: 0.0689
# Epoch 166: val_loss did not improve from 0.01476
#
# Epoch 166: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0140 - mae: 0.0691 - val_loss: 0.0156 - val_mae: 0.0691 - learning_rate: 0.0010
# Epoch 167/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0140 - mae: 0.0673
# Epoch 167: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0139 - mae: 0.0670 - val_loss: 0.0149 - val_mae: 0.0702 - learning_rate: 5.0000e-04
# Epoch 168/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0132 - mae: 0.0654
# Epoch 168: val_loss did not improve from 0.01476
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0131 - mae: 0.0651 - val_loss: 0.0148 - val_mae: 0.0717 - learning_rate: 5.0000e-04
# Epoch 169/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0126 - mae: 0.0632
# Epoch 169: val_loss improved from 0.01476 to 0.01366, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0125 - mae: 0.0630 - val_loss: 0.0137 - val_mae: 0.0647 - learning_rate: 5.0000e-04
# Epoch 170/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0125 - mae: 0.0627
# Epoch 170: val_loss improved from 0.01366 to 0.01353, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0125 - mae: 0.0627 - val_loss: 0.0135 - val_mae: 0.0644 - learning_rate: 5.0000e-04
# Epoch 171/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0118 - mae: 0.0590
# Epoch 171: val_loss improved from 0.01353 to 0.01326, saving model to best_lstm_model_reg.keras
# ...
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0091 - mae: 0.0523 - val_loss: 0.0118 - val_mae: 0.0626 - learning_rate: 1.2500e-04
# Epoch 255/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0091 - mae: 0.0515
# Epoch 255: val_loss did not improve from 0.01133
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0091 - mae: 0.0517 - val_loss: 0.0116 - val_mae: 0.0618 - learning_rate: 6.2500e-05
# Epoch 256/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0089 - mae: 0.0507
# Epoch 256: val_loss did not improve from 0.01133
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0089 - mae: 0.0509 - val_loss: 0.0117 - val_mae: 0.0620 - learning_rate: 6.2500e-05
# Epoch 257/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0091 - mae: 0.0518
# Epoch 257: val_loss did not improve from 0.01133
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0091 - mae: 0.0518 - val_loss: 0.0116 - val_mae: 0.0616 - learning_rate: 6.2500e-05
# Epoch 258/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0092 - mae: 0.0536
# Epoch 258: val_loss did not improve from 0.01133
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0092 - mae: 0.0534 - val_loss: 0.0116 - val_mae: 0.0618 - learning_rate: 6.2500e-05
# Epoch 259/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0090 - mae: 0.0520
# Epoch 259: val_loss did not improve from 0.01133
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0090 - mae: 0.0520 - val_loss: 0.0118 - val_mae: 0.0629 - learning_rate: 6.2500e-05
# Epoch 260/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0090 - mae: 0.0521
# Epoch 260: val_loss did not improve from 0.01133
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0090 - mae: 0.0521 - val_loss: 0.0118 - val_mae: 0.0625 - learning_rate: 6.2500e-05
# Epoch 261/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0090 - mae: 0.0525
# Epoch 261: val_loss did not improve from 0.01133
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0090 - mae: 0.0526 - val_loss: 0.0114 - val_mae: 0.0615 - learning_rate: 6.2500e-05
# Epoch 262/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0090 - mae: 0.0513
# Epoch 262: val_loss did not improve from 0.01133
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0090 - mae: 0.0515 - val_loss: 0.0115 - val_mae: 0.0623 - learning_rate: 6.2500e-05
# Epoch 263/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0089 - mae: 0.0513
# Epoch 263: val_loss did not improve from 0.01133
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0089 - mae: 0.0513 - val_loss: 0.0115 - val_mae: 0.0616 - learning_rate: 6.2500e-05
# Epoch 264/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0086 - mae: 0.0498
# Epoch 264: val_loss did not improve from 0.01133
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0087 - mae: 0.0499 - val_loss: 0.0115 - val_mae: 0.0623 - learning_rate: 6.2500e-05
# Epoch 265/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0091 - mae: 0.0525
# Epoch 265: val_loss improved from 0.01133 to 0.01124, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0091 - mae: 0.0524 - val_loss: 0.0112 - val_mae: 0.0602 - learning_rate: 6.2500e-05
# Epoch 266/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0088 - mae: 0.0503
# Epoch 266: val_loss did not improve from 0.01124
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0089 - mae: 0.0506 - val_loss: 0.0118 - val_mae: 0.0630 - learning_rate: 6.2500e-05
# Epoch 267/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0091 - mae: 0.0519
# Epoch 267: val_loss did not improve from 0.01124
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0091 - mae: 0.0520 - val_loss: 0.0113 - val_mae: 0.0609 - learning_rate: 6.2500e-05
# Epoch 268/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0091 - mae: 0.0528
# Epoch 268: val_loss did not improve from 0.01124
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0091 - mae: 0.0528 - val_loss: 0.0115 - val_mae: 0.0613 - learning_rate: 6.2500e-05
# Epoch 269/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0090 - mae: 0.0520
# Epoch 269: val_loss did not improve from 0.01124
#
# Epoch 269: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0090 - mae: 0.0520 - val_loss: 0.0114 - val_mae: 0.0614 - learning_rate: 6.2500e-05
# Epoch 270/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0092 - mae: 0.0530
# Epoch 270: val_loss did not improve from 0.01124
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0091 - mae: 0.0529 - val_loss: 0.0113 - val_mae: 0.0611 - learning_rate: 3.1250e-05
# Epoch 271/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0089 - mae: 0.0511
# Epoch 271: val_loss did not improve from 0.01124
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0089 - mae: 0.0512 - val_loss: 0.0113 - val_mae: 0.0606 - learning_rate: 3.1250e-05
# Epoch 272/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0085 - mae: 0.0488
# Epoch 272: val_loss improved from 0.01124 to 0.01121, saving model to best_lstm_model_reg.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0085 - mae: 0.0489 - val_loss: 0.0112 - val_mae: 0.0602 - learning_rate: 3.1250e-05
# Epoch 273/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0090 - mae: 0.0519
# Epoch 273: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0090 - mae: 0.0518 - val_loss: 0.0115 - val_mae: 0.0613 - learning_rate: 3.1250e-05
# Epoch 274/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0087 - mae: 0.0507
# Epoch 274: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0088 - mae: 0.0509 - val_loss: 0.0113 - val_mae: 0.0610 - learning_rate: 3.1250e-05
# Epoch 275/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0085 - mae: 0.0492
# Epoch 275: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0085 - mae: 0.0493 - val_loss: 0.0114 - val_mae: 0.0613 - learning_rate: 3.1250e-05
# Epoch 276/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0087 - mae: 0.0500
# Epoch 276: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0087 - mae: 0.0502 - val_loss: 0.0114 - val_mae: 0.0610 - learning_rate: 3.1250e-05
# Epoch 277/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0089 - mae: 0.0516
# Epoch 277: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0089 - mae: 0.0516 - val_loss: 0.0113 - val_mae: 0.0609 - learning_rate: 3.1250e-05
# Epoch 278/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0087 - mae: 0.0495
# Epoch 278: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0087 - mae: 0.0496 - val_loss: 0.0113 - val_mae: 0.0608 - learning_rate: 3.1250e-05
# Epoch 279/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0091 - mae: 0.0531
# Epoch 279: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0091 - mae: 0.0530 - val_loss: 0.0114 - val_mae: 0.0617 - learning_rate: 3.1250e-05
# Epoch 280/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0088 - mae: 0.0508
# Epoch 280: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0088 - mae: 0.0507 - val_loss: 0.0113 - val_mae: 0.0610 - learning_rate: 3.1250e-05
# Epoch 281/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0089 - mae: 0.0522
# Epoch 281: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0090 - mae: 0.0523 - val_loss: 0.0114 - val_mae: 0.0609 - learning_rate: 3.1250e-05
# Epoch 282/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0091 - mae: 0.0524
# Epoch 282: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0091 - mae: 0.0522 - val_loss: 0.0115 - val_mae: 0.0623 - learning_rate: 3.1250e-05
# Epoch 283/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0089 - mae: 0.0519
# Epoch 283: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0089 - mae: 0.0517 - val_loss: 0.0114 - val_mae: 0.0615 - learning_rate: 3.1250e-05
# Epoch 284/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0090 - mae: 0.0521
# Epoch 284: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0090 - mae: 0.0521 - val_loss: 0.0113 - val_mae: 0.0609 - learning_rate: 3.1250e-05
# Epoch 285/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0090 - mae: 0.0522
# Epoch 285: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0090 - mae: 0.0522 - val_loss: 0.0112 - val_mae: 0.0606 - learning_rate: 3.1250e-05
# Epoch 286/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0088 - mae: 0.0511
# Epoch 286: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0088 - mae: 0.0512 - val_loss: 0.0116 - val_mae: 0.0621 - learning_rate: 3.1250e-05
# Epoch 287/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0090 - mae: 0.0524
# Epoch 287: val_loss did not improve from 0.01121
#
# Epoch 287: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0090 - mae: 0.0522 - val_loss: 0.0115 - val_mae: 0.0620 - learning_rate: 3.1250e-05
# Epoch 288/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0088 - mae: 0.0513
# Epoch 288: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0088 - mae: 0.0512 - val_loss: 0.0115 - val_mae: 0.0618 - learning_rate: 1.5625e-05
# Epoch 289/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0088 - mae: 0.0511
# Epoch 289: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0088 - mae: 0.0511 - val_loss: 0.0114 - val_mae: 0.0613 - learning_rate: 1.5625e-05
# Epoch 290/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0084 - mae: 0.0495
# Epoch 290: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0085 - mae: 0.0496 - val_loss: 0.0114 - val_mae: 0.0615 - learning_rate: 1.5625e-05
# Epoch 291/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0088 - mae: 0.0511
# Epoch 291: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0088 - mae: 0.0512 - val_loss: 0.0114 - val_mae: 0.0617 - learning_rate: 1.5625e-05
# Epoch 292/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0088 - mae: 0.0509
# Epoch 292: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0088 - mae: 0.0508 - val_loss: 0.0114 - val_mae: 0.0617 - learning_rate: 1.5625e-05
# Epoch 293/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0088 - mae: 0.0518
# Epoch 293: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0088 - mae: 0.0517 - val_loss: 0.0114 - val_mae: 0.0617 - learning_rate: 1.5625e-05
# Epoch 294/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0087 - mae: 0.0511
# Epoch 294: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0088 - mae: 0.0511 - val_loss: 0.0114 - val_mae: 0.0614 - learning_rate: 1.5625e-05
# Epoch 295/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0089 - mae: 0.0516
# Epoch 295: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0089 - mae: 0.0515 - val_loss: 0.0114 - val_mae: 0.0615 - learning_rate: 1.5625e-05
# Epoch 296/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0088 - mae: 0.0516
# Epoch 296: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0088 - mae: 0.0516 - val_loss: 0.0114 - val_mae: 0.0613 - learning_rate: 1.5625e-05
# Epoch 297/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0087 - mae: 0.0509
# Epoch 297: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0087 - mae: 0.0509 - val_loss: 0.0115 - val_mae: 0.0614 - learning_rate: 1.5625e-05
# Epoch 298/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0088 - mae: 0.0507
# Epoch 298: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0088 - mae: 0.0508 - val_loss: 0.0114 - val_mae: 0.0612 - learning_rate: 1.5625e-05
# Epoch 299/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0089 - mae: 0.0519
# Epoch 299: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0088 - mae: 0.0518 - val_loss: 0.0114 - val_mae: 0.0611 - learning_rate: 1.5625e-05
# Epoch 300/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0089 - mae: 0.0519
# Epoch 300: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0089 - mae: 0.0519 - val_loss: 0.0113 - val_mae: 0.0612 - learning_rate: 1.5625e-05
# Epoch 301/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0088 - mae: 0.0513
# Epoch 301: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0088 - mae: 0.0511 - val_loss: 0.0112 - val_mae: 0.0606 - learning_rate: 1.5625e-05
# Epoch 302/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0089 - mae: 0.0514
# Epoch 302: val_loss did not improve from 0.01121
#
# Epoch 302: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0089 - mae: 0.0515 - val_loss: 0.0113 - val_mae: 0.0608 - learning_rate: 1.5625e-05
# Epoch 303/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0089 - mae: 0.0515
# Epoch 303: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0088 - mae: 0.0514 - val_loss: 0.0114 - val_mae: 0.0610 - learning_rate: 7.8125e-06
# Epoch 304/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0091 - mae: 0.0528
# Epoch 304: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0091 - mae: 0.0528 - val_loss: 0.0113 - val_mae: 0.0609 - learning_rate: 7.8125e-06
# Epoch 305/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0090 - mae: 0.0523
# Epoch 305: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0090 - mae: 0.0523 - val_loss: 0.0113 - val_mae: 0.0611 - learning_rate: 7.8125e-06
# Epoch 306/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0087 - mae: 0.0503
# Epoch 306: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0088 - mae: 0.0504 - val_loss: 0.0114 - val_mae: 0.0613 - learning_rate: 7.8125e-06
# Epoch 307/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0083 - mae: 0.0482
# Epoch 307: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0084 - mae: 0.0484 - val_loss: 0.0114 - val_mae: 0.0610 - learning_rate: 7.8125e-06
# Epoch 308/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0090 - mae: 0.0523
# Epoch 308: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0090 - mae: 0.0523 - val_loss: 0.0113 - val_mae: 0.0608 - learning_rate: 7.8125e-06
# Epoch 309/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0087 - mae: 0.0508
# Epoch 309: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0087 - mae: 0.0508 - val_loss: 0.0113 - val_mae: 0.0610 - learning_rate: 7.8125e-06
# Epoch 310/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0085 - mae: 0.0497
# Epoch 310: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0085 - mae: 0.0497 - val_loss: 0.0114 - val_mae: 0.0610 - learning_rate: 7.8125e-06
# Epoch 311/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0083 - mae: 0.0483
# Epoch 311: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0084 - mae: 0.0485 - val_loss: 0.0113 - val_mae: 0.0607 - learning_rate: 7.8125e-06
# Epoch 312/500
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0086 - mae: 0.0499
# Epoch 312: val_loss did not improve from 0.01121
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0086 - mae: 0.0500 - val_loss: 0.0113 - val_mae: 0.0610 - learning_rate: 7.8125e-06
# Epoch 312: early stopping
# Restoring model weights from the end of the best epoch: 272.

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import  mean_absolute_error

# model  = load_model("/content/best_lstm_model_reg.keras")
# پیش‌بینی روی داده تست-
y_pred_scaled = final_model.predict(X_windows_test)  # (N, 1)

# برگرداندن به مقیاس اصلی
y_pred_original = y_scaler.inverse_transform(y_pred_scaled)
y_true_original = y_scaler.inverse_transform(y_windows_test)




mae = mean_absolute_error(y_true_original, y_pred_original)
mae2 = mean_absolute_error(y_windows_test, y_pred_scaled)

print(f"Test MAE(scaled): {mae2:.3f}")
print(f"Test MAE(true value): {mae:.3f}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step
# Test MAE(scaled): 0.056
# Test MAE(true value): 0.802

# %%
import matplotlib.pyplot as plt

# Set font sizes and styles for publication
plt.rcParams.update({
    'font.size': 14,
    'axes.labelsize': 16,
    'axes.titlesize': 18,
    'legend.fontsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'font.family': 'serif',  # Optional: use serif font (common in papers)
    'figure.figsize': (8, 5)
})

# Plot training & validation loss
plt.plot(history.history["loss"], label="Training Loss", linewidth=2.5, color='tab:blue')
plt.plot(history.history["val_loss"], label="Validation Loss", linewidth=2.5, color='tab:red')

# Add title and axis labels
plt.title("Model Training Progress", fontsize=18, pad=20)
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")

# Improve layout and add grid
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.legend(frameon=True, loc='upper right', shadow=False, edgecolor='black')

# Use tight layout to prevent clipping
plt.tight_layout()

# Save high-resolution figure for your article
plt.savefig("training_validation_loss.pdf", format='pdf', dpi=300, bbox_inches='tight')
plt.savefig("training_validation_loss.png", format='png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import pickle

with open('training_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
# time = np.arange(1, y_true_original.shape[0]+1) * 0.01
# time = time.reshape(-1, 1)

plt.figure(figsize=(15,10))
plt.plot(y_true_original[222,:])
plt.plot(y_pred_original[222,:])
plt.grid()
