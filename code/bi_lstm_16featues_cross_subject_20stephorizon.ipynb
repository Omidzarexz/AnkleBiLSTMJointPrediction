# %%
# !git clone https://github.com/Omidzarexz/crispy-computing-machine
# Out:
# fatal: destination path 'crispy-computing-machine' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt


# df_clean_train_12feature_cross_subject = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_train_12feature_cross_subject.csv")
# df_clean_test_12feature_cross_subject  = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_test_12feature_cross_subject.csv")


df_clean_train_16feature_cross_subject = pd.read_csv("/content/crispy-computing-machine/df_clean_train_16feature_cross_subject.csv")
df_clean_test_16feature_cross_subject  = pd.read_csv("/content/crispy-computing-machine/df_clean_test_16feature_cross_subject.csv")


# df_clean_train_16feature_within_subject = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_train_16feature_within_subject_txt25.csv")
# df_clean_test_16feature_within_subject  = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_test_16feature_within_subject_txt25.csv")

df_clean_train = df_clean_train_16feature_cross_subject
df_clean_test  = df_clean_test_16feature_cross_subject

# %%
from scipy.signal import butter, filtfilt

def low_pass_butter(signal, cutoff=10, fs=100, order=2):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return filtfilt(b, a, signal)
feature_columns = [
    'MPU1_Acc_X', 'MPU1_Acc_Y', 'MPU1_Acc_Z',
    'MPU1_Gyro_X', 'MPU1_Gyro_Y', 'MPU1_Gyro_Z',
    'MPU1_Roll','MPU1_Pitch',
    'MPU2_Acc_X', 'MPU2_Acc_Y', 'MPU2_Acc_Z',
    'MPU2_Gyro_X', 'MPU2_Gyro_Y', 'MPU2_Gyro_Z',
    'MPU2_Roll','MPU2_Pitch'
]




df_filtered_trainig = pd.DataFrame()
df_filtered_test    = pd.DataFrame()
for col in feature_columns:
    df_filtered_trainig[col] = low_pass_butter( df_clean_train[col].values
                                        , cutoff=5 # Hz
                                        , fs=100  # Hz
                                        , order=2  )
    df_filtered_test[col] = low_pass_butter( df_clean_test[col].values
                                        , cutoff=5 # Hz
                                        , fs=100  # Hz
                                        , order=2  )







print("\ndf_filtered_trainig shape:",df_filtered_trainig.shape)
print("\ndf_filtered_test shape:",df_filtered_test.shape)
# Out:
# df_filtered_trainig shape: (87394, 16)
#
# df_filtered_test shape: (17492, 16)

# %%
from sklearn.preprocessing import  MinMaxScaler


scaler = MinMaxScaler(feature_range=(-1, 1))
X_data_train = scaler.fit_transform(df_filtered_trainig[feature_columns].values)  # (T, 12)


y_scaler = MinMaxScaler(feature_range=(-1, 1))
y_data_train = y_scaler.fit_transform(df_clean_train['angle'].values.reshape(-1, 1))





X_data_test = scaler.transform(df_filtered_test[feature_columns].values)

y_data_test = y_scaler.transform(df_clean_test["angle"].values.reshape(-1,1))


# تنظیمات پنجره
window_size = 200   #
horizon = 20        #
step_size = 5      #

# تابع پنجره‌بندی
def create_windows_with_labels(X, y, window_size, horizon, step_size):
    X_windows = []
    y_windows = []
    for i in range(0,  len(X) - window_size - horizon + 1, step_size):
        X_windows.append(X[i:i + window_size])
        y_windows.append(y[i + window_size : i + window_size + horizon])  # برچسب آخرین نمونه در پنجره
    return np.array(X_windows), np.array(y_windows)

# ایجاد پنجره‌ها
X_windows, y_windows = create_windows_with_labels(X_data_train, y_data_train,
                                                  window_size, horizon, step_size)
if horizon==1:
    y_windows = y_windows.reshape(-1,1)
else:
    y_windows = np.squeeze(y_windows, axis=2)





print(f"✅   (X_windows):(samples, time steps, features) → {X_windows.shape}")
print(f"✅  (y_windows): {y_windows.shape}")

step_size_for_test = 1
X_windows_test, y_windows_test = create_windows_with_labels(X_data_test, y_data_test,
                                                            window_size, horizon, step_size_for_test)

if horizon==1:
    y_windows_test = y_windows_test.reshape(-1,1)
else:
    y_windows_test = np.squeeze(y_windows_test, axis=2)

print(f"\n✅   (X_windows_test):(samples, time steps, features) → {X_windows_test.shape}")
print(f"✅  (y_windows_test): {y_windows_test.shape}")
# Out:
# ✅   (X_windows):(samples, time steps, features) → (17435, 200, 16)
# ✅  (y_windows): (17435, 20)
#
# ✅   (X_windows_test):(samples, time steps, features) → (17273, 200, 16)
# ✅  (y_windows_test): (17273, 20)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from keras.layers import Bidirectional

from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, GlobalAveragePooling1D
from tensorflow.keras.layers import Input, Dense, GRU, Bidirectional, Dropout, ReLU, TimeDistributed, LayerNormalization
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l2

LEARNING_RATE = 0.001
lambda_loss_amount = 0.0005



def build_bi_lstm_model(input_shape, horizon=1, lambda_loss_amount=1e-4, learning_rate=1e-3):
    inputs = Input(shape=input_shape, name="input")

    # Dense projection per timestep
    x = TimeDistributed(Dense(64, kernel_regularizer=l2(lambda_loss_amount)))(inputs)
    x = ReLU()(x)

    # Stacked BiGRU layers
    x = Bidirectional(LSTM(64, return_sequences=True,
                           kernel_regularizer=l2(lambda_loss_amount)))(x)
    x = LayerNormalization()(x)
    x = Dropout(0.3)(x)

    x = Bidirectional(LSTM(32, return_sequences=False,
                           kernel_regularizer=l2(lambda_loss_amount)))(x)
    x = Dropout(0.3)(x)

    # Output
    outputs = Dense(horizon, activation='linear')(x)

    # Model compile
    model = Model(inputs=inputs, outputs=outputs, name="BiLSTM_reg")
    model.compile(optimizer=optimizers.Adam(learning_rate=learning_rate),
                  loss='mse',
                  metrics=['mae'])
    return model

final_model = build_bi_lstm_model(input_shape=(X_windows.shape[1],X_windows.shape[2]),horizon=horizon)

# final_model.summary()

plot_model(final_model, show_shapes=True , dpi=80)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from sklearn.model_selection import train_test_split


X_train, X_val, y_train, y_val = train_test_split( X_windows, y_windows, test_size=0.2,
                                                   shuffle=False, random_state=42)


callbacks = [
    ModelCheckpoint('best_lstm_model_reg.keras', save_best_only=True, monitor='val_loss',verbose=1),
    EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True,verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=5e-6,verbose=1)
]

history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=500,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1343 - mae: 0.2272
# Epoch 1: val_loss improved from inf to 0.05113, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 33s 72ms/step - loss: 0.1341 - mae: 0.2270 - val_loss: 0.0511 - val_mae: 0.1222 - learning_rate: 0.0010
# Epoch 2/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0481 - mae: 0.1187
# Epoch 2: val_loss improved from 0.05113 to 0.03344, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0481 - mae: 0.1186 - val_loss: 0.0334 - val_mae: 0.1005 - learning_rate: 0.0010
# Epoch 3/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0330 - mae: 0.0969
# Epoch 3: val_loss improved from 0.03344 to 0.03127, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0330 - mae: 0.0969 - val_loss: 0.0313 - val_mae: 0.1081 - learning_rate: 0.0010
# Epoch 4/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0262 - mae: 0.0880
# Epoch 4: val_loss improved from 0.03127 to 0.02604, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0262 - mae: 0.0880 - val_loss: 0.0260 - val_mae: 0.1008 - learning_rate: 0.0010
# Epoch 5/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0221 - mae: 0.0826
# Epoch 5: val_loss improved from 0.02604 to 0.02410, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 0.0221 - mae: 0.0826 - val_loss: 0.0241 - val_mae: 0.1001 - learning_rate: 0.0010
# Epoch 6/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0196 - mae: 0.0800
# Epoch 6: val_loss improved from 0.02410 to 0.02029, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0196 - mae: 0.0800 - val_loss: 0.0203 - val_mae: 0.0905 - learning_rate: 0.0010
# Epoch 7/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0176 - mae: 0.0768
# Epoch 7: val_loss improved from 0.02029 to 0.02006, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0176 - mae: 0.0768 - val_loss: 0.0201 - val_mae: 0.0947 - learning_rate: 0.0010
# Epoch 8/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0161 - mae: 0.0748
# Epoch 8: val_loss did not improve from 0.02006
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0161 - mae: 0.0748 - val_loss: 0.0207 - val_mae: 0.0981 - learning_rate: 0.0010
# Epoch 9/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0148 - mae: 0.0726
# Epoch 9: val_loss improved from 0.02006 to 0.01757, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0148 - mae: 0.0726 - val_loss: 0.0176 - val_mae: 0.0863 - learning_rate: 0.0010
# Epoch 10/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0135 - mae: 0.0691
# Epoch 10: val_loss improved from 0.01757 to 0.01508, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - loss: 0.0135 - mae: 0.0691 - val_loss: 0.0151 - val_mae: 0.0808 - learning_rate: 0.0010
# Epoch 11/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0127 - mae: 0.0682
# Epoch 11: val_loss did not improve from 0.01508
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - loss: 0.0127 - mae: 0.0682 - val_loss: 0.0161 - val_mae: 0.0886 - learning_rate: 0.0010
# Epoch 12/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0126 - mae: 0.0687
# Epoch 12: val_loss did not improve from 0.01508
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0126 - mae: 0.0687 - val_loss: 0.0164 - val_mae: 0.0879 - learning_rate: 0.0010
# Epoch 13/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0116 - mae: 0.0660
# Epoch 13: val_loss did not improve from 0.01508
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0116 - mae: 0.0660 - val_loss: 0.0169 - val_mae: 0.0871 - learning_rate: 0.0010
# Epoch 14/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0115 - mae: 0.0668
# Epoch 14: val_loss improved from 0.01508 to 0.01434, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0115 - mae: 0.0668 - val_loss: 0.0143 - val_mae: 0.0802 - learning_rate: 0.0010
# Epoch 15/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0111 - mae: 0.0658
# Epoch 15: val_loss did not improve from 0.01434
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0111 - mae: 0.0658 - val_loss: 0.0165 - val_mae: 0.0930 - learning_rate: 0.0010
# Epoch 16/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0106 - mae: 0.0643
# Epoch 16: val_loss improved from 0.01434 to 0.01399, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0106 - mae: 0.0643 - val_loss: 0.0140 - val_mae: 0.0847 - learning_rate: 0.0010
# Epoch 17/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0105 - mae: 0.0644
# Epoch 17: val_loss did not improve from 0.01399
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0105 - mae: 0.0644 - val_loss: 0.0157 - val_mae: 0.0892 - learning_rate: 0.0010
# Epoch 18/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0100 - mae: 0.0622
# Epoch 18: val_loss improved from 0.01399 to 0.01337, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 11s 49ms/step - loss: 0.0100 - mae: 0.0622 - val_loss: 0.0134 - val_mae: 0.0832 - learning_rate: 0.0010
# Epoch 19/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0099 - mae: 0.0628
# Epoch 19: val_loss improved from 0.01337 to 0.01326, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0099 - mae: 0.0628 - val_loss: 0.0133 - val_mae: 0.0796 - learning_rate: 0.0010
# Epoch 20/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0095 - mae: 0.0615
# Epoch 20: val_loss did not improve from 0.01326
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0095 - mae: 0.0615 - val_loss: 0.0138 - val_mae: 0.0853 - learning_rate: 0.0010
# Epoch 21/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0094 - mae: 0.0612
# Epoch 21: val_loss improved from 0.01326 to 0.01223, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0094 - mae: 0.0612 - val_loss: 0.0122 - val_mae: 0.0778 - learning_rate: 0.0010
# Epoch 22/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0092 - mae: 0.0607
# Epoch 22: val_loss did not improve from 0.01223
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 0.0092 - mae: 0.0607 - val_loss: 0.0130 - val_mae: 0.0815 - learning_rate: 0.0010
# Epoch 23/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0091 - mae: 0.0611
# Epoch 23: val_loss did not improve from 0.01223
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0091 - mae: 0.0611 - val_loss: 0.0147 - val_mae: 0.0897 - learning_rate: 0.0010
# Epoch 24/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0093 - mae: 0.0621
# Epoch 24: val_loss did not improve from 0.01223
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0093 - mae: 0.0621 - val_loss: 0.0123 - val_mae: 0.0827 - learning_rate: 0.0010
# Epoch 25/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0088 - mae: 0.0598
# Epoch 25: val_loss did not improve from 0.01223
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0088 - mae: 0.0598 - val_loss: 0.0140 - val_mae: 0.0875 - learning_rate: 0.0010
# Epoch 26/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0088 - mae: 0.0603
# Epoch 26: val_loss did not improve from 0.01223
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0088 - mae: 0.0603 - val_loss: 0.0123 - val_mae: 0.0806 - learning_rate: 0.0010
# Epoch 27/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0093 - mae: 0.0633
# Epoch 27: val_loss did not improve from 0.01223
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0093 - mae: 0.0633 - val_loss: 0.0129 - val_mae: 0.0818 - learning_rate: 0.0010
# Epoch 28/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0104 - mae: 0.0678
# Epoch 28: val_loss improved from 0.01223 to 0.01169, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0104 - mae: 0.0678 - val_loss: 0.0117 - val_mae: 0.0788 - learning_rate: 0.0010
# Epoch 29/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0097 - mae: 0.0651
# Epoch 29: val_loss improved from 0.01169 to 0.01048, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0097 - mae: 0.0651 - val_loss: 0.0105 - val_mae: 0.0724 - learning_rate: 0.0010
# Epoch 30/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0094 - mae: 0.0633
# Epoch 30: val_loss did not improve from 0.01048
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0094 - mae: 0.0633 - val_loss: 0.0109 - val_mae: 0.0756 - learning_rate: 0.0010
# Epoch 31/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0091 - mae: 0.0624
# Epoch 31: val_loss improved from 0.01048 to 0.00967, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0091 - mae: 0.0624 - val_loss: 0.0097 - val_mae: 0.0674 - learning_rate: 0.0010
# Epoch 32/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0100 - mae: 0.0673
# Epoch 32: val_loss did not improve from 0.00967
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0100 - mae: 0.0673 - val_loss: 0.0122 - val_mae: 0.0822 - learning_rate: 0.0010
# Epoch 33/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0123 - mae: 0.0729
# Epoch 33: val_loss did not improve from 0.00967
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0123 - mae: 0.0730 - val_loss: 0.0142 - val_mae: 0.0872 - learning_rate: 0.0010
# Epoch 34/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0101 - mae: 0.0655
# Epoch 34: val_loss did not improve from 0.00967
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0101 - mae: 0.0655 - val_loss: 0.0116 - val_mae: 0.0751 - learning_rate: 0.0010
# Epoch 35/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0093 - mae: 0.0622
# Epoch 35: val_loss did not improve from 0.00967
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0093 - mae: 0.0622 - val_loss: 0.0119 - val_mae: 0.0778 - learning_rate: 0.0010
# Epoch 36/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0094 - mae: 0.0633
# Epoch 36: val_loss did not improve from 0.00967
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0094 - mae: 0.0633 - val_loss: 0.0132 - val_mae: 0.0847 - learning_rate: 0.0010
# Epoch 37/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0088 - mae: 0.0605
# Epoch 37: val_loss did not improve from 0.00967
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0088 - mae: 0.0605 - val_loss: 0.0146 - val_mae: 0.0901 - learning_rate: 0.0010
# Epoch 38/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0091 - mae: 0.0626
# Epoch 38: val_loss did not improve from 0.00967
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0091 - mae: 0.0626 - val_loss: 0.0129 - val_mae: 0.0845 - learning_rate: 0.0010
# Epoch 39/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0089 - mae: 0.0617
# Epoch 39: val_loss did not improve from 0.00967
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0089 - mae: 0.0617 - val_loss: 0.0098 - val_mae: 0.0717 - learning_rate: 0.0010
# Epoch 40/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0085 - mae: 0.0602
# Epoch 40: val_loss did not improve from 0.00967
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0085 - mae: 0.0602 - val_loss: 0.0111 - val_mae: 0.0749 - learning_rate: 0.0010
# Epoch 41/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0083 - mae: 0.0596
# Epoch 41: val_loss did not improve from 0.00967
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0083 - mae: 0.0596 - val_loss: 0.0106 - val_mae: 0.0735 - learning_rate: 0.0010
# Epoch 42/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0085 - mae: 0.0602
# Epoch 42: val_loss did not improve from 0.00967
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0085 - mae: 0.0602 - val_loss: 0.0135 - val_mae: 0.0888 - learning_rate: 0.0010
# Epoch 43/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0085 - mae: 0.0606
# Epoch 43: val_loss improved from 0.00967 to 0.00856, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0085 - mae: 0.0606 - val_loss: 0.0086 - val_mae: 0.0654 - learning_rate: 0.0010
# Epoch 44/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0082 - mae: 0.0600
# Epoch 44: val_loss did not improve from 0.00856
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0082 - mae: 0.0600 - val_loss: 0.0112 - val_mae: 0.0809 - learning_rate: 0.0010
# Epoch 45/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0084 - mae: 0.0604
# Epoch 45: val_loss did not improve from 0.00856
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0084 - mae: 0.0604 - val_loss: 0.0096 - val_mae: 0.0718 - learning_rate: 0.0010
# Epoch 46/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0079 - mae: 0.0583
# Epoch 46: val_loss did not improve from 0.00856
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0079 - mae: 0.0583 - val_loss: 0.0107 - val_mae: 0.0741 - learning_rate: 0.0010
# Epoch 47/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0081 - mae: 0.0592
# Epoch 47: val_loss did not improve from 0.00856
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0081 - mae: 0.0592 - val_loss: 0.0087 - val_mae: 0.0679 - learning_rate: 0.0010
# Epoch 48/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0079 - mae: 0.0586
# Epoch 48: val_loss did not improve from 0.00856
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0079 - mae: 0.0586 - val_loss: 0.0123 - val_mae: 0.0871 - learning_rate: 0.0010
# Epoch 49/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0081 - mae: 0.0594
# Epoch 49: val_loss did not improve from 0.00856
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0081 - mae: 0.0594 - val_loss: 0.0168 - val_mae: 0.1031 - learning_rate: 0.0010
# Epoch 50/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0078 - mae: 0.0583
# Epoch 50: val_loss did not improve from 0.00856
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0078 - mae: 0.0583 - val_loss: 0.0109 - val_mae: 0.0776 - learning_rate: 0.0010
# Epoch 51/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0080 - mae: 0.0593
# Epoch 51: val_loss improved from 0.00856 to 0.00837, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0080 - mae: 0.0593 - val_loss: 0.0084 - val_mae: 0.0659 - learning_rate: 0.0010
# Epoch 52/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0077 - mae: 0.0580
# Epoch 52: val_loss did not improve from 0.00837
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0077 - mae: 0.0580 - val_loss: 0.0085 - val_mae: 0.0678 - learning_rate: 0.0010
# Epoch 53/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0080 - mae: 0.0592
# Epoch 53: val_loss did not improve from 0.00837
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0080 - mae: 0.0592 - val_loss: 0.0129 - val_mae: 0.0864 - learning_rate: 0.0010
# Epoch 54/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0076 - mae: 0.0572
# Epoch 54: val_loss did not improve from 0.00837
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0076 - mae: 0.0572 - val_loss: 0.0138 - val_mae: 0.0900 - learning_rate: 0.0010
# Epoch 55/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0078 - mae: 0.0586
# Epoch 55: val_loss did not improve from 0.00837
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0078 - mae: 0.0586 - val_loss: 0.0114 - val_mae: 0.0822 - learning_rate: 0.0010
# Epoch 56/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0077 - mae: 0.0584
# Epoch 56: val_loss did not improve from 0.00837
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0077 - mae: 0.0584 - val_loss: 0.0193 - val_mae: 0.1126 - learning_rate: 0.0010
# Epoch 57/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0077 - mae: 0.0584
# Epoch 57: val_loss did not improve from 0.00837
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0077 - mae: 0.0584 - val_loss: 0.0097 - val_mae: 0.0742 - learning_rate: 0.0010
# Epoch 58/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0076 - mae: 0.0579
# Epoch 58: val_loss did not improve from 0.00837
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0076 - mae: 0.0579 - val_loss: 0.0151 - val_mae: 0.0999 - learning_rate: 0.0010
# Epoch 59/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0078 - mae: 0.0592
# Epoch 59: val_loss did not improve from 0.00837
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0078 - mae: 0.0592 - val_loss: 0.0118 - val_mae: 0.0834 - learning_rate: 0.0010
# Epoch 60/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0074 - mae: 0.0574
# Epoch 60: val_loss did not improve from 0.00837
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0074 - mae: 0.0574 - val_loss: 0.0097 - val_mae: 0.0755 - learning_rate: 0.0010
# Epoch 61/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0074 - mae: 0.0573
# Epoch 61: val_loss did not improve from 0.00837
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0074 - mae: 0.0573 - val_loss: 0.0126 - val_mae: 0.0884 - learning_rate: 0.0010
# Epoch 62/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0071 - mae: 0.0557
# Epoch 62: val_loss did not improve from 0.00837
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0071 - mae: 0.0557 - val_loss: 0.0105 - val_mae: 0.0797 - learning_rate: 0.0010
# Epoch 63/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0073 - mae: 0.0567
# Epoch 63: val_loss did not improve from 0.00837
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0073 - mae: 0.0567 - val_loss: 0.0086 - val_mae: 0.0686 - learning_rate: 0.0010
# Epoch 64/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0071 - mae: 0.0562
# Epoch 64: val_loss did not improve from 0.00837
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0071 - mae: 0.0562 - val_loss: 0.0097 - val_mae: 0.0732 - learning_rate: 0.0010
# Epoch 65/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0071 - mae: 0.0563
# Epoch 65: val_loss improved from 0.00837 to 0.00745, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0071 - mae: 0.0563 - val_loss: 0.0075 - val_mae: 0.0629 - learning_rate: 0.0010
# Epoch 66/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0071 - mae: 0.0562
# Epoch 66: val_loss did not improve from 0.00745
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0071 - mae: 0.0562 - val_loss: 0.0109 - val_mae: 0.0797 - learning_rate: 0.0010
# Epoch 67/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0070 - mae: 0.0553
# Epoch 67: val_loss did not improve from 0.00745
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 0.0070 - mae: 0.0553 - val_loss: 0.0161 - val_mae: 0.1034 - learning_rate: 0.0010
# Epoch 68/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0073 - mae: 0.0571
# Epoch 68: val_loss improved from 0.00745 to 0.00730, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0073 - mae: 0.0571 - val_loss: 0.0073 - val_mae: 0.0617 - learning_rate: 0.0010
# Epoch 69/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0072 - mae: 0.0565
# Epoch 69: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0072 - mae: 0.0565 - val_loss: 0.0141 - val_mae: 0.0941 - learning_rate: 0.0010
# Epoch 70/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0072 - mae: 0.0570
# Epoch 70: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0072 - mae: 0.0570 - val_loss: 0.0123 - val_mae: 0.0869 - learning_rate: 0.0010
# Epoch 71/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0071 - mae: 0.0564
# Epoch 71: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0071 - mae: 0.0564 - val_loss: 0.0128 - val_mae: 0.0897 - learning_rate: 0.0010
# Epoch 72/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0068 - mae: 0.0551
# Epoch 72: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0068 - mae: 0.0551 - val_loss: 0.0092 - val_mae: 0.0722 - learning_rate: 0.0010
# Epoch 73/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0067 - mae: 0.0547
# Epoch 73: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0067 - mae: 0.0547 - val_loss: 0.0139 - val_mae: 0.0931 - learning_rate: 0.0010
# Epoch 74/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0068 - mae: 0.0552
# Epoch 74: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0068 - mae: 0.0552 - val_loss: 0.0119 - val_mae: 0.0849 - learning_rate: 0.0010
# Epoch 75/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0066 - mae: 0.0538
# Epoch 75: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0066 - mae: 0.0538 - val_loss: 0.0139 - val_mae: 0.0947 - learning_rate: 0.0010
# Epoch 76/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0069 - mae: 0.0555
# Epoch 76: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0069 - mae: 0.0555 - val_loss: 0.0174 - val_mae: 0.1086 - learning_rate: 0.0010
# Epoch 77/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0067 - mae: 0.0545
# Epoch 77: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - loss: 0.0067 - mae: 0.0545 - val_loss: 0.0132 - val_mae: 0.0934 - learning_rate: 0.0010
# Epoch 78/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0068 - mae: 0.0556
# Epoch 78: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - loss: 0.0068 - mae: 0.0556 - val_loss: 0.0107 - val_mae: 0.0800 - learning_rate: 0.0010
# Epoch 79/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0067 - mae: 0.0544
# Epoch 79: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 11s 50ms/step - loss: 0.0067 - mae: 0.0544 - val_loss: 0.0174 - val_mae: 0.1086 - learning_rate: 0.0010
# Epoch 80/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0070 - mae: 0.0566
# Epoch 80: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0070 - mae: 0.0565 - val_loss: 0.0097 - val_mae: 0.0751 - learning_rate: 0.0010
# Epoch 81/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0067 - mae: 0.0547
# Epoch 81: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0067 - mae: 0.0547 - val_loss: 0.0142 - val_mae: 0.0961 - learning_rate: 0.0010
# Epoch 82/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0067 - mae: 0.0548
# Epoch 82: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0067 - mae: 0.0548 - val_loss: 0.0119 - val_mae: 0.0851 - learning_rate: 0.0010
# Epoch 83/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0068 - mae: 0.0559
# Epoch 83: val_loss did not improve from 0.00730
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0068 - mae: 0.0559 - val_loss: 0.0117 - val_mae: 0.0864 - learning_rate: 0.0010
# Epoch 84/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0062 - mae: 0.0519
# Epoch 84: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0062 - mae: 0.0518 - val_loss: 0.0136 - val_mae: 0.0940 - learning_rate: 5.0000e-04
# Epoch 85/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0059 - mae: 0.0505
# Epoch 85: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - loss: 0.0059 - mae: 0.0505 - val_loss: 0.0123 - val_mae: 0.0870 - learning_rate: 5.0000e-04
# Epoch 86/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0058 - mae: 0.0501
# Epoch 86: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0058 - mae: 0.0501 - val_loss: 0.0104 - val_mae: 0.0798 - learning_rate: 5.0000e-04
# Epoch 87/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0059 - mae: 0.0507
# Epoch 87: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 0.0059 - mae: 0.0507 - val_loss: 0.0099 - val_mae: 0.0769 - learning_rate: 5.0000e-04
# Epoch 88/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0058 - mae: 0.0501
# Epoch 88: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 11s 49ms/step - loss: 0.0058 - mae: 0.0501 - val_loss: 0.0148 - val_mae: 0.0982 - learning_rate: 5.0000e-04
# Epoch 89/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0058 - mae: 0.0505
# Epoch 89: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - loss: 0.0058 - mae: 0.0505 - val_loss: 0.0127 - val_mae: 0.0915 - learning_rate: 5.0000e-04
# Epoch 90/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0056 - mae: 0.0494
# Epoch 90: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 11s 49ms/step - loss: 0.0056 - mae: 0.0494 - val_loss: 0.0111 - val_mae: 0.0839 - learning_rate: 5.0000e-04
# Epoch 91/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0058 - mae: 0.0507
# Epoch 91: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 11s 50ms/step - loss: 0.0058 - mae: 0.0507 - val_loss: 0.0111 - val_mae: 0.0825 - learning_rate: 5.0000e-04
# Epoch 92/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0059 - mae: 0.0509
# Epoch 92: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 11s 50ms/step - loss: 0.0059 - mae: 0.0509 - val_loss: 0.0127 - val_mae: 0.0925 - learning_rate: 5.0000e-04
# Epoch 93/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0057 - mae: 0.0502
# Epoch 93: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0057 - mae: 0.0502 - val_loss: 0.0116 - val_mae: 0.0858 - learning_rate: 5.0000e-04
# Epoch 94/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0055 - mae: 0.0491
# Epoch 94: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 0.0055 - mae: 0.0491 - val_loss: 0.0100 - val_mae: 0.0792 - learning_rate: 5.0000e-04
# Epoch 95/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0059 - mae: 0.0517
# Epoch 95: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 11s 49ms/step - loss: 0.0059 - mae: 0.0517 - val_loss: 0.0101 - val_mae: 0.0780 - learning_rate: 5.0000e-04
# Epoch 96/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0058 - mae: 0.0506
# Epoch 96: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0058 - mae: 0.0506 - val_loss: 0.0133 - val_mae: 0.0931 - learning_rate: 5.0000e-04
# Epoch 97/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0056 - mae: 0.0497
# Epoch 97: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0056 - mae: 0.0497 - val_loss: 0.0133 - val_mae: 0.0953 - learning_rate: 5.0000e-04
# Epoch 98/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0056 - mae: 0.0496
# Epoch 98: val_loss did not improve from 0.00730
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 0.0056 - mae: 0.0496 - val_loss: 0.0133 - val_mae: 0.0939 - learning_rate: 5.0000e-04
# Epoch 99/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0054 - mae: 0.0483
# Epoch 99: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0054 - mae: 0.0483 - val_loss: 0.0134 - val_mae: 0.0947 - learning_rate: 2.5000e-04
# Epoch 100/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0053 - mae: 0.0476
# Epoch 100: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0053 - mae: 0.0476 - val_loss: 0.0124 - val_mae: 0.0920 - learning_rate: 2.5000e-04
# Epoch 101/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0051 - mae: 0.0472
# Epoch 101: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0051 - mae: 0.0472 - val_loss: 0.0103 - val_mae: 0.0814 - learning_rate: 2.5000e-04
# Epoch 102/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0052 - mae: 0.0478
# Epoch 102: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0052 - mae: 0.0478 - val_loss: 0.0125 - val_mae: 0.0915 - learning_rate: 2.5000e-04
# Epoch 103/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0051 - mae: 0.0470
# Epoch 103: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0051 - mae: 0.0470 - val_loss: 0.0155 - val_mae: 0.1049 - learning_rate: 2.5000e-04
# Epoch 104/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0051 - mae: 0.0473
# Epoch 104: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 0.0051 - mae: 0.0473 - val_loss: 0.0128 - val_mae: 0.0926 - learning_rate: 2.5000e-04
# Epoch 105/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0050 - mae: 0.0466
# Epoch 105: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0050 - mae: 0.0466 - val_loss: 0.0145 - val_mae: 0.0986 - learning_rate: 2.5000e-04
# Epoch 106/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0050 - mae: 0.0467
# Epoch 106: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0050 - mae: 0.0467 - val_loss: 0.0141 - val_mae: 0.0990 - learning_rate: 2.5000e-04
# Epoch 107/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0051 - mae: 0.0472
# Epoch 107: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0051 - mae: 0.0472 - val_loss: 0.0103 - val_mae: 0.0810 - learning_rate: 2.5000e-04
# Epoch 108/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0051 - mae: 0.0470
# Epoch 108: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - loss: 0.0051 - mae: 0.0470 - val_loss: 0.0133 - val_mae: 0.0954 - learning_rate: 2.5000e-04
# Epoch 109/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0052 - mae: 0.0476
# Epoch 109: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 0.0052 - mae: 0.0476 - val_loss: 0.0120 - val_mae: 0.0889 - learning_rate: 2.5000e-04
# Epoch 110/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0051 - mae: 0.0473
# Epoch 110: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0051 - mae: 0.0473 - val_loss: 0.0155 - val_mae: 0.1046 - learning_rate: 2.5000e-04
# Epoch 111/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0049 - mae: 0.0462
# Epoch 111: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0049 - mae: 0.0462 - val_loss: 0.0137 - val_mae: 0.0971 - learning_rate: 2.5000e-04
# Epoch 112/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0050 - mae: 0.0466
# Epoch 112: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0050 - mae: 0.0466 - val_loss: 0.0111 - val_mae: 0.0856 - learning_rate: 2.5000e-04
# Epoch 113/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0051 - mae: 0.0474
# Epoch 113: val_loss did not improve from 0.00730
#
# Epoch 113: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0051 - mae: 0.0474 - val_loss: 0.0098 - val_mae: 0.0792 - learning_rate: 2.5000e-04
# Epoch 114/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0048 - mae: 0.0458
# Epoch 114: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 0.0048 - mae: 0.0458 - val_loss: 0.0130 - val_mae: 0.0930 - learning_rate: 1.2500e-04
# Epoch 115/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0048 - mae: 0.0456
# Epoch 115: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0048 - mae: 0.0456 - val_loss: 0.0121 - val_mae: 0.0904 - learning_rate: 1.2500e-04
# Epoch 116/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0048 - mae: 0.0453
# Epoch 116: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0048 - mae: 0.0453 - val_loss: 0.0140 - val_mae: 0.0985 - learning_rate: 1.2500e-04
# Epoch 117/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0048 - mae: 0.0453
# Epoch 117: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0048 - mae: 0.0453 - val_loss: 0.0120 - val_mae: 0.0903 - learning_rate: 1.2500e-04
# Epoch 118/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0047 - mae: 0.0451
# Epoch 118: val_loss did not improve from 0.00730
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0047 - mae: 0.0451 - val_loss: 0.0108 - val_mae: 0.0843 - learning_rate: 1.2500e-04
# Epoch 118: early stopping
# Restoring model weights from the end of the best epoch: 68.

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import  mean_absolute_error


# پیش‌بینی روی داده تست
y_pred_scaled = final_model.predict(X_windows_test)  # (N, 1)

# برگرداندن به مقیاس اصلی
y_pred_original = y_scaler.inverse_transform(y_pred_scaled)
y_true_original = y_scaler.inverse_transform(y_windows_test)




mae = mean_absolute_error(y_true_original, y_pred_original)
mae2 = mean_absolute_error(y_windows_test, y_pred_scaled)

print(f"Test MAE(scaled): {mae2:.3f}")
print(f"Test MAE(true value): {mae:.3f}")
# Out:
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step
# Test MAE(scaled): 0.106
# Test MAE(true value): 2.213

# %%
import matplotlib.pyplot as plt

# Set font sizes and styles for publication
plt.rcParams.update({
    'font.size': 14,
    'axes.labelsize': 16,
    'axes.titlesize': 18,
    'legend.fontsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'font.family': 'serif',  # Optional: use serif font (common in papers)
    'figure.figsize': (8, 5)
})

# Plot training & validation loss
plt.plot(history.history["loss"], label="Training Loss", linewidth=2.5, color='tab:blue')
plt.plot(history.history["val_loss"], label="Validation Loss", linewidth=2.5, color='tab:red')

# Add title and axis labels
plt.title("Model Training Progress", fontsize=18, pad=20)
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")

# Improve layout and add grid
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.legend(frameon=True, loc='upper right', shadow=False, edgecolor='black')

# Use tight layout to prevent clipping
plt.tight_layout()

# Save high-resolution figure for your article
plt.savefig("training_validation_loss.pdf", format='pdf', dpi=300, bbox_inches='tight')
plt.savefig("training_validation_loss.png", format='png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import pickle

with open('training_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
y_true_original.shape
# Out:
# (17273, 20)

# %%
y_pred_original.shape
# Out:
# (17273, 20)

# %%
y_true_original = np.squeeze(y_true_original)
y_pred_original = np.squeeze(y_pred_original)

time = np.arange(1, y_true_original.shape[0]+1) * 0.01
time = time.reshape(-1, 1)

n1=9200
n2=9900
plt.figure(figsize=(15,10))
plt.plot(time , y_true_original[1,1:3],)
# plt.plot(y_pred_original[1,:])
plt.grid()

# %%
import matplotlib.pyplot as plt
import numpy as np

# انتخاب 100 نمونه اول
num_samples_to_plot = 100
y_true = y_true_original[:num_samples_to_plot, :]
y_pred = y_pred_original[:num_samples_to_plot, :]

plt.figure(figsize=(12,6))

# رسم همه 20 قدم پیش‌بینی به صورت خطوط جداگانه
plt.plot(y_true[:, 0], label=f'True step {step+1}', linestyle='-', alpha=0.6)
for step in range(20):

    plt.plot(y_pred[:, step], label=f'Pred step {step+1}', linestyle='--', alpha=0.6)

plt.xlabel('Sample index')
plt.ylabel('Value')
plt.title('Comparison of True vs Predicted Multi-step Forecast')
plt.legend(ncol=2, fontsize=8)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# داده‌ها
x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

# رسم خط
plt.plot(x, y, label='خط', color='blue')  # خط آبی

# رسم یک نقطه خاص
plt.scatter([2], [4], color='red', s=50, label='نقطه')  # نقطه قرمز

# عنوان و برچسب‌ها
plt.title('مثال رسم خط و نقطه')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)

# نمایش نمودار
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1605 (\N{ARABIC LETTER MEEM}) missing from font(s) DejaVu Serif.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Matplotlib currently does not support Arabic natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1579 (\N{ARABIC LETTER THEH}) missing from font(s) DejaVu Serif.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from font(s) DejaVu Serif.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1604 (\N{ARABIC LETTER LAM}) missing from font(s) DejaVu Serif.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1585 (\N{ARABIC LETTER REH}) missing from font(s) DejaVu Serif.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1587 (\N{ARABIC LETTER SEEN}) missing from font(s) DejaVu Serif.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1582 (\N{ARABIC LETTER KHAH}) missing from font(s) DejaVu Serif.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1591 (\N{ARABIC LETTER TAH}) missing from font(s) DejaVu Serif.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1608 (\N{ARABIC LETTER WAW}) missing from font(s) DejaVu Serif.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1606 (\N{ARABIC LETTER NOON}) missing from font(s) DejaVu Serif.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1602 (\N{ARABIC LETTER QAF}) missing from font(s) DejaVu Serif.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1607 (\N{ARABIC LETTER HEH}) missing from font(s) DejaVu Serif.
#   fig.canvas.print_figure(bytes_io, **kw)
