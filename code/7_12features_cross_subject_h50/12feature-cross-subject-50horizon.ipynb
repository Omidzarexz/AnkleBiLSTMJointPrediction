# %%
# !git clone https://github.com/Omidzarexz/AnkleBiLSTMJointPrediction
# Out:
# Cloning into 'AnkleBiLSTMJointPrediction'...
# remote: Enumerating objects: 206, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 206 (delta 45), reused 14 (delta 14), pack-reused 129 (from 1)
# Receiving objects: 100% (206/206), 27.42 MiB | 14.86 MiB/s, done.
# Resolving deltas: 100% (99/99), done.

# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt


df_clean_train_12feature_cross_subject = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_train_12feature_cross_subject.csv")
df_clean_test_12feature_cross_subject  = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_test_12feature_cross_subject.csv")


# df_clean_train_16feature_cross_subject = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_train_16feature_cross_subject.csv")
# df_clean_test_16feature_cross_subject  = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_test_16feature_cross_subject.csv")


# df_clean_train_16feature_within_subject = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_train_16feature_within_subject_txt25.csv")
# df_clean_test_16feature_within_subject  = pd.read_csv("/kaggle/working/AnkleBiLSTMJointPrediction/preprocessed_data/df_clean_test_16feature_within_subject_txt25.csv")

df_clean_train = df_clean_train_12feature_cross_subject
df_clean_test  = df_clean_test_12feature_cross_subject

# %%
from scipy.signal import butter, filtfilt

def low_pass_butter(signal, cutoff=10, fs=100, order=2):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return filtfilt(b, a, signal)
feature_columns = [
    'MPU1_Acc_X', 'MPU1_Acc_Y', 'MPU1_Acc_Z',
    'MPU1_Gyro_X', 'MPU1_Gyro_Y', 'MPU1_Gyro_Z',
    'MPU2_Acc_X', 'MPU2_Acc_Y', 'MPU2_Acc_Z',
    'MPU2_Gyro_X', 'MPU2_Gyro_Y', 'MPU2_Gyro_Z',
]




df_filtered_trainig = pd.DataFrame()
df_filtered_test    = pd.DataFrame()
for col in feature_columns:
    df_filtered_trainig[col] = low_pass_butter( df_clean_train[col].values
                                        , cutoff=5 # Hz
                                        , fs=100  # Hz
                                        , order=2  )
    df_filtered_test[col] = low_pass_butter( df_clean_test[col].values
                                        , cutoff=5 # Hz
                                        , fs=100  # Hz
                                        , order=2  )







print("\ndf_filtered_trainig shape:",df_filtered_trainig.shape)
print("\ndf_filtered_test shape:",df_filtered_test.shape)
# Out:
# df_filtered_trainig shape: (87394, 12)
#
# df_filtered_test shape: (17492, 12)

# %%
from sklearn.preprocessing import  MinMaxScaler


scaler = MinMaxScaler(feature_range=(-1, 1))
X_data_train = scaler.fit_transform(df_filtered_trainig[feature_columns].values)  # (T, 12)


y_scaler = MinMaxScaler(feature_range=(-1, 1))
y_data_train = y_scaler.fit_transform(df_clean_train['angle'].values.reshape(-1, 1))





X_data_test = scaler.transform(df_filtered_test[feature_columns].values)

y_data_test = y_scaler.transform(df_clean_test["angle"].values.reshape(-1,1))


# تنظیمات پنجره
window_size = 200   #
horizon = 50        #
step_size = 20      #

# تابع پنجره‌بندی
def create_windows_with_labels(X, y, window_size, horizon, step_size):
    X_windows = []
    y_windows = []
    for i in range(0,  len(X) - window_size - horizon + 1, step_size):
        X_windows.append(X[i:i + window_size])
        y_windows.append(y[i + window_size : i + window_size + horizon])  # برچسب آخرین نمونه در پنجره
    return np.array(X_windows), np.array(y_windows)

# ایجاد پنجره‌ها
X_windows, y_windows = create_windows_with_labels(X_data_train, y_data_train,
                                                  window_size, horizon, step_size)
if horizon==1:
    y_windows = y_windows.reshape(-1,1)
else:
    y_windows = np.squeeze(y_windows, axis=2)





print(f"✅   (X_windows):(samples, time steps, features) → {X_windows.shape}")
print(f"✅  (y_windows): {y_windows.shape}")

step_size_for_test = 1
X_windows_test, y_windows_test = create_windows_with_labels(X_data_test, y_data_test,
                                                            window_size, horizon, step_size_for_test)

if horizon==1:
    y_windows_test = y_windows_test.reshape(-1,1)
else:
    y_windows_test = np.squeeze(y_windows_test, axis=2)

print(f"\n✅   (X_windows_test):(samples, time steps, features) → {X_windows_test.shape}")
print(f"✅  (y_windows_test): {y_windows_test.shape}")
# Out:
# ✅   (X_windows):(samples, time steps, features) → (4358, 200, 12)
# ✅  (y_windows): (4358, 50)
#
# ✅   (X_windows_test):(samples, time steps, features) → (17243, 200, 12)
# ✅  (y_windows_test): (17243, 50)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from keras.layers import Bidirectional

from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, GlobalAveragePooling1D
from tensorflow.keras.layers import Input, Dense, GRU, Bidirectional, Dropout, ReLU, TimeDistributed, LayerNormalization
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l2

LEARNING_RATE = 0.001
lambda_loss_amount = 0.0005



def build_bi_lstm_model(input_shape, horizon=1, lambda_loss_amount=1e-4, learning_rate=1e-3):
    inputs = Input(shape=input_shape, name="input")

    # Dense projection per timestep
    x = TimeDistributed(Dense(128, kernel_regularizer=l2(lambda_loss_amount)))(inputs)
    x = ReLU()(x)

    # Stacked BiGRU layers
    x = Bidirectional(LSTM(128, return_sequences=True,
                           kernel_regularizer=l2(lambda_loss_amount)))(x)
    x = LayerNormalization()(x)
    x = Dropout(0.3)(x)

    x = Bidirectional(LSTM(128, return_sequences=False,
                           kernel_regularizer=l2(lambda_loss_amount)))(x)
    x = Dropout(0.3)(x)

    # Output
    outputs = Dense(horizon, activation='linear')(x)

    # Model compile
    model = Model(inputs=inputs, outputs=outputs, name="BiLSTM_reg")
    model.compile(optimizer=optimizers.Adam(learning_rate=learning_rate),
                  loss='mse',
                  metrics=['mae'])
    return model

final_model = build_bi_lstm_model(input_shape=(X_windows.shape[1],X_windows.shape[2]),horizon=horizon)

# final_model.summary()

plot_model(final_model, show_shapes=True , dpi=45)
# Out:
# 2025-10-20 13:36:04.664062: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760967364.852898      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760967364.909684      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# I0000 00:00:1760967376.752584      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from sklearn.model_selection import train_test_split


X_train, X_val, y_train, y_val = train_test_split( X_windows, y_windows, test_size=0.2,
                                                   shuffle=False, random_state=42)


callbacks = [
    ModelCheckpoint('best_lstm_model_reg.keras', save_best_only=True, monitor='val_loss',verbose=1),
    EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True,verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=5e-6,verbose=1)
]

history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=500,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/500
# I0000 00:00:1760967392.662817     107 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.2256 - mae: 0.2677
# Epoch 1: val_loss improved from inf to 0.11093, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - loss: 0.2247 - mae: 0.2669 - val_loss: 0.1109 - val_mae: 0.1485 - learning_rate: 0.0010
# Epoch 2/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1140 - mae: 0.1625
# Epoch 2: val_loss improved from 0.11093 to 0.09300, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.1139 - mae: 0.1624 - val_loss: 0.0930 - val_mae: 0.1537 - learning_rate: 0.0010
# Epoch 3/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0804 - mae: 0.1322
# Epoch 3: val_loss improved from 0.09300 to 0.06814, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0803 - mae: 0.1322 - val_loss: 0.0681 - val_mae: 0.1292 - learning_rate: 0.0010
# Epoch 4/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0676 - mae: 0.1287
# Epoch 4: val_loss improved from 0.06814 to 0.06557, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0676 - mae: 0.1287 - val_loss: 0.0656 - val_mae: 0.1397 - learning_rate: 0.0010
# Epoch 5/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0573 - mae: 0.1206
# Epoch 5: val_loss improved from 0.06557 to 0.04987, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0572 - mae: 0.1206 - val_loss: 0.0499 - val_mae: 0.1122 - learning_rate: 0.0010
# Epoch 6/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0478 - mae: 0.1096
# Epoch 6: val_loss improved from 0.04987 to 0.04708, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0478 - mae: 0.1097 - val_loss: 0.0471 - val_mae: 0.1162 - learning_rate: 0.0010
# Epoch 7/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0441 - mae: 0.1096
# Epoch 7: val_loss improved from 0.04708 to 0.04063, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0441 - mae: 0.1096 - val_loss: 0.0406 - val_mae: 0.1075 - learning_rate: 0.0010
# Epoch 8/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0393 - mae: 0.1046
# Epoch 8: val_loss did not improve from 0.04063
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0393 - mae: 0.1046 - val_loss: 0.0431 - val_mae: 0.1205 - learning_rate: 0.0010
# Epoch 9/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0362 - mae: 0.1022
# Epoch 9: val_loss improved from 0.04063 to 0.04045, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0361 - mae: 0.1021 - val_loss: 0.0404 - val_mae: 0.1254 - learning_rate: 0.0010
# Epoch 10/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0364 - mae: 0.1086
# Epoch 10: val_loss did not improve from 0.04045
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0364 - mae: 0.1085 - val_loss: 0.0406 - val_mae: 0.1226 - learning_rate: 0.0010
# Epoch 11/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0323 - mae: 0.1007
# Epoch 11: val_loss improved from 0.04045 to 0.03828, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0323 - mae: 0.1006 - val_loss: 0.0383 - val_mae: 0.1213 - learning_rate: 0.0010
# Epoch 12/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0301 - mae: 0.0981
# Epoch 12: val_loss improved from 0.03828 to 0.03315, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0301 - mae: 0.0981 - val_loss: 0.0331 - val_mae: 0.1078 - learning_rate: 0.0010
# Epoch 13/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0285 - mae: 0.0969
# Epoch 13: val_loss did not improve from 0.03315
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0285 - mae: 0.0969 - val_loss: 0.0338 - val_mae: 0.1132 - learning_rate: 0.0010
# Epoch 14/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0272 - mae: 0.0949
# Epoch 14: val_loss did not improve from 0.03315
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0272 - mae: 0.0950 - val_loss: 0.0342 - val_mae: 0.1222 - learning_rate: 0.0010
# Epoch 15/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0250 - mae: 0.0902
# Epoch 15: val_loss improved from 0.03315 to 0.03077, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0250 - mae: 0.0902 - val_loss: 0.0308 - val_mae: 0.1125 - learning_rate: 0.0010
# Epoch 16/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0246 - mae: 0.0916
# Epoch 16: val_loss did not improve from 0.03077
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0246 - mae: 0.0916 - val_loss: 0.0311 - val_mae: 0.1148 - learning_rate: 0.0010
# Epoch 17/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0236 - mae: 0.0902
# Epoch 17: val_loss improved from 0.03077 to 0.03028, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0236 - mae: 0.0902 - val_loss: 0.0303 - val_mae: 0.1109 - learning_rate: 0.0010
# Epoch 18/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0238 - mae: 0.0928
# Epoch 18: val_loss did not improve from 0.03028
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0238 - mae: 0.0928 - val_loss: 0.0352 - val_mae: 0.1246 - learning_rate: 0.0010
# Epoch 19/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0233 - mae: 0.0917
# Epoch 19: val_loss did not improve from 0.03028
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0233 - mae: 0.0917 - val_loss: 0.0329 - val_mae: 0.1199 - learning_rate: 0.0010
# Epoch 20/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0226 - mae: 0.0907
# Epoch 20: val_loss did not improve from 0.03028
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0226 - mae: 0.0907 - val_loss: 0.0327 - val_mae: 0.1175 - learning_rate: 0.0010
# Epoch 21/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0220 - mae: 0.0892
# Epoch 21: val_loss did not improve from 0.03028
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0220 - mae: 0.0891 - val_loss: 0.0320 - val_mae: 0.1198 - learning_rate: 0.0010
# Epoch 22/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0200 - mae: 0.0845
# Epoch 22: val_loss improved from 0.03028 to 0.02770, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0200 - mae: 0.0845 - val_loss: 0.0277 - val_mae: 0.1120 - learning_rate: 0.0010
# Epoch 23/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0203 - mae: 0.0871
# Epoch 23: val_loss did not improve from 0.02770
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0203 - mae: 0.0870 - val_loss: 0.0337 - val_mae: 0.1223 - learning_rate: 0.0010
# Epoch 24/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0213 - mae: 0.0908
# Epoch 24: val_loss improved from 0.02770 to 0.02756, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0213 - mae: 0.0908 - val_loss: 0.0276 - val_mae: 0.1091 - learning_rate: 0.0010
# Epoch 25/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0194 - mae: 0.0852
# Epoch 25: val_loss did not improve from 0.02756
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0194 - mae: 0.0852 - val_loss: 0.0286 - val_mae: 0.1175 - learning_rate: 0.0010
# Epoch 26/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0191 - mae: 0.0856
# Epoch 26: val_loss improved from 0.02756 to 0.02720, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0191 - mae: 0.0856 - val_loss: 0.0272 - val_mae: 0.1110 - learning_rate: 0.0010
# Epoch 27/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0196 - mae: 0.0883
# Epoch 27: val_loss improved from 0.02720 to 0.02442, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0196 - mae: 0.0882 - val_loss: 0.0244 - val_mae: 0.1015 - learning_rate: 0.0010
# Epoch 28/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0181 - mae: 0.0834
# Epoch 28: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0181 - mae: 0.0834 - val_loss: 0.0282 - val_mae: 0.1143 - learning_rate: 0.0010
# Epoch 29/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0179 - mae: 0.0819
# Epoch 29: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0179 - mae: 0.0820 - val_loss: 0.0354 - val_mae: 0.1311 - learning_rate: 0.0010
# Epoch 30/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0199 - mae: 0.0905
# Epoch 30: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0199 - mae: 0.0904 - val_loss: 0.0293 - val_mae: 0.1222 - learning_rate: 0.0010
# Epoch 31/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0179 - mae: 0.0838
# Epoch 31: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0179 - mae: 0.0838 - val_loss: 0.0268 - val_mae: 0.1148 - learning_rate: 0.0010
# Epoch 32/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0175 - mae: 0.0819
# Epoch 32: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0174 - mae: 0.0819 - val_loss: 0.0286 - val_mae: 0.1206 - learning_rate: 0.0010
# Epoch 33/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0165 - mae: 0.0798
# Epoch 33: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0165 - mae: 0.0798 - val_loss: 0.0270 - val_mae: 0.1158 - learning_rate: 0.0010
# Epoch 34/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0174 - mae: 0.0838
# Epoch 34: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0174 - mae: 0.0838 - val_loss: 0.0292 - val_mae: 0.1233 - learning_rate: 0.0010
# Epoch 35/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0169 - mae: 0.0816
# Epoch 35: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0169 - mae: 0.0816 - val_loss: 0.0293 - val_mae: 0.1169 - learning_rate: 0.0010
# Epoch 36/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0160 - mae: 0.0795
# Epoch 36: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0160 - mae: 0.0795 - val_loss: 0.0276 - val_mae: 0.1175 - learning_rate: 0.0010
# Epoch 37/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0156 - mae: 0.0775
# Epoch 37: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0156 - mae: 0.0775 - val_loss: 0.0282 - val_mae: 0.1172 - learning_rate: 0.0010
# Epoch 38/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0156 - mae: 0.0789
# Epoch 38: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0156 - mae: 0.0789 - val_loss: 0.0267 - val_mae: 0.1130 - learning_rate: 0.0010
# Epoch 39/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0161 - mae: 0.0809
# Epoch 39: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0161 - mae: 0.0809 - val_loss: 0.0245 - val_mae: 0.1103 - learning_rate: 0.0010
# Epoch 40/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0152 - mae: 0.0777
# Epoch 40: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0152 - mae: 0.0778 - val_loss: 0.0300 - val_mae: 0.1223 - learning_rate: 0.0010
# Epoch 41/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0154 - mae: 0.0797
# Epoch 41: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0154 - mae: 0.0797 - val_loss: 0.0290 - val_mae: 0.1194 - learning_rate: 0.0010
# Epoch 42/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0157 - mae: 0.0792
# Epoch 42: val_loss did not improve from 0.02442
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0157 - mae: 0.0792 - val_loss: 0.0286 - val_mae: 0.1201 - learning_rate: 0.0010
# Epoch 43/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0156 - mae: 0.0797
# Epoch 43: val_loss did not improve from 0.02442
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0156 - mae: 0.0796 - val_loss: 0.0291 - val_mae: 0.1219 - learning_rate: 5.0000e-04
# Epoch 44/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0135 - mae: 0.0721
# Epoch 44: val_loss improved from 0.02442 to 0.02403, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0135 - mae: 0.0721 - val_loss: 0.0240 - val_mae: 0.1099 - learning_rate: 5.0000e-04
# Epoch 45/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0136 - mae: 0.0729
# Epoch 45: val_loss did not improve from 0.02403
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0136 - mae: 0.0729 - val_loss: 0.0256 - val_mae: 0.1156 - learning_rate: 5.0000e-04
# Epoch 46/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0132 - mae: 0.0716
# Epoch 46: val_loss improved from 0.02403 to 0.02364, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0131 - mae: 0.0716 - val_loss: 0.0236 - val_mae: 0.1076 - learning_rate: 5.0000e-04
# Epoch 47/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0126 - mae: 0.0698
# Epoch 47: val_loss improved from 0.02364 to 0.02225, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0126 - mae: 0.0698 - val_loss: 0.0222 - val_mae: 0.1032 - learning_rate: 5.0000e-04
# Epoch 48/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0125 - mae: 0.0696
# Epoch 48: val_loss did not improve from 0.02225
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0125 - mae: 0.0696 - val_loss: 0.0248 - val_mae: 0.1153 - learning_rate: 5.0000e-04
# Epoch 49/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0139 - mae: 0.0748
# Epoch 49: val_loss did not improve from 0.02225
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0139 - mae: 0.0747 - val_loss: 0.0269 - val_mae: 0.1163 - learning_rate: 5.0000e-04
# Epoch 50/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0124 - mae: 0.0693
# Epoch 50: val_loss did not improve from 0.02225
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0124 - mae: 0.0693 - val_loss: 0.0290 - val_mae: 0.1234 - learning_rate: 5.0000e-04
# Epoch 51/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0130 - mae: 0.0723
# Epoch 51: val_loss did not improve from 0.02225
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0130 - mae: 0.0723 - val_loss: 0.0290 - val_mae: 0.1227 - learning_rate: 5.0000e-04
# Epoch 52/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0122 - mae: 0.0691
# Epoch 52: val_loss did not improve from 0.02225
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0122 - mae: 0.0691 - val_loss: 0.0252 - val_mae: 0.1141 - learning_rate: 5.0000e-04
# Epoch 53/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0120 - mae: 0.0681
# Epoch 53: val_loss did not improve from 0.02225
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0120 - mae: 0.0681 - val_loss: 0.0262 - val_mae: 0.1176 - learning_rate: 5.0000e-04
# Epoch 54/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0118 - mae: 0.0675
# Epoch 54: val_loss did not improve from 0.02225
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0118 - mae: 0.0675 - val_loss: 0.0237 - val_mae: 0.1098 - learning_rate: 5.0000e-04
# Epoch 55/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0122 - mae: 0.0696
# Epoch 55: val_loss did not improve from 0.02225
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0122 - mae: 0.0696 - val_loss: 0.0284 - val_mae: 0.1233 - learning_rate: 5.0000e-04
# Epoch 56/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0127 - mae: 0.0716
# Epoch 56: val_loss did not improve from 0.02225
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0127 - mae: 0.0716 - val_loss: 0.0279 - val_mae: 0.1224 - learning_rate: 5.0000e-04
# Epoch 57/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0118 - mae: 0.0680
# Epoch 57: val_loss did not improve from 0.02225
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0118 - mae: 0.0680 - val_loss: 0.0258 - val_mae: 0.1168 - learning_rate: 5.0000e-04
# Epoch 58/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0126 - mae: 0.0712
# Epoch 58: val_loss improved from 0.02225 to 0.02176, saving model to best_lstm_model_reg.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0126 - mae: 0.0712 - val_loss: 0.0218 - val_mae: 0.1019 - learning_rate: 5.0000e-04
# Epoch 59/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0123 - mae: 0.0707
# Epoch 59: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0123 - mae: 0.0707 - val_loss: 0.0227 - val_mae: 0.1075 - learning_rate: 5.0000e-04
# Epoch 60/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0116 - mae: 0.0678
# Epoch 60: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0116 - mae: 0.0678 - val_loss: 0.0257 - val_mae: 0.1135 - learning_rate: 5.0000e-04
# Epoch 61/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0120 - mae: 0.0704
# Epoch 61: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0120 - mae: 0.0704 - val_loss: 0.0249 - val_mae: 0.1142 - learning_rate: 5.0000e-04
# Epoch 62/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0123 - mae: 0.0711
# Epoch 62: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0123 - mae: 0.0711 - val_loss: 0.0221 - val_mae: 0.1072 - learning_rate: 5.0000e-04
# Epoch 63/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0119 - mae: 0.0695
# Epoch 63: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0119 - mae: 0.0695 - val_loss: 0.0287 - val_mae: 0.1252 - learning_rate: 5.0000e-04
# Epoch 64/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0116 - mae: 0.0682
# Epoch 64: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0116 - mae: 0.0682 - val_loss: 0.0295 - val_mae: 0.1287 - learning_rate: 5.0000e-04
# Epoch 65/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0122 - mae: 0.0712
# Epoch 65: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0122 - mae: 0.0712 - val_loss: 0.0257 - val_mae: 0.1170 - learning_rate: 5.0000e-04
# Epoch 66/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0115 - mae: 0.0672
# Epoch 66: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0115 - mae: 0.0672 - val_loss: 0.0279 - val_mae: 0.1216 - learning_rate: 5.0000e-04
# Epoch 67/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0115 - mae: 0.0685
# Epoch 67: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0115 - mae: 0.0685 - val_loss: 0.0276 - val_mae: 0.1229 - learning_rate: 5.0000e-04
# Epoch 68/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0121 - mae: 0.0701
# Epoch 68: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0120 - mae: 0.0701 - val_loss: 0.0287 - val_mae: 0.1281 - learning_rate: 5.0000e-04
# Epoch 69/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0119 - mae: 0.0699
# Epoch 69: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0119 - mae: 0.0699 - val_loss: 0.0265 - val_mae: 0.1196 - learning_rate: 5.0000e-04
# Epoch 70/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0117 - mae: 0.0697
# Epoch 70: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0117 - mae: 0.0697 - val_loss: 0.0249 - val_mae: 0.1141 - learning_rate: 5.0000e-04
# Epoch 71/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0111 - mae: 0.0670
# Epoch 71: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0111 - mae: 0.0670 - val_loss: 0.0286 - val_mae: 0.1241 - learning_rate: 5.0000e-04
# Epoch 72/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0109 - mae: 0.0662
# Epoch 72: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0109 - mae: 0.0662 - val_loss: 0.0278 - val_mae: 0.1240 - learning_rate: 5.0000e-04
# Epoch 73/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0112 - mae: 0.0673
# Epoch 73: val_loss did not improve from 0.02176
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0112 - mae: 0.0673 - val_loss: 0.0258 - val_mae: 0.1169 - learning_rate: 5.0000e-04
# Epoch 74/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0106 - mae: 0.0652
# Epoch 74: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0106 - mae: 0.0651 - val_loss: 0.0275 - val_mae: 0.1258 - learning_rate: 2.5000e-04
# Epoch 75/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0102 - mae: 0.0636
# Epoch 75: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0102 - mae: 0.0636 - val_loss: 0.0276 - val_mae: 0.1215 - learning_rate: 2.5000e-04
# Epoch 76/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0102 - mae: 0.0632
# Epoch 76: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0102 - mae: 0.0632 - val_loss: 0.0302 - val_mae: 0.1280 - learning_rate: 2.5000e-04
# Epoch 77/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0102 - mae: 0.0635
# Epoch 77: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0102 - mae: 0.0635 - val_loss: 0.0267 - val_mae: 0.1205 - learning_rate: 2.5000e-04
# Epoch 78/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0100 - mae: 0.0628
# Epoch 78: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0100 - mae: 0.0628 - val_loss: 0.0257 - val_mae: 0.1207 - learning_rate: 2.5000e-04
# Epoch 79/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0097 - mae: 0.0620
# Epoch 79: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0097 - mae: 0.0620 - val_loss: 0.0263 - val_mae: 0.1210 - learning_rate: 2.5000e-04
# Epoch 80/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0097 - mae: 0.0617
# Epoch 80: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0097 - mae: 0.0617 - val_loss: 0.0277 - val_mae: 0.1229 - learning_rate: 2.5000e-04
# Epoch 81/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0096 - mae: 0.0616
# Epoch 81: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0096 - mae: 0.0616 - val_loss: 0.0275 - val_mae: 0.1236 - learning_rate: 2.5000e-04
# Epoch 82/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0097 - mae: 0.0619
# Epoch 82: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0097 - mae: 0.0619 - val_loss: 0.0304 - val_mae: 0.1303 - learning_rate: 2.5000e-04
# Epoch 83/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0099 - mae: 0.0629
# Epoch 83: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0099 - mae: 0.0629 - val_loss: 0.0283 - val_mae: 0.1256 - learning_rate: 2.5000e-04
# Epoch 84/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0101 - mae: 0.0640
# Epoch 84: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0101 - mae: 0.0639 - val_loss: 0.0267 - val_mae: 0.1204 - learning_rate: 2.5000e-04
# Epoch 85/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0097 - mae: 0.0627
# Epoch 85: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0097 - mae: 0.0627 - val_loss: 0.0251 - val_mae: 0.1180 - learning_rate: 2.5000e-04
# Epoch 86/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0098 - mae: 0.0625
# Epoch 86: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0098 - mae: 0.0625 - val_loss: 0.0267 - val_mae: 0.1216 - learning_rate: 2.5000e-04
# Epoch 87/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0098 - mae: 0.0626
# Epoch 87: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0098 - mae: 0.0626 - val_loss: 0.0269 - val_mae: 0.1239 - learning_rate: 2.5000e-04
# Epoch 88/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0095 - mae: 0.0615
# Epoch 88: val_loss did not improve from 0.02176
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0095 - mae: 0.0615 - val_loss: 0.0249 - val_mae: 0.1187 - learning_rate: 2.5000e-04
# Epoch 89/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0090 - mae: 0.0593
# Epoch 89: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0090 - mae: 0.0593 - val_loss: 0.0272 - val_mae: 0.1234 - learning_rate: 1.2500e-04
# Epoch 90/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0091 - mae: 0.0591
# Epoch 90: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0091 - mae: 0.0591 - val_loss: 0.0254 - val_mae: 0.1168 - learning_rate: 1.2500e-04
# Epoch 91/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0090 - mae: 0.0596
# Epoch 91: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0090 - mae: 0.0596 - val_loss: 0.0276 - val_mae: 0.1237 - learning_rate: 1.2500e-04
# Epoch 92/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0091 - mae: 0.0601
# Epoch 92: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0091 - mae: 0.0601 - val_loss: 0.0278 - val_mae: 0.1241 - learning_rate: 1.2500e-04
# Epoch 93/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0088 - mae: 0.0583
# Epoch 93: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0088 - mae: 0.0583 - val_loss: 0.0274 - val_mae: 0.1237 - learning_rate: 1.2500e-04
# Epoch 94/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0087 - mae: 0.0580
# Epoch 94: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0087 - mae: 0.0580 - val_loss: 0.0267 - val_mae: 0.1194 - learning_rate: 1.2500e-04
# Epoch 95/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0088 - mae: 0.0585
# Epoch 95: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0088 - mae: 0.0585 - val_loss: 0.0290 - val_mae: 0.1253 - learning_rate: 1.2500e-04
# Epoch 96/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0089 - mae: 0.0591
# Epoch 96: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0089 - mae: 0.0591 - val_loss: 0.0296 - val_mae: 0.1286 - learning_rate: 1.2500e-04
# Epoch 97/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0086 - mae: 0.0580
# Epoch 97: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0086 - mae: 0.0580 - val_loss: 0.0297 - val_mae: 0.1282 - learning_rate: 1.2500e-04
# Epoch 98/500
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0086 - mae: 0.0576
# Epoch 98: val_loss did not improve from 0.02176
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0086 - mae: 0.0576 - val_loss: 0.0280 - val_mae: 0.1248 - learning_rate: 1.2500e-04
# Epoch 98: early stopping
# Restoring model weights from the end of the best epoch: 58.

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import  mean_absolute_error

# model  = load_model("/kaggle/input/m/tensorflow2/default/1/best_lstm_model_reg.keras")
# پیش‌بینی روی داده تست-
y_pred_scaled = final_model.predict(X_windows_test)  # (N, 1)

# برگرداندن به مقیاس اصلی
y_pred_original = y_scaler.inverse_transform(y_pred_scaled)
y_true_original = y_scaler.inverse_transform(y_windows_test)




mae = mean_absolute_error(y_true_original, y_pred_original)
mae2 = mean_absolute_error(y_windows_test, y_pred_scaled)

print(f"Test MAE(scaled): {mae2:.3f}")
print(f"Test MAE(true value): {mae:.3f}")
# Out:
# 539/539 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step
# Test MAE(scaled): 0.212
# Test MAE(true value): 4.414

# %%
import matplotlib.pyplot as plt

# Set font sizes and styles for publication
plt.rcParams.update({
    'font.size': 14,
    'axes.labelsize': 16,
    'axes.titlesize': 18,
    'legend.fontsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'font.family': 'serif',  # Optional: use serif font (common in papers)
    'figure.figsize': (8, 5)
})

# Plot training & validation loss
plt.plot(history.history["loss"], label="Training Loss", linewidth=2.5, color='tab:blue')
plt.plot(history.history["val_loss"], label="Validation Loss", linewidth=2.5, color='tab:red')

# Add title and axis labels
plt.title("Model Training Progress", fontsize=18, pad=20)
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")

# Improve layout and add grid
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.legend(frameon=True, loc='upper right', shadow=False, edgecolor='black')

# Use tight layout to prevent clipping
plt.tight_layout()

# Save high-resolution figure for your article
plt.savefig("training_validation_loss.pdf", format='pdf', dpi=300, bbox_inches='tight')
plt.savefig("training_validation_loss.png", format='png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import pickle

with open('training_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
y_true_original.shape
# Out:
# (17243, 50)

# %%
y_pred_original.shape
# Out:
# (17243, 50)

# %%
# time = np.arange(1, y_true_original.shape[0]+1) * 0.01
# time = time.reshape(-1, 1)

plt.figure(figsize=(15,10))
plt.plot(y_true_original[222,:])
plt.plot(y_pred_original[222,:])
plt.grid()
