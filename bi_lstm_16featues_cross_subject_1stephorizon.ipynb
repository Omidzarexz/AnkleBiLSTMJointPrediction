# %%
# !git clone https://github.com/Omidzarexz/crispy-computing-machine
# Out:
# fatal: destination path 'crispy-computing-machine' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt


# df_clean_train_12feature_cross_subject = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_train_12feature_cross_subject.csv")
# df_clean_test_12feature_cross_subject  = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_test_12feature_cross_subject.csv")


df_clean_train_16feature_cross_subject = pd.read_csv("/content/crispy-computing-machine/df_clean_train_16feature_cross_subject.csv")
df_clean_test_16feature_cross_subject  = pd.read_csv("/content/crispy-computing-machine/df_clean_test_16feature_cross_subject.csv")


# df_clean_train_16feature_within_subject = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_train_16feature_within_subject_txt25.csv")
# df_clean_test_16feature_within_subject  = pd.read_csv("/kaggle/working/crispy-computing-machine/df_clean_test_16feature_within_subject_txt25.csv")

df_clean_train = df_clean_train_16feature_cross_subject
df_clean_test  = df_clean_test_16feature_cross_subject

# %%
from scipy.signal import butter, filtfilt

def low_pass_butter(signal, cutoff=10, fs=100, order=2):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return filtfilt(b, a, signal)
feature_columns = [
    'MPU1_Acc_X', 'MPU1_Acc_Y', 'MPU1_Acc_Z',
    'MPU1_Gyro_X', 'MPU1_Gyro_Y', 'MPU1_Gyro_Z',
    'MPU1_Roll','MPU1_Pitch',
    'MPU2_Acc_X', 'MPU2_Acc_Y', 'MPU2_Acc_Z',
    'MPU2_Gyro_X', 'MPU2_Gyro_Y', 'MPU2_Gyro_Z',
    'MPU2_Roll','MPU2_Pitch'
]

# feature_columns = [
#     'MPU1_Acc_X', 'MPU1_Acc_Y', 'MPU1_Acc_Z',
#     'MPU1_Gyro_X', 'MPU1_Gyro_Y', 'MPU1_Gyro_Z',

#     'MPU2_Acc_X', 'MPU2_Acc_Y', 'MPU2_Acc_Z',
#     'MPU2_Gyro_X', 'MPU2_Gyro_Y', 'MPU2_Gyro_Z',

# ]


df_filtered_trainig = pd.DataFrame()
df_filtered_test    = pd.DataFrame()
for col in feature_columns:
    df_filtered_trainig[col] = low_pass_butter( df_clean_train[col].values
                                        , cutoff=5 # Hz
                                        , fs=100  # Hz
                                        , order=2  )
    df_filtered_test[col] = low_pass_butter( df_clean_test[col].values
                                        , cutoff=5 # Hz
                                        , fs=100  # Hz
                                        , order=2  )



# # اعمال حد مجاز [-200, 200] روی تمام ژیروسکوپ‌ها
# for col in ['MPU1_Gyro_X', 'MPU1_Gyro_Y', 'MPU1_Gyro_Z','MPU2_Gyro_X', 'MPU2_Gyro_Y', 'MPU2_Gyro_Z']:
#     df_filtered_trainig[col] = np.clip(df_filtered_trainig[col], -250, 250)
#     df_filtered_test[col]    = np.clip(df_filtered_test[col], -250, 250)


# # اعمال حد مجاز [-10, 10] روی تمام ژیروسکوپ‌ها
# for col in ['MPU1_Acc_X', 'MPU1_Acc_Y', 'MPU1_Acc_Z', 'MPU2_Acc_X', 'MPU2_Acc_Y', 'MPU2_Acc_Z']:
#     df_filtered_trainig[col] = np.clip(df_filtered_trainig[col], -10, 10)
#     df_filtered_test[col]    = np.clip(df_filtered_test[col], -10, 10)



print("\ndf_filtered_trainig shape:",df_filtered_trainig.shape)
print("\ndf_filtered_test shape:",df_filtered_test.shape)
# Out:
# df_filtered_trainig shape: (87394, 16)
#
# df_filtered_test shape: (17492, 16)

# %%
from sklearn.preprocessing import  MinMaxScaler


scaler = MinMaxScaler(feature_range=(-1, 1))
X_data_train = scaler.fit_transform(df_filtered_trainig[feature_columns].values)  # (T, 12)


y_scaler = MinMaxScaler(feature_range=(-1, 1))
y_data_train = y_scaler.fit_transform(df_clean_train['angle'].values.reshape(-1, 1))





X_data_test = scaler.transform(df_filtered_test[feature_columns].values)

y_data_test = y_scaler.transform(df_clean_test["angle"].values.reshape(-1,1))


# تنظیمات پنجره
window_size = 200   #
horizon = 1        #
step_size = 5      #

# تابع پنجره‌بندی
def create_windows_with_labels(X, y, window_size, horizon, step_size):
    X_windows = []
    y_windows = []
    for i in range(0,  len(X) - window_size - horizon + 1, step_size):
        X_windows.append(X[i:i + window_size])
        y_windows.append(y[i + window_size : i + window_size + horizon])  # برچسب آخرین نمونه در پنجره
    return np.array(X_windows), np.array(y_windows)

# ایجاد پنجره‌ها
X_windows, y_windows = create_windows_with_labels(X_data_train, y_data_train,
                                                  window_size, horizon, step_size)
if horizon==1:
    y_windows = y_windows.reshape(-1,1)




print(f"✅   (X_windows):(samples, time steps, features) → {X_windows.shape}")
print(f"✅  (y_windows): {y_windows.shape}")

step_size_for_test = 1
X_windows_test, y_windows_test = create_windows_with_labels(X_data_test, y_data_test,
                                                            window_size, horizon, step_size_for_test)

if horizon==1:
    y_windows_test = y_windows_test.reshape(-1,1)

print(f"\n✅   (X_windows_test):(samples, time steps, features) → {X_windows_test.shape}")
print(f"✅  (y_windows_test): {y_windows_test.shape}")
# Out:
# ✅   (X_windows):(samples, time steps, features) → (17439, 200, 16)
# ✅  (y_windows): (17439, 1)
#
# ✅   (X_windows_test):(samples, time steps, features) → (17292, 200, 16)
# ✅  (y_windows_test): (17292, 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from keras.layers import Bidirectional

from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, GlobalAveragePooling1D
from tensorflow.keras.layers import Input, Dense, GRU, Bidirectional, Dropout, ReLU, TimeDistributed, LayerNormalization
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l2

LEARNING_RATE = 0.001
lambda_loss_amount = 0.0005



def build_bi_lstm_model(input_shape, horizon=1, lambda_loss_amount=1e-4, learning_rate=1e-3):
    inputs = Input(shape=input_shape, name="input")

    # Dense projection per timestep
    x = TimeDistributed(Dense(64, kernel_regularizer=l2(lambda_loss_amount)))(inputs)
    x = ReLU()(x)

    # Stacked BiGRU layers
    x = Bidirectional(LSTM(64, return_sequences=True,
                           kernel_regularizer=l2(lambda_loss_amount)))(x)
    x = LayerNormalization()(x)
    x = Dropout(0.3)(x)

    x = Bidirectional(LSTM(32, return_sequences=False,
                           kernel_regularizer=l2(lambda_loss_amount)))(x)
    x = Dropout(0.3)(x)

    # Output
    outputs = Dense(horizon, activation='linear')(x)

    # Model compile
    model = Model(inputs=inputs, outputs=outputs, name="BiLSTM_reg")
    model.compile(optimizer=optimizers.Adam(learning_rate=learning_rate),
                  loss='mse',
                  metrics=['mae'])
    return model

final_model = build_bi_lstm_model(input_shape=(X_windows.shape[1],X_windows.shape[2]))

# final_model.summary()

plot_model(final_model, show_shapes=True , dpi=80)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from sklearn.model_selection import train_test_split


X_train, X_val, y_train, y_val = train_test_split( X_windows, y_windows, test_size=0.2,
                                                   shuffle=False, random_state=42)


callbacks = [
    ModelCheckpoint('best_lstm_model_reg.keras', save_best_only=True, monitor='val_loss',verbose=1),
    EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True,verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=5e-6,verbose=1)
]

history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=500,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1263 - mae: 0.2052
# Epoch 1: val_loss improved from inf to 0.05073, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - loss: 0.1259 - mae: 0.2046 - val_loss: 0.0507 - val_mae: 0.0911 - learning_rate: 0.0010
# Epoch 2/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0504 - mae: 0.0950
# Epoch 2: val_loss improved from 0.05073 to 0.04196, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0503 - mae: 0.0949 - val_loss: 0.0420 - val_mae: 0.0897 - learning_rate: 0.0010
# Epoch 3/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0375 - mae: 0.0774
# Epoch 3: val_loss improved from 0.04196 to 0.03457, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0374 - mae: 0.0774 - val_loss: 0.0346 - val_mae: 0.0832 - learning_rate: 0.0010
# Epoch 4/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0301 - mae: 0.0680
# Epoch 4: val_loss improved from 0.03457 to 0.02925, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0301 - mae: 0.0680 - val_loss: 0.0293 - val_mae: 0.0784 - learning_rate: 0.0010
# Epoch 5/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0258 - mae: 0.0647
# Epoch 5: val_loss did not improve from 0.02925
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0257 - mae: 0.0647 - val_loss: 0.0295 - val_mae: 0.0901 - learning_rate: 0.0010
# Epoch 6/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0224 - mae: 0.0628
# Epoch 6: val_loss improved from 0.02925 to 0.02477, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - loss: 0.0224 - mae: 0.0628 - val_loss: 0.0248 - val_mae: 0.0814 - learning_rate: 0.0010
# Epoch 7/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0196 - mae: 0.0597
# Epoch 7: val_loss did not improve from 0.02477
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0196 - mae: 0.0597 - val_loss: 0.0258 - val_mae: 0.0922 - learning_rate: 0.0010
# Epoch 8/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0170 - mae: 0.0560
# Epoch 8: val_loss improved from 0.02477 to 0.02340, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 0.0170 - mae: 0.0560 - val_loss: 0.0234 - val_mae: 0.0908 - learning_rate: 0.0010
# Epoch 9/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0157 - mae: 0.0565
# Epoch 9: val_loss improved from 0.02340 to 0.01815, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0157 - mae: 0.0565 - val_loss: 0.0182 - val_mae: 0.0763 - learning_rate: 0.0010
# Epoch 10/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0142 - mae: 0.0552
# Epoch 10: val_loss improved from 0.01815 to 0.01694, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0142 - mae: 0.0551 - val_loss: 0.0169 - val_mae: 0.0753 - learning_rate: 0.0010
# Epoch 11/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0132 - mae: 0.0551
# Epoch 11: val_loss improved from 0.01694 to 0.01433, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0132 - mae: 0.0551 - val_loss: 0.0143 - val_mae: 0.0659 - learning_rate: 0.0010
# Epoch 12/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0118 - mae: 0.0518
# Epoch 12: val_loss did not improve from 0.01433
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0118 - mae: 0.0518 - val_loss: 0.0202 - val_mae: 0.0965 - learning_rate: 0.0010
# Epoch 13/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0109 - mae: 0.0519
# Epoch 13: val_loss did not improve from 0.01433
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - loss: 0.0109 - mae: 0.0519 - val_loss: 0.0213 - val_mae: 0.1036 - learning_rate: 0.0010
# Epoch 14/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0106 - mae: 0.0531
# Epoch 14: val_loss improved from 0.01433 to 0.01259, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0106 - mae: 0.0531 - val_loss: 0.0126 - val_mae: 0.0688 - learning_rate: 0.0010
# Epoch 15/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0094 - mae: 0.0496
# Epoch 15: val_loss did not improve from 0.01259
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0094 - mae: 0.0496 - val_loss: 0.0191 - val_mae: 0.0996 - learning_rate: 0.0010
# Epoch 16/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0096 - mae: 0.0538
# Epoch 16: val_loss did not improve from 0.01259
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0096 - mae: 0.0538 - val_loss: 0.0224 - val_mae: 0.1108 - learning_rate: 0.0010
# Epoch 17/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0086 - mae: 0.0502
# Epoch 17: val_loss did not improve from 0.01259
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0086 - mae: 0.0502 - val_loss: 0.0168 - val_mae: 0.0903 - learning_rate: 0.0010
# Epoch 18/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0079 - mae: 0.0483
# Epoch 18: val_loss did not improve from 0.01259
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0079 - mae: 0.0483 - val_loss: 0.0195 - val_mae: 0.1058 - learning_rate: 0.0010
# Epoch 19/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0077 - mae: 0.0483
# Epoch 19: val_loss did not improve from 0.01259
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0077 - mae: 0.0483 - val_loss: 0.0141 - val_mae: 0.0849 - learning_rate: 0.0010
# Epoch 20/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0070 - mae: 0.0460
# Epoch 20: val_loss improved from 0.01259 to 0.01255, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0070 - mae: 0.0460 - val_loss: 0.0125 - val_mae: 0.0791 - learning_rate: 0.0010
# Epoch 21/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0070 - mae: 0.0471
# Epoch 21: val_loss improved from 0.01255 to 0.01242, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0070 - mae: 0.0471 - val_loss: 0.0124 - val_mae: 0.0773 - learning_rate: 0.0010
# Epoch 22/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0071 - mae: 0.0492
# Epoch 22: val_loss did not improve from 0.01242
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 0.0071 - mae: 0.0492 - val_loss: 0.0234 - val_mae: 0.1250 - learning_rate: 0.0010
# Epoch 23/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0067 - mae: 0.0472
# Epoch 23: val_loss did not improve from 0.01242
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0067 - mae: 0.0472 - val_loss: 0.0128 - val_mae: 0.0826 - learning_rate: 0.0010
# Epoch 24/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0062 - mae: 0.0454
# Epoch 24: val_loss did not improve from 0.01242
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0062 - mae: 0.0454 - val_loss: 0.0137 - val_mae: 0.0850 - learning_rate: 0.0010
# Epoch 25/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0060 - mae: 0.0453
# Epoch 25: val_loss improved from 0.01242 to 0.00934, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0060 - mae: 0.0453 - val_loss: 0.0093 - val_mae: 0.0682 - learning_rate: 0.0010
# Epoch 26/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0059 - mae: 0.0452
# Epoch 26: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0059 - mae: 0.0452 - val_loss: 0.0095 - val_mae: 0.0689 - learning_rate: 0.0010
# Epoch 27/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0055 - mae: 0.0428
# Epoch 27: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - loss: 0.0055 - mae: 0.0428 - val_loss: 0.0144 - val_mae: 0.0922 - learning_rate: 0.0010
# Epoch 28/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0056 - mae: 0.0447
# Epoch 28: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0056 - mae: 0.0447 - val_loss: 0.0130 - val_mae: 0.0850 - learning_rate: 0.0010
# Epoch 29/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0058 - mae: 0.0463
# Epoch 29: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0058 - mae: 0.0463 - val_loss: 0.0137 - val_mae: 0.0896 - learning_rate: 0.0010
# Epoch 30/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0051 - mae: 0.0422
# Epoch 30: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0051 - mae: 0.0422 - val_loss: 0.0155 - val_mae: 0.0913 - learning_rate: 0.0010
# Epoch 31/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0051 - mae: 0.0427
# Epoch 31: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 0.0051 - mae: 0.0427 - val_loss: 0.0148 - val_mae: 0.0981 - learning_rate: 0.0010
# Epoch 32/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0053 - mae: 0.0445
# Epoch 32: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0053 - mae: 0.0445 - val_loss: 0.0219 - val_mae: 0.1233 - learning_rate: 0.0010
# Epoch 33/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0050 - mae: 0.0427
# Epoch 33: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0050 - mae: 0.0427 - val_loss: 0.0094 - val_mae: 0.0715 - learning_rate: 0.0010
# Epoch 34/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0051 - mae: 0.0433
# Epoch 34: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0051 - mae: 0.0433 - val_loss: 0.0139 - val_mae: 0.0922 - learning_rate: 0.0010
# Epoch 35/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0053 - mae: 0.0457
# Epoch 35: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0053 - mae: 0.0457 - val_loss: 0.0120 - val_mae: 0.0854 - learning_rate: 0.0010
# Epoch 36/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0048 - mae: 0.0420
# Epoch 36: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - loss: 0.0048 - mae: 0.0420 - val_loss: 0.0152 - val_mae: 0.1022 - learning_rate: 0.0010
# Epoch 37/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0052 - mae: 0.0457
# Epoch 37: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0052 - mae: 0.0456 - val_loss: 0.0115 - val_mae: 0.0835 - learning_rate: 0.0010
# Epoch 38/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0048 - mae: 0.0428
# Epoch 38: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0048 - mae: 0.0428 - val_loss: 0.0144 - val_mae: 0.0991 - learning_rate: 0.0010
# Epoch 39/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0045 - mae: 0.0414
# Epoch 39: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0045 - mae: 0.0414 - val_loss: 0.0104 - val_mae: 0.0760 - learning_rate: 0.0010
# Epoch 40/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0049 - mae: 0.0443
# Epoch 40: val_loss did not improve from 0.00934
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0049 - mae: 0.0443 - val_loss: 0.0120 - val_mae: 0.0847 - learning_rate: 0.0010
# Epoch 41/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0042 - mae: 0.0395
# Epoch 41: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 0.0042 - mae: 0.0395 - val_loss: 0.0131 - val_mae: 0.0926 - learning_rate: 5.0000e-04
# Epoch 42/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0039 - mae: 0.0372
# Epoch 42: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0039 - mae: 0.0372 - val_loss: 0.0111 - val_mae: 0.0834 - learning_rate: 5.0000e-04
# Epoch 43/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0040 - mae: 0.0382
# Epoch 43: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0040 - mae: 0.0382 - val_loss: 0.0169 - val_mae: 0.1116 - learning_rate: 5.0000e-04
# Epoch 44/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0038 - mae: 0.0375
# Epoch 44: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0038 - mae: 0.0375 - val_loss: 0.0154 - val_mae: 0.1048 - learning_rate: 5.0000e-04
# Epoch 45/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0041 - mae: 0.0394
# Epoch 45: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0041 - mae: 0.0394 - val_loss: 0.0164 - val_mae: 0.1085 - learning_rate: 5.0000e-04
# Epoch 46/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0041 - mae: 0.0394
# Epoch 46: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - loss: 0.0041 - mae: 0.0394 - val_loss: 0.0134 - val_mae: 0.0928 - learning_rate: 5.0000e-04
# Epoch 47/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0038 - mae: 0.0375
# Epoch 47: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0038 - mae: 0.0375 - val_loss: 0.0162 - val_mae: 0.1055 - learning_rate: 5.0000e-04
# Epoch 48/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0037 - mae: 0.0362
# Epoch 48: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0037 - mae: 0.0363 - val_loss: 0.0151 - val_mae: 0.1011 - learning_rate: 5.0000e-04
# Epoch 49/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0036 - mae: 0.0367
# Epoch 49: val_loss did not improve from 0.00934
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0036 - mae: 0.0367 - val_loss: 0.0114 - val_mae: 0.0860 - learning_rate: 5.0000e-04
# Epoch 50/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0038 - mae: 0.0378
# Epoch 50: val_loss improved from 0.00934 to 0.00835, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0038 - mae: 0.0378 - val_loss: 0.0083 - val_mae: 0.0683 - learning_rate: 5.0000e-04
# Epoch 51/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0036 - mae: 0.0367
# Epoch 51: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 0.0036 - mae: 0.0367 - val_loss: 0.0142 - val_mae: 0.0985 - learning_rate: 5.0000e-04
# Epoch 52/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0037 - mae: 0.0371
# Epoch 52: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0037 - mae: 0.0371 - val_loss: 0.0126 - val_mae: 0.0926 - learning_rate: 5.0000e-04
# Epoch 53/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0035 - mae: 0.0361
# Epoch 53: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0035 - mae: 0.0361 - val_loss: 0.0109 - val_mae: 0.0838 - learning_rate: 5.0000e-04
# Epoch 54/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0038 - mae: 0.0387
# Epoch 54: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0038 - mae: 0.0387 - val_loss: 0.0085 - val_mae: 0.0714 - learning_rate: 5.0000e-04
# Epoch 55/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0037 - mae: 0.0377
# Epoch 55: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 0.0037 - mae: 0.0377 - val_loss: 0.0147 - val_mae: 0.1045 - learning_rate: 5.0000e-04
# Epoch 56/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0035 - mae: 0.0360
# Epoch 56: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - loss: 0.0035 - mae: 0.0360 - val_loss: 0.0094 - val_mae: 0.0770 - learning_rate: 5.0000e-04
# Epoch 57/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0035 - mae: 0.0365
# Epoch 57: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0035 - mae: 0.0365 - val_loss: 0.0165 - val_mae: 0.1010 - learning_rate: 5.0000e-04
# Epoch 58/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0037 - mae: 0.0375
# Epoch 58: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0037 - mae: 0.0375 - val_loss: 0.0158 - val_mae: 0.1080 - learning_rate: 5.0000e-04
# Epoch 59/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0038 - mae: 0.0389
# Epoch 59: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0038 - mae: 0.0389 - val_loss: 0.0116 - val_mae: 0.0893 - learning_rate: 5.0000e-04
# Epoch 60/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0035 - mae: 0.0361
# Epoch 60: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 0.0035 - mae: 0.0362 - val_loss: 0.0094 - val_mae: 0.0758 - learning_rate: 5.0000e-04
# Epoch 61/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0035 - mae: 0.0367
# Epoch 61: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0035 - mae: 0.0367 - val_loss: 0.0093 - val_mae: 0.0751 - learning_rate: 5.0000e-04
# Epoch 62/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0034 - mae: 0.0353
# Epoch 62: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0034 - mae: 0.0354 - val_loss: 0.0120 - val_mae: 0.0902 - learning_rate: 5.0000e-04
# Epoch 63/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0034 - mae: 0.0357
# Epoch 63: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0034 - mae: 0.0357 - val_loss: 0.0094 - val_mae: 0.0771 - learning_rate: 5.0000e-04
# Epoch 64/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0037 - mae: 0.0388
# Epoch 64: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0037 - mae: 0.0388 - val_loss: 0.0108 - val_mae: 0.0822 - learning_rate: 5.0000e-04
# Epoch 65/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0034 - mae: 0.0362
# Epoch 65: val_loss did not improve from 0.00835
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0034 - mae: 0.0362 - val_loss: 0.0109 - val_mae: 0.0848 - learning_rate: 5.0000e-04
# Epoch 66/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0031 - mae: 0.0334
# Epoch 66: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0031 - mae: 0.0334 - val_loss: 0.0090 - val_mae: 0.0753 - learning_rate: 2.5000e-04
# Epoch 67/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0031 - mae: 0.0336
# Epoch 67: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0031 - mae: 0.0336 - val_loss: 0.0096 - val_mae: 0.0799 - learning_rate: 2.5000e-04
# Epoch 68/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0029 - mae: 0.0325
# Epoch 68: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0029 - mae: 0.0325 - val_loss: 0.0109 - val_mae: 0.0852 - learning_rate: 2.5000e-04
# Epoch 69/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0030 - mae: 0.0334
# Epoch 69: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0030 - mae: 0.0334 - val_loss: 0.0116 - val_mae: 0.0904 - learning_rate: 2.5000e-04
# Epoch 70/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0030 - mae: 0.0330
# Epoch 70: val_loss did not improve from 0.00835
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0030 - mae: 0.0330 - val_loss: 0.0090 - val_mae: 0.0759 - learning_rate: 2.5000e-04
# Epoch 71/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0029 - mae: 0.0322
# Epoch 71: val_loss improved from 0.00835 to 0.00797, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0029 - mae: 0.0322 - val_loss: 0.0080 - val_mae: 0.0682 - learning_rate: 2.5000e-04
# Epoch 72/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0029 - mae: 0.0325
# Epoch 72: val_loss did not improve from 0.00797
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0029 - mae: 0.0325 - val_loss: 0.0108 - val_mae: 0.0841 - learning_rate: 2.5000e-04
# Epoch 73/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0030 - mae: 0.0335
# Epoch 73: val_loss did not improve from 0.00797
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0030 - mae: 0.0335 - val_loss: 0.0098 - val_mae: 0.0806 - learning_rate: 2.5000e-04
# Epoch 74/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0030 - mae: 0.0334
# Epoch 74: val_loss improved from 0.00797 to 0.00795, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0030 - mae: 0.0334 - val_loss: 0.0080 - val_mae: 0.0689 - learning_rate: 2.5000e-04
# Epoch 75/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0029 - mae: 0.0327
# Epoch 75: val_loss did not improve from 0.00795
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0029 - mae: 0.0327 - val_loss: 0.0091 - val_mae: 0.0760 - learning_rate: 2.5000e-04
# Epoch 76/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0030 - mae: 0.0331
# Epoch 76: val_loss improved from 0.00795 to 0.00791, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0030 - mae: 0.0331 - val_loss: 0.0079 - val_mae: 0.0656 - learning_rate: 2.5000e-04
# Epoch 77/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0037 - mae: 0.0393
# Epoch 77: val_loss did not improve from 0.00791
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0037 - mae: 0.0393 - val_loss: 0.0080 - val_mae: 0.0675 - learning_rate: 2.5000e-04
# Epoch 78/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0032 - mae: 0.0357
# Epoch 78: val_loss improved from 0.00791 to 0.00687, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0032 - mae: 0.0357 - val_loss: 0.0069 - val_mae: 0.0628 - learning_rate: 2.5000e-04
# Epoch 79/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0032 - mae: 0.0357
# Epoch 79: val_loss did not improve from 0.00687
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0032 - mae: 0.0357 - val_loss: 0.0084 - val_mae: 0.0726 - learning_rate: 2.5000e-04
# Epoch 80/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0031 - mae: 0.0343
# Epoch 80: val_loss improved from 0.00687 to 0.00670, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0031 - mae: 0.0343 - val_loss: 0.0067 - val_mae: 0.0625 - learning_rate: 2.5000e-04
# Epoch 81/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0031 - mae: 0.0342
# Epoch 81: val_loss improved from 0.00670 to 0.00627, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - loss: 0.0031 - mae: 0.0342 - val_loss: 0.0063 - val_mae: 0.0605 - learning_rate: 2.5000e-04
# Epoch 82/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0031 - mae: 0.0345
# Epoch 82: val_loss did not improve from 0.00627
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0031 - mae: 0.0345 - val_loss: 0.0081 - val_mae: 0.0711 - learning_rate: 2.5000e-04
# Epoch 83/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0029 - mae: 0.0333
# Epoch 83: val_loss did not improve from 0.00627
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0029 - mae: 0.0333 - val_loss: 0.0115 - val_mae: 0.0907 - learning_rate: 2.5000e-04
# Epoch 84/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0029 - mae: 0.0330
# Epoch 84: val_loss did not improve from 0.00627
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0029 - mae: 0.0330 - val_loss: 0.0085 - val_mae: 0.0714 - learning_rate: 2.5000e-04
# Epoch 85/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0030 - mae: 0.0347
# Epoch 85: val_loss did not improve from 0.00627
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0030 - mae: 0.0347 - val_loss: 0.0074 - val_mae: 0.0675 - learning_rate: 2.5000e-04
# Epoch 86/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0028 - mae: 0.0325
# Epoch 86: val_loss improved from 0.00627 to 0.00559, saving model to best_lstm_model_reg.keras
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0028 - mae: 0.0325 - val_loss: 0.0056 - val_mae: 0.0544 - learning_rate: 2.5000e-04
# Epoch 87/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0029 - mae: 0.0331
# Epoch 87: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0029 - mae: 0.0331 - val_loss: 0.0072 - val_mae: 0.0655 - learning_rate: 2.5000e-04
# Epoch 88/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0028 - mae: 0.0326
# Epoch 88: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0028 - mae: 0.0326 - val_loss: 0.0104 - val_mae: 0.0836 - learning_rate: 2.5000e-04
# Epoch 89/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0028 - mae: 0.0328
# Epoch 89: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0028 - mae: 0.0328 - val_loss: 0.0067 - val_mae: 0.0639 - learning_rate: 2.5000e-04
# Epoch 90/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0028 - mae: 0.0325
# Epoch 90: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0028 - mae: 0.0325 - val_loss: 0.0084 - val_mae: 0.0739 - learning_rate: 2.5000e-04
# Epoch 91/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0028 - mae: 0.0328
# Epoch 91: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0028 - mae: 0.0328 - val_loss: 0.0059 - val_mae: 0.0580 - learning_rate: 2.5000e-04
# Epoch 92/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0028 - mae: 0.0327
# Epoch 92: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0028 - mae: 0.0327 - val_loss: 0.0062 - val_mae: 0.0595 - learning_rate: 2.5000e-04
# Epoch 93/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0027 - mae: 0.0317
# Epoch 93: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0027 - mae: 0.0317 - val_loss: 0.0098 - val_mae: 0.0836 - learning_rate: 2.5000e-04
# Epoch 94/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0029 - mae: 0.0337
# Epoch 94: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0029 - mae: 0.0336 - val_loss: 0.0072 - val_mae: 0.0671 - learning_rate: 2.5000e-04
# Epoch 95/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0026 - mae: 0.0313
# Epoch 95: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0026 - mae: 0.0313 - val_loss: 0.0099 - val_mae: 0.0827 - learning_rate: 2.5000e-04
# Epoch 96/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0028 - mae: 0.0323
# Epoch 96: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0028 - mae: 0.0323 - val_loss: 0.0063 - val_mae: 0.0604 - learning_rate: 2.5000e-04
# Epoch 97/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0027 - mae: 0.0313
# Epoch 97: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0027 - mae: 0.0313 - val_loss: 0.0086 - val_mae: 0.0766 - learning_rate: 2.5000e-04
# Epoch 98/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0028 - mae: 0.0327
# Epoch 98: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0028 - mae: 0.0327 - val_loss: 0.0063 - val_mae: 0.0611 - learning_rate: 2.5000e-04
# Epoch 99/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0026 - mae: 0.0308
# Epoch 99: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0026 - mae: 0.0308 - val_loss: 0.0082 - val_mae: 0.0730 - learning_rate: 2.5000e-04
# Epoch 100/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0027 - mae: 0.0316
# Epoch 100: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0027 - mae: 0.0317 - val_loss: 0.0107 - val_mae: 0.0856 - learning_rate: 2.5000e-04
# Epoch 101/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0027 - mae: 0.0321
# Epoch 101: val_loss did not improve from 0.00559
#
# Epoch 101: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0027 - mae: 0.0321 - val_loss: 0.0097 - val_mae: 0.0827 - learning_rate: 2.5000e-04
# Epoch 102/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0025 - mae: 0.0306
# Epoch 102: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0025 - mae: 0.0306 - val_loss: 0.0087 - val_mae: 0.0768 - learning_rate: 1.2500e-04
# Epoch 103/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0024 - mae: 0.0290
# Epoch 103: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0024 - mae: 0.0290 - val_loss: 0.0078 - val_mae: 0.0702 - learning_rate: 1.2500e-04
# Epoch 104/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0024 - mae: 0.0296
# Epoch 104: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0024 - mae: 0.0296 - val_loss: 0.0076 - val_mae: 0.0696 - learning_rate: 1.2500e-04
# Epoch 105/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0025 - mae: 0.0300
# Epoch 105: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0025 - mae: 0.0300 - val_loss: 0.0111 - val_mae: 0.0898 - learning_rate: 1.2500e-04
# Epoch 106/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0025 - mae: 0.0304
# Epoch 106: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0025 - mae: 0.0304 - val_loss: 0.0085 - val_mae: 0.0748 - learning_rate: 1.2500e-04
# Epoch 107/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0024 - mae: 0.0294
# Epoch 107: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0024 - mae: 0.0294 - val_loss: 0.0086 - val_mae: 0.0739 - learning_rate: 1.2500e-04
# Epoch 108/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0024 - mae: 0.0296
# Epoch 108: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0024 - mae: 0.0296 - val_loss: 0.0097 - val_mae: 0.0820 - learning_rate: 1.2500e-04
# Epoch 109/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0024 - mae: 0.0300
# Epoch 109: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0024 - mae: 0.0299 - val_loss: 0.0062 - val_mae: 0.0619 - learning_rate: 1.2500e-04
# Epoch 110/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0024 - mae: 0.0295
# Epoch 110: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0024 - mae: 0.0295 - val_loss: 0.0067 - val_mae: 0.0640 - learning_rate: 1.2500e-04
# Epoch 111/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0024 - mae: 0.0295
# Epoch 111: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0024 - mae: 0.0295 - val_loss: 0.0085 - val_mae: 0.0747 - learning_rate: 1.2500e-04
# Epoch 112/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0024 - mae: 0.0294
# Epoch 112: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0024 - mae: 0.0294 - val_loss: 0.0070 - val_mae: 0.0663 - learning_rate: 1.2500e-04
# Epoch 113/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0025 - mae: 0.0301
# Epoch 113: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0025 - mae: 0.0301 - val_loss: 0.0089 - val_mae: 0.0782 - learning_rate: 1.2500e-04
# Epoch 114/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0025 - mae: 0.0299
# Epoch 114: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0025 - mae: 0.0299 - val_loss: 0.0080 - val_mae: 0.0718 - learning_rate: 1.2500e-04
# Epoch 115/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0025 - mae: 0.0298
# Epoch 115: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0025 - mae: 0.0298 - val_loss: 0.0083 - val_mae: 0.0737 - learning_rate: 1.2500e-04
# Epoch 116/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0034 - mae: 0.0372
# Epoch 116: val_loss did not improve from 0.00559
#
# Epoch 116: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0034 - mae: 0.0372 - val_loss: 0.0096 - val_mae: 0.0817 - learning_rate: 1.2500e-04
# Epoch 117/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0025 - mae: 0.0304
# Epoch 117: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0025 - mae: 0.0304 - val_loss: 0.0077 - val_mae: 0.0706 - learning_rate: 6.2500e-05
# Epoch 118/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0024 - mae: 0.0299
# Epoch 118: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0024 - mae: 0.0299 - val_loss: 0.0077 - val_mae: 0.0699 - learning_rate: 6.2500e-05
# Epoch 119/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0024 - mae: 0.0293
# Epoch 119: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0024 - mae: 0.0293 - val_loss: 0.0071 - val_mae: 0.0668 - learning_rate: 6.2500e-05
# Epoch 120/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0024 - mae: 0.0289
# Epoch 120: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0024 - mae: 0.0289 - val_loss: 0.0083 - val_mae: 0.0741 - learning_rate: 6.2500e-05
# Epoch 121/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0024 - mae: 0.0292
# Epoch 121: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0024 - mae: 0.0292 - val_loss: 0.0074 - val_mae: 0.0699 - learning_rate: 6.2500e-05
# Epoch 122/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0023 - mae: 0.0288
# Epoch 122: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0023 - mae: 0.0288 - val_loss: 0.0085 - val_mae: 0.0752 - learning_rate: 6.2500e-05
# Epoch 123/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0023 - mae: 0.0284
# Epoch 123: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0023 - mae: 0.0284 - val_loss: 0.0071 - val_mae: 0.0672 - learning_rate: 6.2500e-05
# Epoch 124/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0023 - mae: 0.0285
# Epoch 124: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0023 - mae: 0.0285 - val_loss: 0.0077 - val_mae: 0.0705 - learning_rate: 6.2500e-05
# Epoch 125/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0023 - mae: 0.0285
# Epoch 125: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0023 - mae: 0.0285 - val_loss: 0.0064 - val_mae: 0.0626 - learning_rate: 6.2500e-05
# Epoch 126/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0023 - mae: 0.0283
# Epoch 126: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 0.0023 - mae: 0.0283 - val_loss: 0.0064 - val_mae: 0.0615 - learning_rate: 6.2500e-05
# Epoch 127/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0023 - mae: 0.0288
# Epoch 127: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - loss: 0.0023 - mae: 0.0288 - val_loss: 0.0096 - val_mae: 0.0758 - learning_rate: 6.2500e-05
# Epoch 128/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0024 - mae: 0.0293
# Epoch 128: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0024 - mae: 0.0293 - val_loss: 0.0067 - val_mae: 0.0640 - learning_rate: 6.2500e-05
# Epoch 129/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0023 - mae: 0.0283
# Epoch 129: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0023 - mae: 0.0283 - val_loss: 0.0082 - val_mae: 0.0743 - learning_rate: 6.2500e-05
# Epoch 130/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0023 - mae: 0.0282
# Epoch 130: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0023 - mae: 0.0282 - val_loss: 0.0068 - val_mae: 0.0642 - learning_rate: 6.2500e-05
# Epoch 131/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0023 - mae: 0.0282
# Epoch 131: val_loss did not improve from 0.00559
#
# Epoch 131: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0023 - mae: 0.0282 - val_loss: 0.0078 - val_mae: 0.0704 - learning_rate: 6.2500e-05
# Epoch 132/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0024 - mae: 0.0286
# Epoch 132: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0024 - mae: 0.0286 - val_loss: 0.0074 - val_mae: 0.0691 - learning_rate: 3.1250e-05
# Epoch 133/500
# 217/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0022 - mae: 0.0276
# Epoch 133: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0022 - mae: 0.0276 - val_loss: 0.0067 - val_mae: 0.0644 - learning_rate: 3.1250e-05
# Epoch 134/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0023 - mae: 0.0279
# Epoch 134: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0023 - mae: 0.0279 - val_loss: 0.0064 - val_mae: 0.0627 - learning_rate: 3.1250e-05
# Epoch 135/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0022 - mae: 0.0274
# Epoch 135: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0022 - mae: 0.0274 - val_loss: 0.0068 - val_mae: 0.0646 - learning_rate: 3.1250e-05
# Epoch 136/500
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0023 - mae: 0.0281
# Epoch 136: val_loss did not improve from 0.00559
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0023 - mae: 0.0281 - val_loss: 0.0081 - val_mae: 0.0730 - learning_rate: 3.1250e-05
# Epoch 136: early stopping
# Restoring model weights from the end of the best epoch: 86.

# %%
    from tensorflow.keras.models import load_model
    from sklearn.metrics import  mean_absolute_error


    # پیش‌بینی روی داده تست
    y_pred_scaled = final_model.predict(X_windows_test)  # (N, 1)

    # برگرداندن به مقیاس اصلی
    y_pred_original = y_scaler.inverse_transform(y_pred_scaled)
    y_true_original = y_scaler.inverse_transform(y_windows_test)




    mae = mean_absolute_error(y_true_original, y_pred_original)
    mae2 = mean_absolute_error(y_windows_test, y_pred_scaled)

    print(f"Test MAE(scaled): {mae2:.3f}")
    print(f"Test MAE(true value): {mae:.3f}")
# Out:
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step
# Test MAE(scaled): 0.061
# Test MAE(true value): 1.264

# %%
import matplotlib.pyplot as plt

# Set font sizes and styles for publication
plt.rcParams.update({
    'font.size': 14,
    'axes.labelsize': 16,
    'axes.titlesize': 18,
    'legend.fontsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'font.family': 'serif',  # Optional: use serif font (common in papers)
    'figure.figsize': (8, 5)
})

# Plot training & validation loss
plt.plot(history.history["loss"], label="Training Loss", linewidth=2.5, color='tab:blue')
plt.plot(history.history["val_loss"], label="Validation Loss", linewidth=2.5, color='tab:red')

# Add title and axis labels
plt.title("Model Training Progress", fontsize=18, pad=20)
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")

# Improve layout and add grid
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.legend(frameon=True, loc='upper right', shadow=False, edgecolor='black')

# Use tight layout to prevent clipping
plt.tight_layout()

# Save high-resolution figure for your article
plt.savefig("training_validation_loss.pdf", format='pdf', dpi=300, bbox_inches='tight')
plt.savefig("training_validation_loss.png", format='png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Set font sizes and styles for publication
plt.rcParams.update({
    'font.size': 14,
    'axes.labelsize': 16,
    'axes.titlesize': 18,
    'legend.fontsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'font.family': 'serif',  # Optional: use serif font (common in papers)
    'figure.figsize': (8, 5)
})

# Plot training & validation loss
plt.plot(history.history["loss"], label="Training Loss", linewidth=2.5, color='tab:blue')
plt.plot(history.history["val_loss"], label="Validation Loss", linewidth=2.5, color='tab:red')

# Add title and axis labels
plt.title("Model Training Progress", fontsize=18, pad=20)
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")

# Improve layout and add grid
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.legend(frameon=True, loc='upper right', shadow=False, edgecolor='black')

# Use tight layout to prevent clipping
plt.tight_layout()

# Save high-resolution figure for your article
plt.savefig("training_validation_loss.pdf", format='pdf', dpi=300, bbox_inches='tight')
plt.savefig("training_validation_loss.png", format='png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import pickle

with open('training_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
y_true_original = tf.squeeze(y_true_original)
y_pred_original = tf.squeeze(y_pred_original)
n1=9200
n2=9900
plt.figure(figsize=(15,10))
plt.plot(y_true_original[n1:n2])
plt.plot(y_pred_original[n1:n2])
plt.grid()
